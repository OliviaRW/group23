# %% [markdown]
# > **Note:** In most sessions you will be solving exercises posed in a Jupyter notebook that looks like this one. Because you are cloning a Github repository that only we can push to, you should **NEVER EDIT** any of the files you pull from Github. Instead, what you should do, is either make a new notebook and write your solutions in there, or **make a copy of this notebook and save it somewhere else** on your computer, not inside the `sds` folder that you cloned, so you can write your answers in there. If you edit the notebook you pulled from Github, those edits (possible your solutions to the exercises) may be overwritten and lost the next time you pull from Github. This is important, so don't hesitate to ask if it is unclear.

# %% [markdown]
# ## Use Connector class for accessing the internet
# Even if logging is not important for the below exercises, get in the habit of using this class for connecting to the internet, to practice logging your activity. This will be expected in the final exam.

# %%
import requests,os,time
def ratelimit():
    "A function that handles the rate of your calls."
    time.sleep(1) # sleep one second.

class Connector():
  def __init__(self,logfile,overwrite_log=False,connector_type='requests',session=False,path2selenium='',n_tries = 5,timeout=30):
    """This Class implements a method for reliable connection to the internet and monitoring. 
    It handles simple errors due to connection problems, and logs a range of information for basic quality assessments
    
    Keyword arguments:
    logfile -- path to the logfile
    overwrite_log -- bool, defining if logfile should be cleared (rarely the case). 
    connector_type -- use the 'requests' module or the 'selenium'. Will have different since the selenium webdriver does not have a similar response object when using the get method, and monitoring the behavior cannot be automated in the same way.
    session -- requests.session object. For defining custom headers and proxies.
    path2selenium -- str, sets the path to the geckodriver needed when using selenium.
    n_tries -- int, defines the number of retries the *get* method will try to avoid random connection errors.
    timeout -- int, seconds the get request will wait for the server to respond, again to avoid connection errors.
    """
    
    ## Initialization function defining parameters. 
    self.n_tries = n_tries # For avoiding triviel error e.g. connection errors, this defines how many times it will retry.
    self.timeout = timeout # Defining the maximum time to wait for a server to response.
    ## not implemented here, if you use selenium.
    if connector_type=='selenium':
      assert path2selenium!='', "You need to specify the path to you geckodriver if you want to use Selenium"
      from selenium import webdriver 
      ## HIN download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases

      assert os.path.isfile(path2selenium),'You need to insert a valid path2selenium the path to your geckodriver. You can download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases'
      self.browser = webdriver.Firefox(executable_path=path2selenium) # start the browser with a path to the geckodriver.

    self.connector_type = connector_type # set the connector_type
    
    if session: # set the custom session
      self.session = session
    else:
      self.session = requests.session()
    self.logfilename = logfile # set the logfile path
    ## define header for the logfile
    header = ['id','project','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
    if os.path.isfile(logfile):        
      if overwrite_log==True:
        self.log = open(logfile,'w')
        self.log.write(';'.join(header))
      else:
        self.log = open(logfile,'a')
    else:
      self.log = open(logfile,'w')
      self.log.write(';'.join(header))
    ## load log 
    with open(logfile,'r') as f: # open file
        
      l = f.read().split('\n') # read and split file by newlines.
      ## set id
      if len(l)<=1:
        self.id = 0
      else:
        self.id = int(l[-1][0])+1
            
  def get(self,url,project_name):
    """Method for connector reliably to the internet, with multiple tries and simple error handling, as well as default logging function.
    Input url and the project name for the log (i.e. is it part of mapping the domain, or is it the part of the final stage in the data collection).
    
    Keyword arguments:
    url -- str, url
    project_name -- str, Name used for analyzing the log. Use case could be the 'Mapping of domain','Meta_data_collection','main data collection'. 
    """
     
    project_name = project_name.replace(';','-') # make sure the default csv seperator is not in the project_name.
    if self.connector_type=='requests': # Determine connector method.
      for _ in range(self.n_tries): # for loop defining number of retries with the requests method.
        ratelimit()
        t = time.time()
        try: # error handling 
          response = self.session.get(url,timeout = self.timeout) # make get call

          err = '' # define python error variable as empty assumming success.
          success = True # define success variable
          redirect_url = response.url # log current url, after potential redirects 
          dt = t - time.time() # define delta-time waiting for the server and downloading content.
          size = len(response.text) # define variable for size of html content of the response.
          response_code = response.status_code # log status code.
          ## log...
          call_id = self.id # get current unique identifier for the call
          self.id+=1 # increment call id
          #['id','project_name','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row to be written in the log.
          self.log.write('\n'+';'.join(map(str,row))) # write log.
          return response,call_id # return response and unique identifier.

        except Exception as e: # define error condition
          err = str(e) # python error
          response_code = '' # blank response code 
          success = False # call success = False
          size = 0 # content is empty.
          redirect_url = '' # redirect url empty 
          dt = t - time.time() # define delta t

          ## log...
          call_id = self.id # define unique identifier
          self.id+=1 # increment call_id

          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row
          self.log.write('\n'+';'.join(map(str,row))) # write row to log.
    else:
      t = time.time()
      ratelimit()
      self.browser.get(url) # use selenium get method
      ## log
      call_id = self.id # define unique identifier for the call. 
      self.id+=1 # increment the call_id
      err = '' # blank error message
      success = '' # success blank
      redirect_url = self.browser.current_url # redirect url.
      dt = t - time.time() # get time for get method ... NOTE: not necessarily the complete load time.
      size = len(self.browser.page_source) # get size of content ... NOTE: not necessarily correct, since selenium works in the background, and could still be loading.
      response_code = '' # empty response code.
      row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row 
      self.log.write('\n'+';'.join(map(str,row))) # write row to log file.
    # Using selenium it will not return a response object, instead you should call the browser object of the connector.
    ## connector.browser.page_source will give you the html.
      return call_id
logfile = 'filename'## name your log file.
connector = Connector(logfile)

# %%
import pandas as pd
import time

# %% [markdown]
# # Exercise Set 8: Introduction to Web Scraping
#
# *Afternoon, August 16, 2018*
#
# In this Exercise Set we shall practice our webscraping skills utiilizing only basic python. We shall cover variations between static and dynamic pages and build.

# %% [markdown]
# ## Exercise Section 8.1: Scraping Jobnet.dk
#
# This exercise you get to practice locating the request that the JavaScript sends to get the job data that it builds the joblistings from. You should use the **>Network Monitor<** tool in your browser.
#
# Furthermore you practice spotting how the pagination is done, without clicking on the next page button, but instead changing a small parameter in the URL.

# %% [markdown]
# > **Ex. 8.1.1:** Hit the joblisting webpage here: https://job.jobnet.dk/CV and locate the request that gets the joblisting data using the the **>Network Monitor<**. *(Hint: Filter by XHR files)
#
# > **Ex. 8.1.2.:** Use the `request` module to collect the first 20 results and unpack the relevant `json` data into a `pandas` DataFrame.
#
# > **Ex. 8.1.3.:** Store the 'TotalResultCount' value for later use.

# %%
import requests
TotalResultCount = json.loads(requests.get('https://job.jobnet.dk/CV/FindWork/Search?Offset=0').text)['TotalResultCount']

URL = 'https://job.jobnet.dk/CV/FindWork/Search'

data_list = []

for i in range(0, TotalResultCount, 20):
    response = requests.get('https://job.jobnet.dk/CV/FindWork/Search?Offset=%s' % i)
    data_list.append(pd.DataFrame(json.loads(response.text)['JobPositionPostings']))

# %%
import json
json_data = json.loads(response.text)

[job['JobHeadline'] for job in json_data['JobPositionPostings']]
# Out:
# ['Manager, Procure to Pay (BPI)',
#  'Business Development Manager',
#  'Studentermedhjælpere til AV/IT Support på RUC',
#  'Vice President for Portfolio, Project & Resource Management',
#  'Frontend App Developer',
#  'Head of Site Investigations Procurement (f/m/d)',
#  "Global Category Manager, Direct Materials and CMO's",
#  'Økonomimedarbejder til Borgercenter Voksne - Staben i Socialforvaltningen',
#  'Rybners Handelsgymnasium (HHX) søger underviser til dansk og psykolog (vikariat)',
#  'iOS Developer',
#  'Android Developer',
#  'AWS Lead with DevOps',
#  'Lærer til de praktisk/musiske fag på Katrinedals Skole (vikariat)',
#  'Energiske og kreative sosu-hjælpere til dagvagter på Egebo',
#  'Uddannelseschef til KEA Digital',
#  'Pædagogmedhjælper til Brolopperne',
#  'Senior Regional Talent Manager',
#  'Business Process Manager Commercial',
#  'Medarbejder til rengøring og kantineservice søges',
#  'Pædagog R3']

# %%
TotalResultCount = json_data['TotalResultCount']
print(TotalResultCount)
pd.DataFrame(json_data['JobPositionPostings']).head()
# Out:
# 15001
#    AnonymousEmployer  AssignmentStartDate  AutomatchType  Country  \
# 0              False  0001-01-01T00:00:00              0  Danmark
# 1              False  0001-01-01T00:00:00              0  Danmark
# 2              False  0001-01-01T00:00:00              0  Danmark
# 3              False  0001-01-01T00:00:00              0  Danmark
# 4              False  0001-01-01T00:00:00              0  Danmark
#
#                                           DetailsUrl EmploymentType  \
# 0  https://job.jobnet.dk/CV/FindWork/Details/5030832
# 1  https://job.jobnet.dk/CV/FindWork/Details/5030827
# 2  https://job.jobnet.dk/CV/FindWork/Details/5030824
# 3  https://job.jobnet.dk/CV/FindWork/Details/5030822
# 4  https://job.jobnet.dk/CV/FindWork/Details/5030819
#
#    HasLocationValues  HiringOrgCVR          HiringOrgName       ID  ...  \
# 0               True      47458714        LEGO SYSTEM A/S  5030832  ...
# 1               True      30799968  NORDIC BIOSCIENCE A/S  5030827  ...
# 2               True      29057559   Roskilde Universitet  5030824  ...
# 3               True      12516479         CHR HANSEN A/S  5030822  ...
# 4               True      37073512         Be My Eyes IVS  5030819  ...
#
#    UseWorkPlaceAddressForJoblog  Weight  WorkHours WorkPlaceAbroad  \
# 0                          True     1.0    Fuldtid           False
# 1                          True     1.0    Fuldtid           False
# 2                          True     1.0     Deltid           False
# 3                          True     1.0    Fuldtid           False
# 4                          True     1.0    Fuldtid           False
#
#        WorkPlaceAddress WorkPlaceCity WorkPlaceNotStatic  \
# 0              Åstvej 1       Billund              False
# 1  Herlev Hovedgade 205        Herlev              False
# 2     Universitetsvej 1      Roskilde              False
# 3          Bøge Alle 10      Hørsholm              False
# 4            Sletvej 2F   Tranbjerg J              False
#
#   WorkPlaceOtherAddress  WorkPlacePostalCode WorkplaceID
# 0                 False                 7190       11393
# 1                 False                 2730       91803
# 2                 False                 4000       66024
# 3                 False                 2970        8958
# 4                 False                 8310           0
#
# [5 rows x 44 columns]

# %% [markdown]
# > **Ex. 8.1.4:** This exercise is about paging the results. We need to understand the websites pagination scheme.
#
# > Now scroll down the webpage and press the next page button. See how the parameters of the url changes as you turn the pages.
#
# > **Ex. 8.1.5:** Design a`for` loop using the `range` function that changes this paging parameter in the URL. Use the TotalResultCount parameter from before to define the limits of the range function. Store these urls in a container.
#
# >**extra** Change the SortValue parameter from BestMatch to CreationDate, to make the sorting amendable to updating results daily.
#
# *(HINT: See that the parameter is an offset and that this relates to the number of results pr. call made.)*

# %%
# [Answer to Ex. 8.1.4-5 here]

# %% [markdown]
# > **Ex.8.1.6:** Pick 20 random links using the `random.sample()` function and collect them using the `Connector` class. Also use the `time.sleep()` function to limit the rate of your calls. Make sure to save the links already collected in a `set()` container to avoid having to reload links already collected. ***extra***: monitor the time left to completing the loop by using `tqdm.tqdm()` function.
#
# > **Ex.8.1.7:** Load all the results into a DataFrame.

# %%
# [Answer to Ex. 8.1.6-7 here]

# %% [markdown]
# ## Exercise Section 8.2: Scraping Trustpilot.com
# Now for a slightly more elaborate, yet still simple scraping problem. Here we want to scrape trustpilot for user reviews. This data is very nice since it provides free labeled data (rating) to train a machine learning model to understand positive and negative sentiment.
#
# Here you will practice crawling a website collecting the links to each company review page, and finally locate another behind the scenes JavaScript request that gets the review data in a neat json format.

# %% [markdown]
# > **Ex. 8.2.1:** Visit the https://www.trustpilot.com/ website and locate the categories page.
# From this page you find links to company listings.
#
# > **Ex. 8.2.2:**
# Get the category page using the `requests` module and extract each link to a specific category page from the HTML. This can be done using the basic python `.split()` string method. Make sure only links within the ***/categories/*** section are kept, checking each string using the ```if 'pattern' in string``` condition.
#
# *(Hint: The links are relative. You need to add the domain name)*

# %%
import re
link_regex = re.compile(r'href="/categories/([^"]+)')
trustpilot_text = requests.get('https://www.trustpilot.com/categories').text
link_m = link_regex.findall(trustpilot_text)
link_m
# Out:
# ['agistment_service',
#  'feed_store',
#  'aquarium',
#  'aquarium_shop',
#  'bird_shop',
#  'dog_breeder',
#  'dog_day_care_center',
#  'dog_trainer',
#  'dog_walker',
#  'horseback_riding_service',
#  'pet_adoption_service',
#  'pet_boarding_service',
#  'pet_groomer',
#  'pet_sitter',
#  'pet_store',
#  'pet_supply_store',
#  'pet_trainer',
#  'tack_shop',
#  'veterinarian',
#  'zoo',
#  'aromatherapy_supply_store',
#  'barber_shop',
#  'barber_supply_store',
#  'beauty_product_supplier',
#  'beauty_products_wholesaler',
#  'beauty_salon',
#  'beauty_supply_store',
#  'body_piercing_shop',
#  'cosmetic_products_manufacturer',
#  'cosmetics_industry',
#  'cosmetics_store',
#  'cosmetics_wholesaler',
#  'cosmetics_and_parfumes_supplier',
#  'day_spa',
#  'fitness_and_nutrition_service',
#  'flavours_fragrances_and_aroma_supplier',
#  'foot_care',
#  'hair_extensions_supplier',
#  'hair_product_store',
#  'hair_removal_service',
#  'hair_replacement_service',
#  'hair_salon',
#  'health_spa',
#  'health_and_beauty_shop',
#  'herb_shop',
#  'herbalist',
#  'makeup_artist',
#  'massage_therapist',
#  'mobile_hairdresser',
#  'nail_salon',
#  'perfume_store',
#  'sauna',
#  'skin_care_clinic',
#  'spa',
#  'tanning_studio',
#  'tattoo_shop',
#  'tattoo_and_piercing_shop',
#  'toiletries_store',
#  'vitamin_and_supplements_store',
#  'weight_loss_service',
#  'wellness_center',
#  'wellness_program',
#  'yoga_instructor',
#  'yoga_retreat_center',
#  'yoga_studio',
#  'accounting_software_company',
#  'advertising_agency',
#  'advertising_photographer',
#  'affiliate_marketing_service',
#  'applicant_tracking_system',
#  'audio_transcription_service',
#  'auditor',
#  'automation_company',
#  'bpo_company',
#  'bpo_placement_agency',
#  'business_administration_service',
#  'business_broker',
#  'business_center',
#  'business_development_service',
#  'business_management_consultant',
#  'business_networking_company',
#  'business_and_it_consulting_agency',
#  'business_to_business_service',
#  'crm_provider',
#  'call_center',
#  'card_processing_service',
#  'chamber_of_agriculture',
#  'chamber_of_commerce',
#  'circular_distribution_service',
#  'clothing_wholesale_market_place',
#  'clothing_wholesaler',
#  'cloud_computing_service',
#  'cloud_storage_service',
#  'commercial_agent',
#  'commercial_cleaning_service',
#  'commercial_printer',
#  'commercial_real_estate_agency',
#  'commercial_real_estate_inspector',
#  'computer_consultant',
#  'computer_security_service',
#  'conference_calling_service',
#  'conference_center',
#  'conference_and_meeting_room_organizer',
#  'construction_material_wholesaler',
#  'consultant',
#  'copying_supply_store',
#  'corporate_gift_supplier',
#  'courier_service',
#  'courier_and_delivery_service',
#  'coworking_space',
#  'custom_label_printer',
#  'data_destruction_equipment_wholesaler',
#  'data_entry_service',
#  'data_recovery_service',
#  'database_management_company',
#  'debris_removal_service',
#  'delivery_service',
#  'design_agency',
#  'desktop_publishing_service',
#  'digital_printer',
#  'digital_printing_service',
#  'direct_mail_advertising',
#  'distribution_service',
#  'drives_and_storage_service',
#  'educational_consultant',
#  'eftpos_equipment_supplier',
#  'electrical_appliance_wholesaler',
#  'electrical_wholesaler',
#  'electronics_wholesaler',
#  'employment_consultant',
#  'executive_search_firm',
#  'executive_suite_rental_agency',
#  'freight_forwarding_service',
#  'furniture_wholesaler',
#  'graphic_designer',
#  'greeting_card_shop',
#  'human_ressource_consulting',
#  'import_export_company',
#  'industrial_chemicals_wholesaler',
#  'industrial_design_company',
#  'internet_marketing_service',
#  'laboratory',
#  'logistics_service',
#  'mailbox_rental_service',
#  'mailing_service',
#  'makerspace',
#  'market_operator',
#  'market_researcher',
#  'marketing_agency',
#  'marketing_consultant',
#  'media_consultant',
#  'meeting_planning_service',
#  'office_accessories_wholesaler',
#  'office_equipment_supplier',
#  'office_refurbishment_service',
#  'office_space_rental_agency',
#  'office_supply_store',
#  'online_marketing_agency',
#  'packaging_company',
#  'packaging_machinery',
#  'packaging_store',
#  'packaging_supply_store',
#  'payment_service',
#  'payroll_service',
#  'print_shop',
#  'printer_and_scanner_store',
#  'printing_equipment_supplier',
#  'printing_equipment_and_supplies',
#  'print_and_signs_store',
#  'professional_organizer',
#  'promotional_items_store',
#  'promotional_products_supplier',
#  'recruiter',
#  'recruitment_service',
#  'research_and_product_development',
#  'seo_service',
#  'screen_printer',
#  'screen_printing_shop',
#  'security_guard_service',
#  'shipping_company',
#  'shipping_service',
#  'shipping_and_mailing_service',
#  'sign_shop',
#  'stationery_store',
#  'sticker_manufacturer',
#  'store_equipment_supplier',
#  'telemarketing_service',
#  'temp_agency',
#  'toner_cartridge_supplier',
#  'transcription_service',
#  'translator',
#  'vehicle_shipping_agent',
#  'video_conferencing_service',
#  'virtual_office_rental',
#  'warehouse',
#  'web_designer',
#  'website_designer',
#  'wholesale_market',
#  'wholesaler',
#  'wholesaler_household_appliances',
#  'e_commerce_agency',
#  'e_commerce_service',
#  'e-commerce_solution_provider',
#  'acoustical_consultant',
#  'agricultural_machinery_manufacturer',
#  'air_conditioning_contractor',
#  'air_filter_supplier',
#  'alternator_supplier',
#  'aluminium_supplier',
#  'aluminum_window',
#  'architect',
#  'architectural_designer',
#  'biotechnology_company',
#  'building_consultant',
#  'building_design_company',
#  'building_equipment_hire_service',
#  'building_firm',
#  'building_materials_market',
#  'building_materials_store',
#  'building_materials_supplier',
#  'building_restoration_service',
#  'concrete_contractor',
#  'concrete_product_supplier',
#  'conservatory_construction_contractor',
#  'construction_company',
#  'construction_machine_dealer',
#  'contractor',
#  'custom_home_builder',
#  'decal_supplier',
#  'door_supplier',
#  'drafting_service',
#  'electrical_engineer',
#  'electrical_equipment_supplier',
#  'engineer',
#  'environmental_engineer',
#  'equipment_rental_agency',
#  'equipment_supplier',
#  'excavating_contractor',
#  'fabric_product_manufacturer',
#  'fabrication_engineer',
#  'fastener_supplier',
#  'fireplace_manufacturer',
#  'garage_builder',
#  'gas_engineer',
#  'gazebo_builder',
#  'general_contractor',
#  'hvac_contractor',
#  'heating_contractor',
#  'heating_equipment_supplier',
#  'home_builder',
#  'industrial_vacuum_equipment_supplier',
#  'insulation_contractor',
#  'interior_construction_contractor',
#  'interior_fitting_contractor',
#  'janitorial_equipment_supplier',
#  'joiner',
#  'laboratory_equipment_supplier',
#  'landscaping_service',
#  'lighting_manufacturer',
#  'log_home_builder',
#  'machine_shop',
#  'machining_manufacturer',
#  'manufacturer',
#  'manufacturing service',
#  'marine_engineer',
#  'masonry_contractor',
#  'metal_fabricator',
#  'modular_home_builder',
#  'natural_stone_supplier',
#  'pvc_industry',
#  'pvc_windows_supplier',
#  'pallet_supplier',
#  'plastic_fabrication_company',
#  'playground_equipment_supplier',
#  'plumbing_supply_store',
#  'portable_building_manufacturer',
#  'powder_coating_service',
#  'prefabricated_house_companies',
#  'property_maintenance',
#  'protective_clothing_supplier',
#  'pump_supplier',
#  'quantity_surveyor',
#  'railing_contractor',
#  'real_estate_surveyor',
#  'roofing_contractor',
#  'safety_equipment_supplier',
#  'safety_and_work_wear_store',
#  'shed_builder',
#  'siding_contractor',
#  'skylight_contractor',
#  'solar_energy_contractor',
#  'solar_hot_water_system_supplier',
#  'stair_contractor',
#  'steel_distributor',
#  'stone_cutter',
#  'stone_supplier',
#  'stonemason',
#  'stove_builder',
#  'sunroom_contractor',
#  'tile_contractor',
#  'tool_store',
#  'window_installation_service',
#  'window_supplier',
#  'window_tinting_service',
#  'wood_frame_supplier',
#  'woodworker',
#  'woodworking_supply_store',
#  'accounting_school',
#  'adult_education_school',
#  'after_school_program',
#  'apprenticeship_center',
#  'architecture_school',
#  'art_school',
#  'auditorium',
#  'beauty_school',
#  'business_school',
#  'cbse_school',
#  'career_coach',
#  'career_and_education_provider',
#  'chinese_language_instructor',
#  'chinese_language_school',
#  'class',
#  'college',
#  'computer_training_school',
#  'cooking_school',
#  'distance_learning_center',
#  'drivers_license_training_school',
#  'driving_school',
#  'driving_test_centre',
#  'education_center',
#  'educational_institution',
#  'educational_supply_store',
#  'educational_testing_service',
#  'elementary_school',
#  'emergency_training_school',
#  'engineering_school',
#  'english_language_instructor',
#  'english_language_school',
#  'foreign_languages_program_school',
#  'german_language_instructor',
#  'graduate_school',
#  'high_school',
#  'hospitality_and_tourism_school',
#  'iut',
#  'insurance_school',
#  'japanese_language_instructor',
#  'language_course_provider',
#  'language_school',
#  'learning_center',
#  'life_coach',
#  'medical_school',
#  'preschool',
#  'primary_school',
#  'private_tutor',
#  'real_estate_school',
#  'resume_service',
#  'school',
#  'software_training_institute',
#  'student_career_counseling_office',
#  'student_housing_center',
#  'studying_center',
#  'technical_university',
#  'trade_school',
#  'training_school',
#  'university',
#  'vocational_training_school',
#  'appliance_rental_service',
#  'appliance_store',
#  'battery_store',
#  'binocular_store',
#  'cable_company',
#  'camera_store',
#  'cell_phone_accessory_store',
#  'cell_phone_recycling_and_unlocking_service',
#  'cell_phone_store',
#  'cell_phone_unlocking_service',
#  'closed_circuit_television',
#  'computer_accessories_store',
#  'computer_hardware_manufacturer',
#  'computer_networking_center',
#  'computer_repair_service',
#  'computer_service',
#  'computer_software_store',
#  'computer_store',
#  'computer_support_and_services',
#  'computer_and_accessories',
#  'dns_provider',
#  'electrical_repair_shop',
#  'electronic_parts_supplier',
#  'electronic_spare_parts_and_component_store',
#  'electronics_company',
#  'electronics_repair_shop',
#  'electronics_store',
#  'electronics_vending_machine',
#  'email_service_provider',
#  'hi-fi_shop',
#  'stereo_store',
#  'home_theater_store',
#  'internet_provider',
#  'internet_service_provider',
#  'internet_shop',
#  'mobile_network_operator',
#  'mobile_phone_repair_shop',
#  'phone_repair_service',
#  'phone_and_internet_service',
#  'photo_restoration_service',
#  'photo_shop',
#  'process_server',
#  'screen_store',
#  'search_engine',
#  'software_company',
#  'software_vendor',
#  'tv_store',
#  'technical_service',
#  'telecommunications_contractor',
#  'telecommunications_equipment_supplier',
#  'telecommunications_service_provider',
#  'telephone_company',
#  'used_computer_store',
#  'vpn_service',
#  'web_collaboration_platform',
#  'web_hosting_service',
#  'adult_dating_service',
#  'adult_entertainment_club',
#  'adult_entertainment_store',
#  'amusement_center',
#  'aquatic_center',
#  'art_center',
#  'art_gallery',
#  'balloon_artist',
#  'betting_agency',
#  'bingo_hall',
#  'bookmaker',
#  'casino',
#  'childrens_party_service',
#  'childrens_store',
#  'childrens_toy_store',
#  'club',
#  'dj',
#  'dating_service',
#  'entertainer',
#  'entertainment_agency',
#  'erotic_clothing_store',
#  'escape_room_center',
#  'event_management_company',
#  'event_planner',
#  'event_technology_service',
#  'event_ticket_seller',
#  'event_venue',
#  'festival',
#  'film_and_photograph_library',
#  'gambling_house',
#  'game_store',
#  'gaming_service_provider',
#  'gift_shop',
#  'karaoke',
#  'lottery_vendor',
#  'movie_rental_store',
#  'movie_streaming_service',
#  'movie_theater',
#  'online_casino_or_bookmaker',
#  'party_equipment_rental_service',
#  'party_planner',
#  'party_store',
#  'performing_arts_group',
#  'performing_arts_theater',
#  'sex_toy_store',
#  'singing_telegram_service',
#  'toy_store',
#  'video_arcade',
#  'video_game_store',
#  'wedding_photographer',
#  'wedding_planner',
#  'wedding_service',
#  'wedding_store',
#  'wedding_venue',
#  'agricultural_product_wholesaler',
#  'agricultural_service_supply_agency',
#  'agrochemicals_supplier',
#  'alcohol_manufacturer',
#  'alcohol_store',
#  'bagel_shop',
#  'bakery',
#  'beverage_distributor',
#  'brewery',
#  'butcher_shop',
#  'candy_store',
#  'cannabis_store',
#  'catering_service',
#  'catering_food_and_drink_supplies',
#  'cigar_shop',
#  'coffee_machine_supplier',
#  'coffee_roasters',
#  'coffee_store',
#  'dairy',
#  'discount_supermarket',
#  'electronic_cigarette_store',
#  'food_manufacturer',
#  'food_processing_company',
#  'food_producer',
#  'food_products_supplier',
#  'fruit_and_vegetable_processing',
#  'fruit_and_vegetable_store',
#  'gourmet_grocery_store',
#  'green_grocers',
#  'asador',
#  'grocery_delivery_service',
#  'health_food_store',
#  'honey_farm',
#  'liquor_store',
#  'meal_delivery',
#  'meat_products',
#  'natural_foods_store',
#  'nut_store',
#  'olive_oil_manufacturer',
#  'organic_food_store',
#  'organic_store',
#  'supermarket',
#  'tea_manufacturer',
#  'tea_market_place',
#  'tea_store',
#  'tobacco_shop',
#  'tobacco_store',
#  'tobacco_supplier',
#  'vaporizer_store',
#  'wine_store',
#  'acupuncturist',
#  'addiction_treatment_center',
#  'adoption_agency',
#  'alcoholism_treatment_program',
#  'alternative_medicine_practitioner',
#  'assisted_living_facility',
#  'blood_testing_service',
#  'cancer_treatment_center',
#  'chinese_medicine_store',
#  'chiropractor',
#  'community_health_center',
#  'contact_lenses_supplier',
#  'cosmetic_dentist',
#  'dental_clinic',
#  'dental_implants_periodontist',
#  'dental_supply_store',
#  'dentist',
#  'denture_care_center',
#  'diabetes_equipment_supplier',
#  'diagnostic_center',
#  'disability_equipment_supplier',
#  'doctor',
#  'drug_addiction_treatment_center',
#  'drugstore',
#  'emergency_care_service',
#  'emergency_dental_service',
#  'eye_care_center',
#  'family_planning_center',
#  'fertility_clinic',
#  'fertility_physician',
#  'first_aid',
#  'gastroenterologist',
#  'gastrointestinal_surgeon',
#  'general_hospital',
#  'general_practitioner',
#  'glasses_wholesaler',
#  'health_consultant',
#  'health_resort',
#  'hearing_aid_store',
#  'herbal_medicine_store',
#  'home_health_care_service',
#  'home_help',
#  'home_help_service_agency',
#  'homeopath',
#  'hospice',
#  'hospital',
#  'hospital_and_equipment_supplies',
#  'hypnotherapy_service',
#  'kinesiologist',
#  'marriage_counselor',
#  'maternity_hospital',
#  'medical_billing_service',
#  'medical_center',
#  'medical_certificate_service',
#  'medical_diagnostic_imaging_center',
#  'medical_equipment_manufacturer',
#  'medical_equipment_supplier',
#  'medical_group',
#  'medical_spa',
#  'medical_supply_store',
#  'medical_technology_manufacturer',
#  'medicine_exporter',
#  'mental_health_service',
#  'mobility_equipment_supplier',
#  'neonatal_physician',
#  'nutritionist',
#  'gynecologist',
#  'occupational_health_service',
#  'online_pharmacy',
#  'online_prescription_medication_vendor',
#  'ophthalmology_clinic',
#  'optician',
#  'optometrist',
#  'orthodontist',
#  'osteopath',
#  'pediatrician',
#  'pharmaceutical_company',
#  'pharmaceutical_lab',
#  'pharmaceutical_products_wholesaler',
#  'pharmacy',
#  'physiotherapist',
#  'physiotherapy_center',
#  'physiotherapy_equip_supplier',
#  'plastic_surgery_clinic',
#  'pregnancy_care_center',
#  'private_hospital',
#  'psychologist',
#  'psychotherapist',
#  'reproductive_health_clinic',
#  'std_testing_service',
#  'self_service_health_station',
#  'sexologist',
#  'specialized_clinic',
#  'specialized_hospital',
#  'sports_massage_therapist',
#  'sports_medicine_physician',
#  'surgical_center',
#  'surgical_supply_store',
#  'teeth_whitening_service',
#  'travel_clinic',
#  'wheelchair_rental_service',
#  'wheelchair_store',
#  'obstetrics_gynecology_clinic',
#  'youth_care',
#  'aeromodel_shop',
#  'art_antiques',
#  'art_dealer',
#  'art_studio',
#  'art_supply_store',
#  'artist',
#  'camping_store',
#  'collectibles_store',
#  'craft_store',
#  'doll_store',
#  'drum_store',
#  'embroidery_service',
#  'fashion_designer',
#  'fishing_charter',
#  'fishing_store',
#  'glazier',
#  'haberdashery',
#  'handicraft',
#  'handicrafts_wholesaler',
#  'hobby_store',
#  'hunting_store',
#  'magic_store',
#  'metaphysical_supply_store',
#  'model_car_play_area',
#  'scale_model_shop',
#  'model_train_store',
#  'musical_instrument_manufacturer',
#  'musical_instrument_repair_shop',
#  'musical_instrument_store',
#  'paint_store',
#  'piano_store',
#  'psychic',
#  'recreation_center',
#  'sewing_machine_store',
#  'trading_card_store',
#  'trophy_shop',
#  'used_musical_instrument_store',
#  'wool_store',
#  'yarn_store',
#  'air_conditioning_repair_service',
#  'air_conditioning_system_supplier',
#  'australian_goods_store',
#  'bathroom_remodeler',
#  'bathroom_supply_store',
#  'bed_shop',
#  'bedding_store',
#  'bedroom_furniture_store',
#  'blinds_shop',
#  'heating_supplier',
#  'boutique',
#  'burglar_alarm_store',
#  'cabinet_store',
#  'candle_store',
#  'carpet_store',
#  'carpet_wholesaler',
#  'ceramics_wholesaler',
#  'childrens_furniture_store',
#  'cleaning_products_supplier',
#  'curtain_store',
#  'curtain_supplier_and_maker',
#  'decoration_and_interior_design_store',
#  'fence_supply_store',
#  'fireplace_store',
#  'firewood_supplier',
#  'flag_store',
#  'flat_pack_assembly',
#  'flooring_store',
#  'florist',
#  'flower_delivery',
#  'flower_designer',
#  'flower_market',
#  'furniture_accessories',
#  'furniture_maker',
#  'furniture_manufacturer',
#  'furniture_rental_service',
#  'furniture_store',
#  'futon_store',
#  'garden_building_retail',
#  'garden_center',
#  'garden_furniture_store',
#  'gardener',
#  'gas_installation_service',
#  'general_store',
#  'glassware_store',
#  'grill_store',
#  'hardware_accessories_store',
#  'hardware_store',
#  'home_automation_company',
#  'home_goods_store',
#  'home_improvement_store',
#  'hot_tub_store',
#  'interior_designer',
#  'kitchen_furniture_store',
#  'kitchen_remodeler',
#  'kitchen_supply_store',
#  'knife_store',
#  'lawn_equipment_rental_service',
#  'leather_cleaning_service',
#  'leather_goods_store',
#  'light_bulb_supplier',
#  'lighting_store',
#  'linens_store',
#  'living_room_furniture_store',
#  'mailbox_supplier',
#  'mattress_store',
#  'novelty_store',
#  'office_furniture_store',
#  'outdoor_furniture_store',
#  'patio_enclosure_supplier',
#  'plant_nursery',
#  'pond_supply_store',
#  'poster_store',
#  'refrigerator_store',
#  'remodeler',
#  'rug_store',
#  'rustic_furniture_store',
#  'security_equipment_store',
#  'seed_supplier',
#  'sofa_store',
#  'solar_energy_equipment_supplier',
#  'store',
#  'swimming_pool_repair_service',
#  'tile_store',
#  'tree_service',
#  'upholstery_shop',
#  'variety_store',
#  'wallpaper_store',
#  'window_treatment_store',
#  'wood_stove_shop',
#  'air_duct_cleaning_service',
#  'asbestos_testing_service',
#  'bird_control_service',
#  'bricklayer',
#  'carpenter',
#  'carpet_cleaning_service',
#  'carpet_installer',
#  'chimney_services',
#  'chimney_sweep',
#  'cleaners',
#  'cleaning_service',
#  'double_glazing_supplier',
#  'electrical_installation_service',
#  'electrician',
#  'emergency_locksmith_service',
#  'fire_protection_service',
#  'flooring_contractor',
#  'grounds_maintenance_service',
#  'gutter_cleaning_service',
#  'handyman',
#  'home_inspector',
#  'hot_tub_repair_service',
#  'house_cleaning_service',
#  'house_clearance_service',
#  'house_sitter',
#  'janitorial_service',
#  'lawn_care_service',
#  'lighting_consultant',
#  'linoleum_store',
#  'locksmith',
#  'moving_company',
#  'moving_supply_store',
#  'moving_and_storage_service',
#  'painter',
#  'pest_control_service',
#  'piano_moving_service',
#  'plumber',
#  'pool_cleaning_service',
#  'repair_service',
#  'security_service',
#  'security_system_installer',
#  'security_system_supplier',
#  'self_storage_facility',
#  'storage_facility',
#  'water_damage_restoration_service',
#  'waterproofing_company',
#  'window_cleaning_service',
#  'wine_storage_facility',
#  'wood_and_laminate_flooring_supplier',
#  'bail_bonds_service',
#  'bankruptcy_attorney',
#  'barrister',
#  'civil_law_attorney',
#  'commissioner_for_oaths',
#  'conveyancer',
#  'criminal_law_attorney',
#  'customs_broker',
#  'divorce_attorney',
#  'divorce_service',
#  'elder_law_attorney',
#  'estate_planning_attorney',
#  'family_law_attorney',
#  'general_practice_attorney',
#  'immigration_attorney',
#  'immigration_and_naturalization_service',
#  'insurance_attorney',
#  'law_firm',
#  'lawyer',
#  'legal_services',
#  'license_bureau',
#  'mediation_service',
#  'municipal_administration_office',
#  'notary_public',
#  'passport_agent',
#  'personal_injury_lawyer',
#  'real_estate_attorney',
#  'tax_attorney',
#  'trial_attorney',
#  'animation_studio',
#  'audio_visual_consultant',
#  'audio_visual_equipment_supplier',
#  'blogger',
#  'book_publisher',
#  'book_store',
#  'childrens_book_store',
#  'cinema_equipment_supplier',
#  'dvd_store',
#  'film_production_company',
#  'film_and_video_producer',
#  'magazine_store',
#  'media_company',
#  'media_house',
#  'media_and_marketing_agency',
#  'modeling_agency',
#  'movie_studio',
#  'multimedia_and_electronic_book_publisher',
#  'music_producer',
#  'music_publisher',
#  'music_store',
#  'news_service',
#  'photo_agency',
#  'photo_printing_service',
#  'photographer',
#  'photography_service',
#  'photography_studio',
#  'public_relations_firm',
#  'publisher',
#  'radio_broadcaster',
#  'rare_book_store',
#  'social_media_agency',
#  'television_station',
#  'used_book_store',
#  'video_duplication_service',
#  'video_editing_service',
#  'video_production_service',
#  'accident_insurance_company',
#  'accountant',
#  'accounting_firm',
#  'alternate_finance_services',
#  'apartment_rental_agency',
#  'asset_manager',
#  'auto_insurance_agency',
#  'bank',
#  'bookkeeping_service',
#  'business_insurance_company',
#  'car_finance_and_loan_company',
#  'cashback_provider',
#  'check_cashing_service',
#  'commercial_insurance_company',
#  'credit_bureau',
#  'credit_counseling_service',
#  'credit_reporting_agency',
#  'cryptocurrency_service',
#  'currency_exchange_service',
#  'debt_collection_agency',
#  'debt_relief_service',
#  'dental_insurance_agency',
#  'disability_insurance_company',
#  'finance_broker',
#  'financial_consultant',
#  'financial_institution',
#  'financial_planner',
#  'fund_management_company',
#  'gold_dealer',
#  'gold_and_silver_trading_company',
#  'health_insurance_agency',
#  'home_insurance_agency',
#  'income_protection_insurance',
#  'insurance_agency',
#  'insurance_broker',
#  'insurance_company',
#  'investment_bank',
#  'investment_company',
#  'investment_service',
#  'landlord_insurance_company',
#  'liability_insurance_company',
#  'life_insurance_agency',
#  'loan_agency',
#  'loss_adjuster',
#  'money_order_service',
#  'money_transfer_service',
#  'mortgage_broker',
#  'mortgage_lender',
#  'motorcycle_insurance_agency',
#  'non_bank_finance',
#  'pawn_shop',
#  'pension_fund',
#  'personal_insurance_company',
#  'private_equity_firm',
#  'private_sector_bank',
#  'property_investment',
#  'property_management_company',
#  'real_estate_agency',
#  'real_estate_agents',
#  'real_estate_appraiser',
#  'real_estate_consultant',
#  'real_estate_rental_agency',
#  'renters_insurance_agency',
#  'stock_broker',
#  'tax_advisor',
#  'tax_assessor',
#  'tax_consultant',
#  'tax_preparation',
#  'tax_preparation_service',
#  'tax_preparation_software',
#  'term_life_insurance_company',
#  'travel_insurance_company',
#  'association_or_organization',
#  'buddhist_supplies_store',
#  'career_guidance_service',
#  'charity',
#  'child_care_agency',
#  'coaching_center',
#  'consumer_advice_center',
#  'emergency_training',
#  'employment_agency',
#  'employment_search_service',
#  'funeral_home',
#  'genealogist',
#  'guardia_civil',
#  'housing_association',
#  'housing_society',
#  'information_bureau',
#  'information_services',
#  'labor_union',
#  'low_income_housing_program',
#  'non_governmental_organization',
#  'notaries_association',
#  'recycling_center',
#  'reformed_church',
#  'sewage_disposal_service',
#  'social_club',
#  'training_center',
#  'tutoring_service',
#  'waste_management_service',
#  'american_restaurant',
#  'cafe',
#  'cafeteria',
#  'caribbean_restaurant',
#  'diner',
#  'european_restaurant',
#  'family_restaurant',
#  'fried_chicken_takeaway',
#  'online_food_ordering_service',
#  'pizza_delivery_service',
#  'pizza_restaurant',
#  'pizzatakeaway',
#  'pub',
#  'restaurant',
#  'restaurant_supply_store',
#  'take_away_service',
#  'activewear_store',
#  'army_and_navy_store',
#  'baby_clothing_store',
#  'baby_store',
#  'bag_shop',
#  'bags_and_luggage_store',
#  'bazar',
#  'beach_clothing_store',
#  'belt_shop',
#  'boot_store',
#  ...]

# %% [markdown]
# > **Ex. 8.2.3:** Get one of the category section links. Write a function to extract the links to the company review page from the HTML.
#
# > **Ex. 8.2.4:** Figure out how the pagination is done, by following how the url changes when pressing the **next page**-button to obtain more company listings. Write a function that builds links to paging all the company listing results of each category. This includes parsing the number of subpages of each category and changing the correct parameter in the url.
#
# (Hint: Find the maximum number of result pages, right before the next page button and make a loop change the page parameter of the url.)

# %%
params = {'numberofreviews': '0', 
          'page': '1',
          'status': 'collecting', 
          'timeperiod': '0'}
url = 'https://www.trustpilot.com/categories/business_to_business_service/businesses?'
json.loads(requests.get(url, params = params).text)
# Out:
# {'filteredBusinessUnitList': [{'businessUnitId': '4bdc9828000064000505dc60',
#    'displayName': 'Flashbay',
#    'identifyingName': 'www.flashbay.com',
#    'numberOfReviews': 14922.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '50b8769100006400051f0dbb',
#    'displayName': 'DoItYourselfLettering.com',
#    'identifyingName': 'doityourselflettering.com',
#    'numberOfReviews': 7866.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '51b3db64000064000539d4c7',
#    'displayName': 'Nevada Corporate Headquarters, Inc.',
#    'identifyingName': 'nchinc.com',
#    'numberOfReviews': 3335.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '4bec568700006400050b477b',
#    'displayName': 'Trusted Translations, Inc.',
#    'identifyingName': 'www.trustedtranslations.com',
#    'numberOfReviews': 1072.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '51f836c200006400056d0a2b',
#    'displayName': 'TheFlyerLab.com',
#    'identifyingName': 'theflyerlab.com',
#    'numberOfReviews': 803.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '563be3900000ff0005853258',
#    'displayName': 'Tiny Little Monster',
#    'identifyingName': 'tinylittlemonster.com',
#    'numberOfReviews': 636.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '53d25b1600006400057924b6',
#    'displayName': 'Pack Mule',
#    'identifyingName': 'packmule.com',
#    'numberOfReviews': 511.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '5941879f0000ff0005a493aa',
#    'displayName': "Leapin' Lizard Labels",
#    'identifyingName': 'leapinlizardlabels.com',
#    'numberOfReviews': 511.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '591222750000ff0005a225cf',
#    'displayName': 'The Manko Company',
#    'identifyingName': 'mankocompany.com',
#    'numberOfReviews': 389.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '50b7b53200006400051f094e',
#    'displayName': 'RELYmedia',
#    'identifyingName': 'relymedia.com',
#    'numberOfReviews': 297.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '51932f4900006400052cc18d',
#    'displayName': 'Harvard Business Services',
#    'identifyingName': 'delawareinc.com',
#    'numberOfReviews': 2600.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '4ff34faa000064000517796d',
#    'displayName': 'RestroomDirect',
#    'identifyingName': 'restroomdirect.com',
#    'numberOfReviews': 1906.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '5a71ed51468781000120393e',
#    'displayName': 'Office Sign Company',
#    'identifyingName': 'officesigncompany.com',
#    'numberOfReviews': 1825.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '5542a3b20000ff00057f1eed',
#    'displayName': 'Displayit',
#    'identifyingName': 'displayit.com',
#    'numberOfReviews': 1168.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '51f7bcde00006400056cbf67',
#    'displayName': 'Notepads Your Way',
#    'identifyingName': 'notepadsyourway.com',
#    'numberOfReviews': 899.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '51f84e7200006400056d1b2b',
#    'displayName': 'CustomButtons.com by Everyone Loves Buttons Inc.®',
#    'identifyingName': 'custombuttons.com',
#    'numberOfReviews': 742.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '556c6a230000ff00057fd723',
#    'displayName': 'Stoney Creek Wine Press',
#    'identifyingName': 'stoneycreekwinepress.com',
#    'numberOfReviews': 710.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '4e94792a00006400051134bf',
#    'displayName': 'USB Memory Direct',
#    'identifyingName': 'www.usbmemorydirect.com',
#    'numberOfReviews': 707.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '599ae9b80000ff0005a9592d',
#    'displayName': 'Logo in 30 Minutes',
#    'identifyingName': 'logoin30minutes.com',
#    'numberOfReviews': 660.0,
#    'stars': 5.0,
#    'trustscore': '9.8'},
#   {'businessUnitId': '5195f6530000640005312ba9',
#    'displayName': 'Websticker',
#    'identifyingName': 'websticker.com',
#    'numberOfReviews': 649.0,
#    'stars': 5.0,
#    'trustscore': '9.8'}],
#  'recentlyReviewedBusinessUnitList': [{'businessUnitId': '4bdcfc30000064000506033c',
#    'displayName': 'National Pen Company US',
#    'identifyingName': 'www.pens.com',
#    'numberOfReviews': 33133.0,
#    'stars': 4.0,
#    'trustscore': '7.6'},
#   {'businessUnitId': '554257880000ff00057f1d7d',
#    'displayName': 'ClearBags',
#    'identifyingName': 'clearbags.com',
#    'numberOfReviews': 13970.0,
#    'stars': 5.0,
#    'trustscore': '9.5'},
#   {'businessUnitId': '5196851b00006400053237a1',
#    'displayName': 'The Bash powered by GigMasters',
#    'identifyingName': 'www.thebash.com',
#    'numberOfReviews': 11130.0,
#    'stars': 5.0,
#    'trustscore': '9.6'},
#   {'businessUnitId': '542d952d00006400057ab096',
#    'displayName': '1&1 IONOS | ionos.com',
#    'identifyingName': 'ionos.com',
#    'numberOfReviews': 10195.0,
#    'stars': 4.0,
#    'trustscore': '7.7'},
#   {'businessUnitId': '5492142600006400057c3af0',
#    'displayName': 'Fivestars',
#    'identifyingName': 'www.fivestars.com',
#    'numberOfReviews': 9000.0,
#    'stars': 5.0,
#    'trustscore': '9.5'},
#   {'businessUnitId': '50b8769100006400051f0dbb',
#    'displayName': 'DoItYourselfLettering.com',
#    'identifyingName': 'doityourselflettering.com',
#    'numberOfReviews': 7866.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '5612efe40000ff0005840baa',
#    'displayName': 'Parts Town',
#    'identifyingName': 'partstown.com',
#    'numberOfReviews': 7242.0,
#    'stars': 4.0,
#    'trustscore': '8.9'},
#   {'businessUnitId': '4be50cdb0000640005091657',
#    'displayName': 'Concordia Supply',
#    'identifyingName': 'www.concordiasupply.com',
#    'numberOfReviews': 6819.0,
#    'stars': 5.0,
#    'trustscore': '9.5'},
#   {'businessUnitId': '55ba62e80000ff0005819be8',
#    'displayName': 'Service Caster',
#    'identifyingName': 'servicecaster.com',
#    'numberOfReviews': 6206.0,
#    'stars': 5.0,
#    'trustscore': '9.7'},
#   {'businessUnitId': '50c8b55800006400051f8262',
#    'displayName': 'Rev.com',
#    'identifyingName': 'www.rev.com',
#    'numberOfReviews': 4906.0,
#    'stars': 5.0,
#    'trustscore': '9.1'},
#   {'businessUnitId': '51b3db64000064000539d4c7',
#    'displayName': 'Nevada Corporate Headquarters, Inc.',
#    'identifyingName': 'nchinc.com',
#    'numberOfReviews': 3335.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '4c9135b300006400050ddd32',
#    'displayName': 'Optimalprint',
#    'identifyingName': 'optimalprint.com',
#    'numberOfReviews': 2862.0,
#    'stars': 5.0,
#    'trustscore': '9.3'},
#   {'businessUnitId': '5485c63c00006400057c0471',
#    'displayName': 'LegacyHeadstones.com',
#    'identifyingName': 'legacyheadstones.com',
#    'numberOfReviews': 2760.0,
#    'stars': 5.0,
#    'trustscore': '9.6'},
#   {'businessUnitId': '4bdc7fea000064000505ccdb',
#    'displayName': 'SiteGround',
#    'identifyingName': 'www.siteground.com',
#    'numberOfReviews': 2456.0,
#    'stars': 5.0,
#    'trustscore': '9.4'},
#   {'businessUnitId': '568ed6f80000ff0005875374',
#    'displayName': 'Inc Authority',
#    'identifyingName': 'www.incauthority.com',
#    'numberOfReviews': 2204.0,
#    'stars': 5.0,
#    'trustscore': '9.7'},
#   {'businessUnitId': '55bf890f0000ff000581bbf1',
#    'displayName': 'SunDoc Filings',
#    'identifyingName': 'sundocumentfilings.com',
#    'numberOfReviews': 1982.0,
#    'stars': 5.0,
#    'trustscore': '9.7'},
#   {'businessUnitId': '553a4ee10000ff00057efb76',
#    'displayName': 'ForeverCar',
#    'identifyingName': 'forevercar.com',
#    'numberOfReviews': 1799.0,
#    'stars': 5.0,
#    'trustscore': '9.7'},
#   {'businessUnitId': '5c12d8d7393a0100015d1c3e',
#    'displayName': 'Scrum.org',
#    'identifyingName': 'scrum.org',
#    'numberOfReviews': 920.0,
#    'stars': 5.0,
#    'trustscore': '9.6'},
#   {'businessUnitId': '51f836c200006400056d0a2b',
#    'displayName': 'TheFlyerLab.com',
#    'identifyingName': 'theflyerlab.com',
#    'numberOfReviews': 803.0,
#    'stars': 5.0,
#    'trustscore': '9.9'},
#   {'businessUnitId': '5babd5306b01ec0001b7740c',
#    'displayName': 'Acoustimac',
#    'identifyingName': 'acoustimac.com',
#    'numberOfReviews': 604.0,
#    'stars': 5.0,
#    'trustscore': '9.4'}],
#  'totalNumberOfFilteredBusinesses': 584,
#  'totalNumberOfRecentlyReviewedBusinesses': 1703,
#  'totalPageNumber': 114}

# %%
params = {'numberofreviews': '0', 
              'page': '1',
              'status': 'collecting', 
              'timeperiod': '0'}

# %%
'&'.join(['{0}={1}'.format(k,v) for (k, v) in params.items()])
# Out:
# 'numberofreviews=0&page=1&status=collecting&timeperiod=0'

# %%
def get_business_urls(category):
    """
    Returns a list of urls for the the businesses in the supllied category.
    """
    params = {'numberofreviews': '0', 
              'page': '1',
              'status': 'collecting', 
              'timeperiod': '0'} #parameters to be used in the request
    url = 'https://www.trustpilot.com/categories/{}/businesses'.format(category)
    business_root_url = 'https://www.trustpilot.com/review/' #root url for business links
    
    try: #Error handling
        response = requests.get(url, params = params)
        response.raise_for_status()
    except requests.exceptions.RequestException as err:
        print(err)
        return None
    
    total_page_number = json.loads(response.text)['totalPageNumber']
    
    business_urls = []
    for i in range(1, total_page_number+1):
        params['page'] = i #change page
        business_unit_list = json.loads(requests.get(url, params = params).text)['filteredBusinessUnitList']
        business_urls += [business_root_url + unit['identifyingName'] 
                          for unit in business_unit_list] #append new urls
        time.sleep(1)

    return business_urls

# %%
get_business_urls('blablakljk')
# Out:
# 500 Server Error: Internal Server Error for url: https://www.trustpilot.com/categories/blablakljk/businesses?numberofreviews=0&page=1&status=collecting&timeperiod=0

# %% [markdown]
# > **Ex. 8.2.5:** Loop through all categories and build the paging links using the above defined function.
#
# > **Ex. 8.2.6:** Randomly pick one of category listing links you have generated, and get the links to the companies listed using the other function defined.
#
# > **Ex. 8.2.7:** Visit one of these links and inspect the **>Network Monitor<** to locate the request that loads the review data. Use the requests module to retrieve this link and unpack the json results to a pandas DataFrame.

# %%
#[Answer to Ex.8.2.5-7]

# %% [markdown]
# Congratulations on coming this far. By now you are almost - still need to figure out how to page the reviews and to find the company ID in the html -, ready to deploy a scraper collecting all reviews on trustpilot.
# If you wanna see just how valuable such data could be visit the follow blogpost: https://blog.openai.com/unsupervised-sentiment-neuron/

# %%
import requests
import os
import time


def ratelimit(duration=0.5):
    "A function that handles the rate of your calls."
    time.sleep(duration)  # sleep one second.



class LogFile:

    def __init__(self, file, mode):
        self.file = file 
        self.mode = mode
        self.f = None

    def __str__(self):
        return f'Logfile {self.file}'

    def __repr__(self):
        return f'Logfile {self.file} in mode {self.mode}'

    def write(self, content):
        with open(self.file, self.mode) as f:
            f.write(content)

    def flush(self):
        # Deprecated
        return 

    def read(self):
        with open(self.file, 'r') as f:
            content = f.read()
        return content



class Connector():
    def __init__(self, 
                 logfile, 
                 overwrite_log=False, 
                 connector_type='requests', 
                 session=False, 
                 path2selenium='', 
                 n_tries=5, 
                 timeout=30
                 ):
        """This Class implements a method for reliable connection to the internet 
            and monitoring. It handles simple errors due to connection problems, and logs 
            a range of information for basic quality assessments

        Keyword arguments:
        logfile -- path to the logfile
        overwrite_log -- bool, defining if logfile should be cleared (rarely the case). 
        connector_type -- use the 'requests' module or the 'selenium'. 
                          Will have different since the selenium webdriver does not have a 
                          similar response object when using the get method, and 
                          monitoring the behavior cannot be automated in the same way.
        session -- requests.session object. For defining custom headers and proxies.
        path2selenium -- str, sets the path to the geckodriver needed when using selenium.
        n_tries -- int, defines the number of retries the *get* method will try to avoid 
                   random connection errors.
        timeout -- int, seconds the get request will wait for the server to respond, 
                   again to avoid connection errors.
        """

        # Initialization function defining parameters.
        # For avoiding triviel error e.g. connection errors, this defines how many times it will retry.
        self.n_tries = n_tries
        # Defining the maximum time to wait for a server to response.
        self.timeout = timeout
        # not implemented here, if you use selenium.
        if connector_type == 'selenium':
            assert path2selenium != '', "You need to specify the path to you geckodriver if you want to use Selenium"
            from selenium import webdriver
            # HIN download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases

            assert os.path.isfile(
                path2selenium), 'You need to insert a valid path2selenium the path to your geckodriver. You can download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases'
            # start the browser with a path to the geckodriver.
            self.browser = webdriver.Firefox(executable_path=path2selenium)

        self.connector_type = connector_type  # set the connector_type

        if session:  # set the custom session
            self.session = session
        else:
            self.session = requests.session()
        self.logfilename = logfile  # set the logfile path
        # define header for the logfile
        header = ['id', 'project', 'connector_type', 't', 'delta_t', 'url',
                  'redirect_url', 'response_size', 'response_code', 'success', 'error']

        if os.path.isfile(logfile):
            if overwrite_log == True:
                self.log = LogFile(logfile, 'w')
                self.log.write(';'.join(header))
                self.log.mode = 'a'
            else:
                self.log = LogFile(logfile, 'a')
        else:
            self.log = LogFile(logfile, 'w')
            self.log.write(';'.join(header))

        # load log
        l = self.log.read().split('\n')
        if len(l) <= 1:
            self.id = 0
        else:
            self.id = int(l[-1][0])+1

        # with open(logfile, 'r') as f:  # open file

        #     l = f.read().split('\n')  # read and split file by newlines.
        #     # set id
        #     if len(l) <= 1:
        #         self.id = 0
        #     else:
        #         self.id = int(l[-1][0])+1

    def get(self, url, project_name, params = None):
        """Method for connector reliably to the internet, with multiple tries and simple 
            error handling, as well as default logging function.
        Input url and the project name for the log (i.e. is it part of mapping the domain, 
        or is it the part of the final stage in the data collection).

        Keyword arguments:
        url -- str, url
        project_name -- str, Name used for analyzing the log. Use case could be the 
                            'Mapping of domain','Meta_data_collection','main data collection'. 
        params -- dict, Mapping of parameters to be used in the url.
        """

        # make sure the default csv seperator is not in the project_name.
        project_name = project_name.replace(';', '-')
        if self.connector_type == 'requests':  # Determine connector method.
            # for loop defining number of retries with the requests method.
            for _ in range(self.n_tries):
                ratelimit()
                t = time.time()
                try:  # error handling
                    response = self.session.get(
                        url, params = params, timeout=self.timeout)  # make get call

                    # define python error variable as empty assumming success.
                    err = ''
                    success = True  # define success variable
                    redirect_url = response.url  # log current url, after potential redirects
                    # define delta-time waiting for the server and downloading content.
                    dt = t - time.time()
                    # define variable for size of html content of the response.
                    size = len(response.text)
                    response_code = response.status_code  # log status code.
                    # log...
                    call_id = self.id  # get current unique identifier for the call
                    self.id += 1  # increment call id
                    #['id','project_name','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
                    # define row to be written in the log.
                    row = [call_id, project_name, self.connector_type, t, dt,
                           url, redirect_url, size, response_code, success, err]
                    self.log.write('\n'+';'.join(map(str, row)))  # write log.
                    self.log.flush()
                    # return response and unique identifier.
                    return response, call_id

                except Exception as e:  # define error condition
                    err = str(e)  # python error
                    response_code = ''  # blank response code
                    success = False  # call success = False
                    size = 0  # content is empty.
                    redirect_url = ''  # redirect url empty
                    dt = t - time.time()  # define delta t

                    # log...
                    call_id = self.id  # define unique identifier
                    self.id += 1  # increment call_id

                    row = [call_id, project_name, self.connector_type, t, dt, url,
                           redirect_url, size, response_code, success, err]  # define row
                    # write row to log.
                    self.log.write('\n'+';'.join(map(str, row)))
                    self.log.flush()
        else:
            t = time.time()
            ratelimit()
            url = url +'?{}'.format('&'.join(['{0}={1}'.format(k,v) for (k, v) in params.items()]))
            self.browser.get(url)  # use selenium get method
            # log
            call_id = self.id  # define unique identifier for the call.
            self.id += 1  # increment the call_id
            err = ''  # blank error message
            success = ''  # success blank
            redirect_url = self.browser.current_url  # redirect url.
            # get time for get method ... NOTE: not necessarily the complete load time.
            dt = t - time.time()
            # get size of content ... NOTE: not necessarily correct, since selenium works in the background, and could still be loading.
            size = len(self.browser.page_source)
            response_code = ''  # empty response code.
            row = [call_id, project_name, self.connector_type, t, dt, url,
                   redirect_url, size, response_code, success, err]  # define row
            # write row to log file.
            self.log.write('\n'+';'.join(map(str, row)))
            self.log.flush()
        # Using selenium it will not return a response object, instead you should call the browser object of the connector.
        # connector.browser.page_source will give you the html.
            return None, call_id

# %%
connector = Connector('logfile.txt')
params = {'numberofreviews': '0', 
          'page': '1',
          'status': 'collecting', 
          'timeperiod': '0'} #parameters to be used in the request
url = 'https://www.trustpilot.com/categories/pet_store/businesses'
response, id = connector.get(url, 'Test project', params = params)

# %%
response.url
# Out:
# 'https://www.trustpilot.com/categories/pet_store/businesses?numberofreviews=0&page=1&status=collecting&timeperiod=0'

# %%
import urllib
#from urllib.parse import urlparse
#scheme://netloc/path;parameters?query#fragment
result = urllib.parse.urlparse('https://www.trustpilot.com/categories/pet_store/businesses')
#'{0}://{1}/{2};{3}?{4}#{5}' % result
result
# Out:
# ParseResult(scheme='https', netloc='www.trustpilot.com', path='/categories/pet_store/businesses', params='', query='', fragment='')
