# %%
import requests

# %%
params = {'token': 1234, 'api_key': '6BiXLxtymFfWHRZPeOWuyGaczU1N42Dp', 'token_ttl': 1000}
response = requests.post('https://api.etilbudsavis.dk/v2/sessions', params = params)
response
# Out:
# <Response [400]>

# %%
response.text
# Out:
# '{"code":1102,"id":"00jzjdpy7yhdseelgm9b23dir5icr41j","message":"Invalid api key","details":"Invalid API key.\\nCould not find app matching your api key.","previous":null,"@note.1":"Hey! It looks like you found an error. If you have any questions about this error, feel free to contact support with the above error id."}'

# %%
params = {'Content-Type': 'application/json',
'Accept': 'application/json'}
response = requests.post('https://api.etilbudsavis.dk/v2/sessions', params = params)
response
# Out:
# <Response [400]>

# %%
response.text
# Out:
# '{"code":1400,"id":"00jzjdopysluw1awu0gcd864tuirx6me","message":"missing api_key","details":"Request invalid due to missing information.","previous":null,"@note.1":"Hey! It looks like you found an error. If you have any questions about this error, feel free to contact support with the above error id."}'

# %%
response = requests.get('https://accounts.spotify.com/authorize?client_id=99a1524d00784f5f8c6b8c05e098f6aa&response_type=code')
response
# Out:
# <Response [200]>

# %% [markdown]
# https://github.com/sebastianbaltser/sds2019/compare/master...abjer:master

# %%
response = requests.get('https://apps-infomedia-dk.esc-web.lib.cbs.dk:8443/mediearkiv/search/basicsearch?username=seba17ab&password=CanadaCBS1080')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <title>CBS Single Sign On</title>\n  <link rel=\'stylesheet\' href="https://cas.cbs.dk/saml/module.php/cbs/css/cbs.css" type=\'text/css\' />\n    <link rel="stylesheet" href=" https://cas.cbs.dk/saml/module.php/cbs/css/bootstrap.min.css" type="text/css" />\n  <link rel="stylesheet" href=" https://cas.cbs.dk/saml/module.php/cbs/css/bootstrap-theme.min.css" type="text/css" />\n\n  <!-- START: forgot password box -->\n  <link rel=\'stylesheet\' href="https://cas.cbs.dk/saml/module.php/cbs/css/colorbox.css" type=\'text/css\' />\n  <script type="text/javascript" src="https://cas.cbs.dk/saml/module.php/cbs/js/jquery-1.11.3.min.js" ></script>\n  <script type="text/javascript" src="https://cas.cbs.dk/saml/module.php/cbs/js/jquery.colorbox-min.js" ></script>\n  <script type="text/javas
# ...

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <title>CBS Single Sign On</title>\n  <link rel=\'stylesheet\' href="https://cas.cbs.dk/saml/module.php/cbs/css/cbs.css" type=\'text/css\' />\n    <link rel="stylesheet" href=" https://cas.cbs.dk/saml/module.php/cbs/css/bootstrap.min.css" type="text/css" />\n  <link rel="stylesheet" href=" https://cas.cbs.dk/saml/module.php/cbs/css/bootstrap-theme.min.css" type="text/css" />\n\n  <!-- START: forgot password box -->\n  <link rel=\'stylesheet\' href="https://cas.cbs.dk/saml/module.php/cbs/css/colorbox.css" type=\'text/css\' />\n  <script type="text/javascript" src="https://cas.cbs.dk/saml/module.php/cbs/js/jquery-1.11.3.min.js" ></script>\n  <script type="text/javascript" src="https://cas.cbs.dk/saml/module.php/cbs/js/jquery.colorbox-min.js" ></script>\n  <script type="text/javas
# ...

# %%
import pandas as pd
import numpy as np
columns = ['Date', 'Count']
df = pd.read_csv('/Users/sebastianbaltser/Desktop/CycleHistoricalReport20190820_2335.csv', 
                 header = 8, 
                 sep = ';', parse_dates = [[0, 1]])
df.columns = columns
df['Date'] = pd.to_datetime(df['Date'], dayfirst = True)
df.set_index('Date', inplace = True)
df = df.reindex(pd.date_range('2016-01-01', '2017-12-31'), fill_value = np.nan)

# %%
df['Count'].isnull().sum()
# Out:
# 108

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (15, 4))
ax.plot(df, '-o')

plt.show()

# %%
import requests, json, pprint
from bs4 import BeautifulSoup
response = requests.get('https://www.dailymail.co.uk/home/search.html?offset=0&size=50&sel=site&searchPhrase=migration&sort=recent&type=article&type=video&type=permabox&days=all')
soup = BeautifulSoup(response.text, features = 'lxml')
response.text
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "//www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd"><html lang="en" xml:lang="en" xmlns:fb="//www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/" xmlns="//www.w3.org/1999/xhtml"><head><!--class fe.views.page_modules.Head-->\n<!--class fe.views.head_modules.DefineAdvertsProperty-->\n<script type="text/javascript">\ntry {\n  Object.defineProperty(window, \'adverts\', {configurable: false, value:{}});\n}\ncatch(error) {\n  console.error(error);\n}\n</script>\n<!--class fe.views.head_modules.Favicon-->\n<link href="/favicon.ico?v=2" rel="icon" />\n<!--class fe.views.head_modules.Title-->\n<title>migration | Search Results | Daily Mail Online | Daily Mail Online</title>\n<!--class fe.views.preload.Preload-->\n<link href=\'//swa.and.co.uk\' rel=\'dns-prefetch\'>\n<link href=\'//i.dailymail.co.uk\' rel=\'dns-prefetch\'>\n<link href=\'//video.dailymail.co.uk\' rel=\'dns-prefetch\'>\n<link href=\'//script
# ...

# %%
response = requests.get("https://www.dailymail.co.uk/news/article-7377155/Criminal-grandfather-fought-Australia-World-War-II-deported-Papua-New-Guinea.html")
try:
    response.raise_for_status()
except:
    print('Connection error')
soup = BeautifulSoup(response.text, features='lxml')
body_div = soup.find('div', attrs = {'id': 'js-article-text'})
#article_tags = [h3.find('a')['href'] for h3 in article_tags]

# %%
pd.Series(article_tags).to_csv('test.csv', header = False)

# %%
from scraping_class import Connector

# %%
article_tags.find('h2') #title
article_tags.find('span', attrs = {'class': 'article-timestamp article-timestamp-published'}).text #date
' '.join(p.text for p in article_tags.find('div', attrs = {'itemprop': 'articleBody'}).findAll('p')) #body
#soup.find('meta', attrs = {'name': 'articleid'})['content'] #article ID
# Out:
# "A criminal who has lived in Australia since he was three years old is being deported to Papua New Guinea under strict immigration laws. Gus Kuster, 40, has been in and out of Australian jails for most of his adult life for drug and driving offences and was finally ready to walk free. But Mr Kuster is being forced to leave his family behind and move to Port Moresby in Papua New Guinea where he will be forced to start his life over alone. Australian officials escorted the 40-year-old to Brisbane airport on Wednesday where he is set to board a one-way flight to Port Moresby and given two weeks accommodation and $250. Gus Kuster, 40, has been in and out of Australian prison for most of his adult life for drug and driving offences and was finally ready to walk free But Mr Kuster is being forced to leave his family behind and move to Port Moresby in Papua New Guinea where he will be forced to start his life over alone (pictured with his mother) Mr Kuster was born to an Australian father, 
# ...

# %%
URL = 'https://www.dailymail.co.uk/reader-comments/p/asset/readcomments/7377155?max=10&sort=voteRating&order=desc&rcCache=shout'

# %%
response = requests.get("https://www.thesun.co.uk/topic/uk-immigration-crisis/")
try:
    response.raise_for_status()
except:
    print('Connection error')
soup = BeautifulSoup(response.text, features='lxml')
soup.findAll('a', )

# %%
rng = range(5)
pd.DataFrame({'rng': rng, 'x': 'hej'})
# Out:
#    rng    x
# 0    0  hej
# 1    1  hej
# 2    2  hej
# 3    3  hej
# 4    4  hej

# %%
dict1 = {'1': 'f', '2': 'g', '3': 'h'}
dict2 = {'3': 'æ'}
pd.DataFrame([dict1, dict2])
# Out:
#      1    2  3
# 0    f    g  h
# 1  NaN  NaN  æ

# %%
files = [('/Users/sebastianbaltser/Documents/GitHub/SDS/Eksamen/Migration/dr_log.csv', 0), ('/Users/sebastianbaltser/Documents/GitHub/SDS/Eksamen/Migration/dr_log2.csv', None)]
#pd.read_csv(files[1], header = None, sep = ';)
df = pd.concat([pd.read_csv(f, header = h) for f, h in files], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-11-60e821f31591> in <module>()
#       1 files = [('/Users/sebastianbaltser/Documents/GitHub/SDS/Eksamen/Migration/dr_log.csv', 0), ('/Users/sebastianbaltser/Documents/GitHub/SDS/Eksamen/Migration/dr_log2.csv', None)]
#       2 #pd.read_csv(files[1], header = None, sep = ';)
# ----> 3 df = pd.concat([pd.read_csv(f, header = h) for f, h in files], axis = 0)
#
# <ipython-input-11-60e821f31591> in <listcomp>(.0)
#       1 files = [('/Users/sebastianbaltser/Documents/GitHub/SDS/Eksamen/Migration/dr_log.csv', 0), ('/Users/sebastianbaltser/Documents/GitHub/SDS/Eksamen/Migration/dr_log2.csv', None)]
#       2 #pd.read_csv(files[1], header = None, sep = ';)
# ----> 3 df = pd.concat([pd.read_csv(f, header = h) for f, h in files], axis = 0)
#
# ...

# %%
df
# Out:
#            0               1         2             3         4  \
# 0        NaN             NaN       NaN           NaN       NaN
# 1        NaN             NaN       NaN           NaN       NaN
# 2        NaN             NaN       NaN           NaN       NaN
# 3        NaN             NaN       NaN           NaN       NaN
# 4        NaN             NaN       NaN           NaN       NaN
# 5        NaN             NaN       NaN           NaN       NaN
# 6        NaN             NaN       NaN           NaN       NaN
# 7        NaN             NaN       NaN           NaN       NaN
# 8        NaN             NaN       NaN           NaN       NaN
# 9        NaN             NaN       NaN           NaN       NaN
# 10       NaN             NaN       NaN           NaN       NaN
# 11       NaN             NaN       NaN           NaN       NaN
# 12       NaN             NaN       NaN           NaN       NaN
# 13       NaN             NaN       NaN           NaN       NaN
# ...
