# %%
#Import Packages

import csv 
import numpy as np
import pandas as pd
import string as stringmodule
import lemmy
import collections
from unicodedata import normalize
import re
import matplotlib.pyplot as plt
import collections
import seaborn as sns

# %%
def lemmatize_strings(body_text, language = 'da'):
    """Function to lemmatize a string or a list of strings, i.e. remove prefixes. Also removes punctuations.
    
    -- body_text: string or list of strings
    -- language: language of the passed string(s), e.g. 'en', 'da' etc.
    """
    
    if isinstance(body_text, str):
        body_text = [body_text] #Convert whatever passed to a list to support passing of single string
    
    if not hasattr(body_text, '__iter__'):
        raise TypeError('Passed argument should be a sequence.')
    
    lemmatizer = lemmy.load(language) #load lemmatizing dictionary
    
    lemma_list = [] #list to store each lemmatized string 

    word_regex = re.compile('[a-zA-Z0-9æøåÆØÅ]+') #All charachters and digits i.e. all possible words

    for string in body_text:
        #remove punctuation and split words
        matches = word_regex.findall(string)

        #split words and lowercase them unless they are all caps
        lemmatized_string = [word.lower() if not word.isupper() else word for word in matches]

        #lemmatize each word and choose the shortest word of suggested lemmatizations
        lemmatized_string = [min(lemmatizer.lemmatize('', word), key=len) for word in lemmatized_string]

        lemma_list.append(' '.join(lemmatized_string))

    return lemma_list if len(lemma_list) > 1 else lemma_list[0] #return list if list was passed, else return string

# %%
article_data = pd.read_csv('./dr_frequent_articles.csv', header = 0)

# %%
string = lemmatize_strings(' '.join(article_data['Text']).split(' '))

# %% [markdown]
# **Refugee Modifiers**

# %%
dictionary = ['flygtning']
flygtningmodifier = []
for word in dictionary:
    stop = False
    while not stop:
        try:
            idx = string.index(word)
            flygtningmodifier.append(tuple(string[idx-1:idx]))
            string = string[idx+1:]
        except:
            stop = True
            
            
flygtningmodifier
# Out:
# [('med',),
#  ('af',),
#  ('af',),
#  ('afrikansk',),
#  ('pak',),
#  ('afrikansk',),
#  ('300',),
#  ('med',),
#  ('af',),
#  ('hjælpe',),
#  ('som',),
#  ('illegal',),
#  ('15 000',),
#  ('hundred',),
#  ('nordafrikansk',),
#  ('at',),
#  ('af',),
#  ('6700',),
#  ('15 000',),
#  ('afvise',),
#  ('til',),
#  ('mange',),
#  ('modsat',),
#  ('se',),
#  ('at',),
#  ('flest',),
#  ('en',),
#  ('få',),
#  ('holde',),
#  ('af',),
#  ('blive',),
#  ('af',),
#  ('europa',),
#  ('af',),
#  ('flere',),
#  ('være',),
#  ('500',),
#  ('for',),
#  ('strømme',),
#  ('flere',),
#  ('5 000',),
#  ('som',),
#  ('at',),
#  ('ville',),
#  ('500',),
#  ('for',),
#  ('bosnisk',),
#  ('million',),
#  ('båd',),
#  ('af',),
#  ('flest',),
#  ('om',),
#  ('at',),
#  ('syrisk',),
#  ('af',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('med',),
#  ('af',),
#  ('sige',),
#  ('flere',),
#  ('afghansk',),
#  ('en',),
#  ('afghansk',),
#  ('afghansk',),
#  ('illegal',),
#  ('afghansk',),
#  ('en',),
#  ('afghansk',),
#  ('afghansk',),
#  ('illegal',),
#  ('afghansk',),
#  ('en',),
#  ('en',),
#  ('afghansk',),
#  ('illegal',),
#  ('afghansk',),
#  ('blive',),
#  ('illegal',),
#  ('danmark',),
#  ('sende',),
#  ('20',),
#  ('give',),
#  ('med',),
#  ('syrisk',),
#  ('af',),
#  ('syrisk',),
#  ('rigtig',),
#  ('af',),
#  ('afghansk',),
#  ('finde',),
#  ('mange',),
#  ('at',),
#  ('som',),
#  ('af',),
#  ('af',),
#  ('mange',),
#  ('af',),
#  ('tusind',),
#  ('se',),
#  ('syrisk',),
#  ('bosnisk',),
#  ('somalisk',),
#  ('mange',),
#  ('hus',),
#  ('blive',),
#  ('immigrationscenter',),
#  ('land',),
#  ('200',),
#  ('for',),
#  ('de',),
#  ('mange',),
#  ('forhindre',),
#  ('tilbyde',),
#  ('dyr',),
#  ('af',),
#  ('at',),
#  ('syrisk',),
#  ('syrisk',),
#  ('til',),
#  ('producere',),
#  ('end',),
#  ('tvinge',),
#  ('hvis',),
#  ('komme',),
#  ('syrisk',),
#  ('skubbe',),
#  ('syrisk',),
#  ('være',),
#  ('overnatte',),
#  ('grækenland',),
#  ('mange',),
#  ('de',),
#  ('af',),
#  ('og',),
#  ('anerkende',),
#  ('ikke',),
#  ('at',),
#  ('anerkende',),
#  ('og',),
#  ('desperat',),
#  ('af',),
#  ('i',),
#  ('syrisk',),
#  ('hvor',),
#  ('mange',),
#  ('ung',),
#  ('afghansk',),
#  ('som',),
#  ('give',),
#  ('hvor',),
#  ('de',),
#  ('sende',),
#  ('flere',),
#  ('imod',),
#  ('som',),
#  ('af',),
#  ('og',),
#  ('tilbageholde',),
#  ('mod',),
#  ('holde',),
#  ('1014',),
#  ('hovedsagelig',),
#  ('flest',),
#  ('fra',),
#  ('løsning',),
#  ('mange',),
#  ('af',),
#  ('ny',),
#  ('million',),
#  ('syrisk',),
#  ('verden',),
#  ('fjerde',),
#  ('3819',),
#  ('alverden',),
#  ('uledsaget',),
#  ('de',),
#  ('ulovlig',),
#  ('ignorere',),
#  ('flere',),
#  ('være',),
#  ('antal',),
#  ('flere',),
#  ('mange',),
#  ('de',),
#  ('syrisk',),
#  ('syrisk',),
#  ('hjælpe',),
#  ('syrisk',),
#  ('syrisk',),
#  ('holde',),
#  ('men',),
#  ('syrisk',),
#  ('af',),
#  ('syrien',),
#  ('69',),
#  ('48',),
#  ('sende',),
#  ('alverden',),
#  ('de',),
#  ('million',),
#  ('tage',),
#  ('ramme',),
#  ('hjælpe',),
#  ('afrikansk',),
#  ('tusind',),
#  ('samle',),
#  ('13',),
#  ('30 000',),
#  ('af',),
#  ('somalisk',),
#  ('få',),
#  ('verden',),
#  ('de',),
#  ('fordrive',),
#  ('disse',),
#  ('de',),
#  ('flest',),
#  ('5 000',),
#  ('fordele',),
#  ('nordafrikansk',),
#  ('2000',),
#  ('60 000',),
#  ('som',),
#  ('skibbruden',),
#  ('320',),
#  ('anden',),
#  ('imod',),
#  ('hus',),
#  ('illegal',),
#  ('af',),
#  ('af',),
#  ('luchte',),
#  ('syrisk',),
#  ('efter',),
#  ('om',),
#  ('syrisk',),
#  ('syrisk',),
#  ('300',),
#  ('ville',),
#  ('300',),
#  ('anholde',),
#  ('af',),
#  ('80 000',),
#  ('afrikansk',),
#  ('at',),
#  ('dø',),
#  ('tusind',),
#  ('samle',),
#  ('13',),
#  ('område',),
#  ('nødhjælp',),
#  ('flest',),
#  ('libysk',),
#  ('imod',),
#  ('antal',),
#  ('jødisk',),
#  ('og',),
#  ('ny',),
#  ('ny',),
#  ('ny',),
#  ('af',),
#  ('mange',),
#  ('enkelt',),
#  ('aalborg',),
#  (),
#  ('af',),
#  ('fordele',),
#  ('syrisk',),
#  ('8 000',),
#  ('syrisk',),
#  ('50 000',),
#  ('fjerne',),
#  ('af',),
#  ('følge',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('',),
#  ('af',),
#  ('hundred',),
#  ('syrisk',),
#  ('syrisk',),
#  ('330',),
#  ('aalborg',),
#  ('enkelt',),
#  ('aalborg',),
#  ('fordele',),
#  ('fordel',),
#  ('enkelt',),
#  ('fordel',),
#  ('ekstra',),
#  ('af',),
#  ('og',),
#  ('kunne',),
#  ('',),
#  ('mange',),
#  ('af',),
#  ('fordi',),
#  ('somalisk',),
#  ('enkelt',),
#  ('på',),
#  ('for',),
#  ('12 000',),
#  ('fordrive',),
#  ('de',),
#  ('for',),
#  ('mange',),
#  ('enkelt',),
#  ('af',),
#  ('de',),
#  ('til',),
#  ('80 000',),
#  ('jordan',),
#  ('hjælpe',),
#  ('flere',),
#  ('hjælpe',),
#  ('hjemland for',),
#  ('syrisk',),
#  ('smugle',),
#  ('at',),
#  ('syrisk',),
#  ('udlændingemyndighed',),
#  ('syrisk',),
#  ('million',),
#  ('al',),
#  ('mange',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('med',),
#  ('fragte',),
#  ('syrisk',),
#  ('som',),
#  ('syrisk',),
#  ('af',),
#  ('antal',),
#  ('af',),
#  ('BBC',),
#  ('af',),
#  ('gøre',),
#  ('syrisk',),
#  ('af',),
#  ('38',),
#  ('anden',),
#  ('med',),
#  ('332',),
#  ('af',),
#  ('syrisk',),
#  ('fordrive',),
#  ('som',),
#  ('flest',),
#  ('syrisk',),
#  ('for',),
#  ('somalisk',),
#  ('sødygtig',),
#  ('syrisk',),
#  ('syrisk',),
#  ('mange',),
#  ('at',),
#  ('udsat',),
#  ('drik',),
#  ('verden',),
#  ('for',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrien',),
#  ('som',),
#  ('af',),
#  ('at',),
#  ('en',),
#  ('til',),
#  ('tildele',),
#  ('af',),
#  ('syrisk',),
#  ('femte',),
#  ('femte',),
#  ('være',),
#  ('år',),
#  ('al',),
#  ('modtage',),
#  ('henriksen',),
#  ('leve',),
#  ('for',),
#  ('som',),
#  ('mulig',),
#  ('per',),
#  ('lindegård',),
#  ('mange',),
#  ('somalisk',),
#  ('med',),
#  ('modtage',),
#  ('flere',),
#  ('242 000',),
#  ('mange',),
#  ('papirløs',),
#  ('hvilken',),
#  ('for',),
#  ('5000',),
#  ('syrisk',),
#  ('til',),
#  ('antal',),
#  ('forhindre',),
#  ('give',),
#  ('1000',),
#  ('syrisk',),
#  ('nord',),
#  ('flere',),
#  ('af',),
#  ('såre',),
#  ('se',),
#  ('syrisk',),
#  ('syrisk',),
#  ('til',),
#  ('antal',),
#  ('af',),
#  ('og',),
#  ('mode',),
#  ('verden',),
#  ('antal',),
#  ('flest',),
#  ('fjerde',),
#  ('af',),
#  ('mange',),
#  ('370',),
#  ('253',),
#  ('mange',),
#  ('mange',),
#  ('udsat',),
#  ('at',),
#  ('syrisk',),
#  ('mange',),
#  ('afrikansk',),
#  ('syrisk',),
#  ('af',),
#  ('og',),
#  ('syrisk',),
#  ('2850',),
#  ('være',),
#  ('til',),
#  ('at',),
#  ('give',),
#  ('af',),
#  ('af',),
#  ('fordrive',),
#  ('flest',),
#  ('flere',),
#  ('af',),
#  ('antal',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('til',),
#  ('hvor',),
#  ('million',),
#  ('mange',),
#  ('af',),
#  ('hvor',),
#  ('at',),
#  ('600',),
#  ('til',),
#  ('180 000',),
#  ('de',),
#  ('støtte',),
#  ('antal',),
#  ('voksen',),
#  ('mange',),
#  ('fra',),
#  ('give',),
#  ('mange',),
#  ('give',),
#  ('navngive',),
#  ('af',),
#  ('251 000',),
#  ('million',),
#  ('51 000',),
#  ('nyankomme',),
#  ('nyankomme',),
#  ('imod',),
#  ('at',),
#  ('hjælpe',),
#  ('omfordele',),
#  ('mod',),
#  ('anerkende',),
#  ('ramme',),
#  ('syrisk',),
#  ('antal',),
#  ('',),
#  ('til',),
#  ('fordel',),
#  ('syrisk',),
#  ('på',),
#  ('48',),
#  ('irakisk',),
#  ('også',),
#  ('være',),
#  ('en',),
#  ('at',),
#  ('for',),
#  ('300',),
#  ('for',),
#  ('flere',),
#  ('hjælpe',),
#  ('som',),
#  ('imod',),
#  ('illegal',),
#  ('disse',),
#  ('syrisk',),
#  ('af',),
#  ('afrikansk',),
#  ('af',),
#  ('226',),
#  ('af',),
#  ('100',),
#  ('750',),
#  ('give',),
#  ('tunesisk',),
#  ('af',),
#  ('flere',),
#  ('af',),
#  ('2500',),
#  ('af',),
#  ('flest',),
#  ('flere',),
#  ('få',),
#  ('1400',),
#  ('ritzau',),
#  ('for',),
#  ('være',),
#  ('som',),
#  ('traumatisere',),
#  ('de',),
#  ('1300',),
#  ('mange',),
#  ('35 000',),
#  ('mange',),
#  ('med',),
#  ('udgøre',),
#  ('flyve',),
#  ('flere',),
#  ('hvor',),
#  ('de',),
#  ('de',),
#  ('hvor',),
#  ('libysk',),
#  ('tunesien',),
#  ('libysk',),
#  ('af',),
#  ('fordel',),
#  ('følge',),
#  ('fordele',),
#  ('ny',),
#  ('for',),
#  ('gruppe',),
#  ('nå',),
#  ('behandle',),
#  ('af',),
#  ('om',),
#  ('mange',),
#  ('af',),
#  ('million',),
#  ('at',),
#  ('lejr',),
#  ('400',),
#  ('syrisk',),
#  ('af',),
#  ('antal',),
#  ('million',),
#  ('hjælpe',),
#  ('mange',),
#  ('syrisk',),
#  ('100 000',),
#  ('for',),
#  ('for',),
#  ('syrisk',),
#  ('flere',),
#  ('613',),
#  ('hjemvendt',),
#  ('en',),
#  ('en',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('som',),
#  ('som',),
#  ('syrisk',),
#  ('som',),
#  ('palæstinensisk',),
#  ('af',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('gruppe',),
#  ('90 000',),
#  ('af',),
#  ('al',),
#  ('imod',),
#  ('syrisk',),
#  ('25 000',),
#  ('af',),
#  ('syrisk',),
#  ('gillard',),
#  ('af',),
#  ('200',),
#  ('med',),
#  ('var',),
#  ('afghansk',),
#  ('kabul',),
#  ('hvor',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('har',),
#  ('flere',),
#  ('nyhed',),
#  ('al',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('30 000',),
#  ('lad',),
#  ('se',),
#  ('af',),
#  ('mange',),
#  ('komme',),
#  ('100',),
#  ('4484',),
#  ('250',),
#  ('nu',),
#  ('35 000',),
#  ('ny',),
#  ('være',),
#  ('af',),
#  ('mange',),
#  ('med',),
#  ('nå',),
#  ('med',),
#  ('gruppe',),
#  ('hjælpe',),
#  ('ny',),
#  ('og',),
#  ('anvise',),
#  ('med',),
#  ('af',),
#  ('1041',),
#  ('1820',),
#  ('syrisk',),
#  ('10 000',),
#  ('opfordre',),
#  ('af',),
#  ('tysk',),
#  ('tysk',),
#  ('tysk',),
#  ('al',),
#  ('tysk',),
#  ('mange',),
#  ('fordel',),
#  ('at',),
#  ('for',),
#  ('tamilsk',),
#  ('blandt',),
#  (),
#  ('blive',),
#  ('undersøge',),
#  ('tusind',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('har',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('31 000',),
#  ('hvor',),
#  ('risikere',),
#  ('ungarsk',),
#  ('chilensk',),
#  ('bosnisk',),
#  ('mange',),
#  ('således',),
#  ('for',),
#  ('de',),
#  ('øvrig',),
#  ('til',),
#  ('nødhjælp',),
#  ('12',),
#  ('300',),
#  ('lampedusa',),
#  ('300',),
#  ('for',),
#  ('32 000',),
#  ('af',),
#  ('illegal',),
#  ('bringe',),
#  ('komme',),
#  ('nyankomme',),
#  ('nyankomme',),
#  ('nyankomme',),
#  ('for',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('af',),
#  ('tvinge',),
#  ('af',),
#  ('syrisk',),
#  ('mange',),
#  ('4445',),
#  ('6445',),
#  ('mange',),
#  ('syrisk',),
#  ('20 000',),
#  ('antal',),
#  ('til',),
#  ('nå',),
#  ('syrisk',),
#  ('at',),
#  ('syrisk',),
#  ('for',),
#  ('af',),
#  ('af',),
#  ('antal',),
#  ('syrisk',),
#  ('300',),
#  ('mange',),
#  ('300',),
#  ('mange',),
#  ('af',),
#  ('af',),
#  ('mange',),
#  ('syrisk',),
#  ('tusind',),
#  ('irakisk',),
#  ('som',),
#  ('til',),
#  ('som',),
#  ('syrisk',),
#  ('ny',),
#  ('syrisk',),
#  ('',),
#  ('kyse',),
#  ('afrikansk',),
#  ('300',),
#  ('for',),
#  ('som',),
#  ('som',),
#  ('af',),
#  ('sikkerhed',),
#  ('være',),
#  ('påvirke',),
#  ('million',),
#  ('mange',),
#  ('som',),
#  ('mange',),
#  ('at',),
#  ('syrisk',),
#  ('syrisk',),
#  ('mishandle',),
#  ('syrisk',),
#  ('en',),
#  ('300',),
#  ('da',),
#  ('4500',),
#  ('for',),
#  ('af',),
#  ('syrisk',),
#  ('syrisk',),
#  ('flere',),
#  ('syrisk',),
#  ('for',),
#  ('på',),
#  ('omfatte',),
#  ('anden',),
#  ('flest',),
#  ('økonomisk',),
#  ('en',),
#  ('være',),
#  ('3 500',),
#  ('12',),
#  ('300',),
#  ('lampedusa',),
#  ('300',),
#  ('af',),
#  ('million',),
#  ('mange',),
#  ('men',),
#  ('liv',),
#  ('man',),
#  ('afghansk',),
#  ('af',),
#  ('hjemvendende',),
#  ('million',),
#  ('hjemvendt',),
#  ('hjemvendt',),
#  ('af',),
#  ('fordrive',),
#  ('fordrive',),
#  ('fordrive',),
#  ('af',),
#  ('af',),
#  ('flytte',),
#  ('mange',),
#  ('interviewe',),
#  ('fordel',),
#  ('af',),
#  ('af',),
#  ('asylsøgende',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('mange',),
#  ('2 850',),
#  ('2 447',),
#  ('være',),
#  ('mod',),
#  ('hjælpe',),
#  ('være',),
#  ('var',),
#  ('til',),
#  ('100 000',),
#  ('til',),
#  ('af',),
#  ('af',),
#  ('berøre',),
#  ('for',),
#  ('syrisk',),
#  ('af',),
#  ('mange',),
#  ('nordafrikansk',),
#  ('om',),
#  ('de',),
#  ('strande',),
#  ('som',),
#  ('om',),
#  ('om',),
#  ('at',),
#  ('flere',),
#  ('verden',),
#  ('hjælpe',),
#  ('500',),
#  ('den',),
#  ('af',),
#  ('kystvagt',),
#  ('af',),
#  ('syrisk',),
#  ('syrisk',),
#  ('mange',),
#  ('af',),
#  ('syrisk',),
#  ('huse',),
#  ('har',),
#  ('ritzau AFP',),
#  ('med',),
#  ('flere',),
#  ('med',),
#  ('af',),
#  ('syrisk',),
#  ('slem',),
#  ('for',),
#  ('for',),
#  ('5000',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('at',),
#  ('malisk',),
#  ('anden',),
#  ('mange',),
#  ('mange',),
#  ('i',),
#  ('med',),
#  ('100',),
#  ('4484',),
#  ('250',),
#  ('af',),
#  ('mange',),
#  ('og',),
#  ('mod',),
#  ('sne',),
#  ('syrisk',),
#  ('300 000',),
#  ('af',),
#  ('til',),
#  ('som',),
#  ('og',),
#  ('af',),
#  ('imod',),
#  ('give',),
#  ('men',),
#  ('antal',),
#  ('til',),
#  ('nordafrikansk',),
#  ('25 50',),
#  ('mange',),
#  ('eller',),
#  ('således',),
#  ('for',),
#  ('herboende',),
#  ('som',),
#  ('at',),
#  ('ny',),
#  ('strømme',),
#  ('20 000',),
#  ('til',),
#  ('flere',),
#  ('fordi',),
#  ('og',),
#  ('afrikansk',),
#  ('af',),
#  ('somalisk',),
#  ('mange',),
#  ('80 000',),
#  ('mange',),
#  ('på',),
#  ('syrisk',),
#  ('med',),
#  ('og',),
#  ('af',),
#  ('at',),
#  ('flå',),
#  ('drukne',),
#  ('libysk',),
#  ('af',),
#  ('som',),
#  ('million',),
#  ('komit en',),
#  ('komit en',),
#  ('230 000',),
#  ('515 000',),
#  ('17 600',),
#  ('af',),
#  ('syrisk',),
#  ('syrisk',),
#  ('som',),
#  ('tilsvarende',),
#  ('til',),
#  ('palæstinensisk',),
#  ('af',),
#  ('til',),
#  ('som',),
#  ('og',),
#  ('mange',),
#  ('verden',),
#  ('af',),
#  ('30 000',),
#  ('at',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('af',),
#  ('afrikansk',),
#  ('for',),
#  ('organisation',),
#  ('irakisk',),
#  ('udsætte',),
#  ('politisk',),
#  ('på',),
#  ('gælde',),
#  ('en',),
#  ('ny',),
#  ('tunesisk',),
#  ('som',),
#  ('gælde',),
#  ('udsætte',),
#  ('af',),
#  ('komme',),
#  ('mortensen',),
#  ('imod',),
#  ('også',),
#  ('gruppe',),
#  ('de',),
#  ('tydelig',),
#  ('ny',),
#  ('de',),
#  ('for',),
#  ('mange',),
#  ('anden',),
#  ('sluse',),
#  ('hundredetusind',),
#  ('mange',),
#  ('gruppe',),
#  ('papirløs',),
#  ('papirløs',),
#  ('ny',),
#  ('beskytte',),
#  ('opfatte',),
#  ('ny',),
#  ('politisk',),
#  ('hjælpe',),
#  ('som',),
#  ('og',),
#  ('for',),
#  ('af',),
#  ('for',),
#  ('og',),
#  ('af',),
#  ...]

# %% [markdown]
# **Remove Stopwords from modifier list**

# %%
flygtningmodifier
def remove_stopwords(lst):
    with open('./stopord.txt', 'r') as sw:
        stopwords = sw.read().split('\n')
        #read the stopwords file 
        return [word for word in lst if not word in stopwords]

flygtningmodifier = [tuple(remove_stopwords(lst)) for lst in flygtningmodifier]
flygtningmodifier
# Out:
# [(),
#  (),
#  (),
#  ('afrikansk',),
#  ('pak',),
#  ('afrikansk',),
#  ('300',),
#  (),
#  (),
#  ('hjælpe',),
#  (),
#  ('illegal',),
#  ('15 000',),
#  ('hundred',),
#  ('nordafrikansk',),
#  (),
#  (),
#  ('6700',),
#  ('15 000',),
#  ('afvise',),
#  (),
#  (),
#  ('modsat',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('holde',),
#  (),
#  (),
#  (),
#  ('europa',),
#  (),
#  (),
#  (),
#  ('500',),
#  (),
#  ('strømme',),
#  (),
#  ('5 000',),
#  (),
#  (),
#  (),
#  ('500',),
#  (),
#  ('bosnisk',),
#  ('million',),
#  ('båd',),
#  (),
#  (),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  (),
#  (),
#  (),
#  ('afghansk',),
#  (),
#  ('afghansk',),
#  ('afghansk',),
#  ('illegal',),
#  ('afghansk',),
#  (),
#  ('afghansk',),
#  ('afghansk',),
#  ('illegal',),
#  ('afghansk',),
#  (),
#  (),
#  ('afghansk',),
#  ('illegal',),
#  ('afghansk',),
#  (),
#  ('illegal',),
#  ('danmark',),
#  ('sende',),
#  ('20',),
#  ('give',),
#  (),
#  ('syrisk',),
#  (),
#  ('syrisk',),
#  ('rigtig',),
#  (),
#  ('afghansk',),
#  ('finde',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('tusind',),
#  (),
#  ('syrisk',),
#  ('bosnisk',),
#  ('somalisk',),
#  (),
#  ('hus',),
#  (),
#  ('immigrationscenter',),
#  ('land',),
#  ('200',),
#  (),
#  (),
#  (),
#  ('forhindre',),
#  ('tilbyde',),
#  ('dyr',),
#  (),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('producere',),
#  (),
#  ('tvinge',),
#  (),
#  (),
#  ('syrisk',),
#  ('skubbe',),
#  ('syrisk',),
#  (),
#  ('overnatte',),
#  ('grækenland',),
#  (),
#  (),
#  (),
#  (),
#  ('anerkende',),
#  (),
#  (),
#  ('anerkende',),
#  (),
#  ('desperat',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  (),
#  ('ung',),
#  ('afghansk',),
#  (),
#  ('give',),
#  (),
#  (),
#  ('sende',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('tilbageholde',),
#  (),
#  ('holde',),
#  ('1014',),
#  ('hovedsagelig',),
#  (),
#  (),
#  ('løsning',),
#  (),
#  (),
#  (),
#  ('million',),
#  ('syrisk',),
#  ('verden',),
#  ('fjerde',),
#  ('3819',),
#  ('alverden',),
#  ('uledsaget',),
#  (),
#  ('ulovlig',),
#  ('ignorere',),
#  (),
#  (),
#  ('antal',),
#  (),
#  (),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('hjælpe',),
#  ('syrisk',),
#  ('syrisk',),
#  ('holde',),
#  (),
#  ('syrisk',),
#  (),
#  ('syrien',),
#  ('69',),
#  ('48',),
#  ('sende',),
#  ('alverden',),
#  (),
#  ('million',),
#  (),
#  ('ramme',),
#  ('hjælpe',),
#  ('afrikansk',),
#  ('tusind',),
#  ('samle',),
#  ('13',),
#  ('30 000',),
#  (),
#  ('somalisk',),
#  (),
#  ('verden',),
#  (),
#  ('fordrive',),
#  (),
#  (),
#  (),
#  ('5 000',),
#  ('fordele',),
#  ('nordafrikansk',),
#  ('2000',),
#  ('60 000',),
#  (),
#  ('skibbruden',),
#  ('320',),
#  (),
#  (),
#  ('hus',),
#  ('illegal',),
#  (),
#  (),
#  ('luchte',),
#  ('syrisk',),
#  (),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('300',),
#  (),
#  ('300',),
#  ('anholde',),
#  (),
#  ('80 000',),
#  ('afrikansk',),
#  (),
#  ('dø',),
#  ('tusind',),
#  ('samle',),
#  ('13',),
#  ('område',),
#  ('nødhjælp',),
#  (),
#  ('libysk',),
#  (),
#  ('antal',),
#  ('jødisk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('enkelt',),
#  ('aalborg',),
#  (),
#  (),
#  ('fordele',),
#  ('syrisk',),
#  ('8 000',),
#  ('syrisk',),
#  ('50 000',),
#  ('fjerne',),
#  (),
#  ('følge',),
#  (),
#  (),
#  (),
#  ('',),
#  (),
#  ('hundred',),
#  ('syrisk',),
#  ('syrisk',),
#  ('330',),
#  ('aalborg',),
#  ('enkelt',),
#  ('aalborg',),
#  ('fordele',),
#  ('fordel',),
#  ('enkelt',),
#  ('fordel',),
#  ('ekstra',),
#  (),
#  (),
#  (),
#  ('',),
#  (),
#  (),
#  (),
#  ('somalisk',),
#  ('enkelt',),
#  (),
#  (),
#  ('12 000',),
#  ('fordrive',),
#  (),
#  (),
#  (),
#  ('enkelt',),
#  (),
#  (),
#  (),
#  ('80 000',),
#  ('jordan',),
#  ('hjælpe',),
#  (),
#  ('hjælpe',),
#  ('hjemland for',),
#  ('syrisk',),
#  ('smugle',),
#  (),
#  ('syrisk',),
#  ('udlændingemyndighed',),
#  ('syrisk',),
#  ('million',),
#  ('al',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('fragte',),
#  ('syrisk',),
#  (),
#  ('syrisk',),
#  (),
#  ('antal',),
#  (),
#  ('BBC',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('38',),
#  (),
#  (),
#  ('332',),
#  (),
#  ('syrisk',),
#  ('fordrive',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('somalisk',),
#  ('sødygtig',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  (),
#  ('udsat',),
#  ('drik',),
#  ('verden',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrien',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('tildele',),
#  (),
#  ('syrisk',),
#  ('femte',),
#  ('femte',),
#  (),
#  ('år',),
#  ('al',),
#  ('modtage',),
#  ('henriksen',),
#  ('leve',),
#  (),
#  (),
#  ('mulig',),
#  ('per',),
#  ('lindegård',),
#  (),
#  ('somalisk',),
#  (),
#  ('modtage',),
#  (),
#  ('242 000',),
#  (),
#  ('papirløs',),
#  (),
#  (),
#  ('5000',),
#  ('syrisk',),
#  (),
#  ('antal',),
#  ('forhindre',),
#  ('give',),
#  ('1000',),
#  ('syrisk',),
#  ('nord',),
#  (),
#  (),
#  ('såre',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('antal',),
#  (),
#  (),
#  ('mode',),
#  ('verden',),
#  ('antal',),
#  (),
#  ('fjerde',),
#  (),
#  (),
#  ('370',),
#  ('253',),
#  (),
#  (),
#  ('udsat',),
#  (),
#  ('syrisk',),
#  (),
#  ('afrikansk',),
#  ('syrisk',),
#  (),
#  (),
#  ('syrisk',),
#  ('2850',),
#  (),
#  (),
#  (),
#  ('give',),
#  (),
#  (),
#  ('fordrive',),
#  (),
#  (),
#  (),
#  ('antal',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  (),
#  ('million',),
#  (),
#  (),
#  (),
#  (),
#  ('600',),
#  (),
#  ('180 000',),
#  (),
#  ('støtte',),
#  ('antal',),
#  ('voksen',),
#  (),
#  (),
#  ('give',),
#  (),
#  ('give',),
#  ('navngive',),
#  (),
#  ('251 000',),
#  ('million',),
#  ('51 000',),
#  ('nyankomme',),
#  ('nyankomme',),
#  (),
#  (),
#  ('hjælpe',),
#  ('omfordele',),
#  (),
#  ('anerkende',),
#  ('ramme',),
#  ('syrisk',),
#  ('antal',),
#  ('',),
#  (),
#  ('fordel',),
#  ('syrisk',),
#  (),
#  ('48',),
#  ('irakisk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('300',),
#  (),
#  (),
#  ('hjælpe',),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('syrisk',),
#  (),
#  ('afrikansk',),
#  (),
#  ('226',),
#  (),
#  ('100',),
#  ('750',),
#  ('give',),
#  ('tunesisk',),
#  (),
#  (),
#  (),
#  ('2500',),
#  (),
#  (),
#  (),
#  (),
#  ('1400',),
#  ('ritzau',),
#  (),
#  (),
#  (),
#  ('traumatisere',),
#  (),
#  ('1300',),
#  (),
#  ('35 000',),
#  (),
#  (),
#  ('udgøre',),
#  ('flyve',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('libysk',),
#  ('tunesien',),
#  ('libysk',),
#  (),
#  ('fordel',),
#  ('følge',),
#  ('fordele',),
#  (),
#  (),
#  ('gruppe',),
#  ('nå',),
#  ('behandle',),
#  (),
#  (),
#  (),
#  (),
#  ('million',),
#  (),
#  ('lejr',),
#  ('400',),
#  ('syrisk',),
#  (),
#  ('antal',),
#  ('million',),
#  ('hjælpe',),
#  (),
#  ('syrisk',),
#  ('100 000',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('613',),
#  ('hjemvendt',),
#  (),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('palæstinensisk',),
#  (),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('gruppe',),
#  ('90 000',),
#  (),
#  ('al',),
#  (),
#  ('syrisk',),
#  ('25 000',),
#  (),
#  ('syrisk',),
#  ('gillard',),
#  (),
#  ('200',),
#  (),
#  (),
#  ('afghansk',),
#  ('kabul',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nyhed',),
#  ('al',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  ('30 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('100',),
#  ('4484',),
#  ('250',),
#  (),
#  ('35 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nå',),
#  (),
#  ('gruppe',),
#  ('hjælpe',),
#  (),
#  (),
#  ('anvise',),
#  (),
#  (),
#  ('1041',),
#  ('1820',),
#  ('syrisk',),
#  ('10 000',),
#  ('opfordre',),
#  (),
#  ('tysk',),
#  ('tysk',),
#  ('tysk',),
#  ('al',),
#  ('tysk',),
#  (),
#  ('fordel',),
#  (),
#  (),
#  ('tamilsk',),
#  (),
#  (),
#  (),
#  ('undersøge',),
#  ('tusind',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  (),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('31 000',),
#  (),
#  ('risikere',),
#  ('ungarsk',),
#  ('chilensk',),
#  ('bosnisk',),
#  (),
#  (),
#  (),
#  (),
#  ('øvrig',),
#  (),
#  ('nødhjælp',),
#  ('12',),
#  ('300',),
#  ('lampedusa',),
#  ('300',),
#  (),
#  ('32 000',),
#  (),
#  ('illegal',),
#  ('bringe',),
#  (),
#  ('nyankomme',),
#  ('nyankomme',),
#  ('nyankomme',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('tvinge',),
#  (),
#  ('syrisk',),
#  (),
#  ('4445',),
#  ('6445',),
#  (),
#  ('syrisk',),
#  ('20 000',),
#  ('antal',),
#  (),
#  ('nå',),
#  ('syrisk',),
#  (),
#  ('syrisk',),
#  (),
#  (),
#  (),
#  ('antal',),
#  ('syrisk',),
#  ('300',),
#  (),
#  ('300',),
#  (),
#  (),
#  (),
#  (),
#  ('syrisk',),
#  ('tusind',),
#  ('irakisk',),
#  (),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('syrisk',),
#  ('',),
#  ('kyse',),
#  ('afrikansk',),
#  ('300',),
#  (),
#  (),
#  (),
#  (),
#  ('sikkerhed',),
#  (),
#  ('påvirke',),
#  ('million',),
#  (),
#  (),
#  (),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('mishandle',),
#  ('syrisk',),
#  (),
#  ('300',),
#  (),
#  ('4500',),
#  (),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('syrisk',),
#  (),
#  (),
#  ('omfatte',),
#  (),
#  (),
#  ('økonomisk',),
#  (),
#  (),
#  ('3 500',),
#  ('12',),
#  ('300',),
#  ('lampedusa',),
#  ('300',),
#  (),
#  ('million',),
#  (),
#  (),
#  ('liv',),
#  (),
#  ('afghansk',),
#  (),
#  ('hjemvendende',),
#  ('million',),
#  ('hjemvendt',),
#  ('hjemvendt',),
#  (),
#  ('fordrive',),
#  ('fordrive',),
#  ('fordrive',),
#  (),
#  (),
#  ('flytte',),
#  (),
#  ('interviewe',),
#  ('fordel',),
#  (),
#  (),
#  ('asylsøgende',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  ('palæstinensisk',),
#  (),
#  ('2 850',),
#  ('2 447',),
#  (),
#  (),
#  ('hjælpe',),
#  (),
#  (),
#  (),
#  ('100 000',),
#  (),
#  (),
#  (),
#  ('berøre',),
#  (),
#  ('syrisk',),
#  (),
#  (),
#  ('nordafrikansk',),
#  (),
#  (),
#  ('strande',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('verden',),
#  ('hjælpe',),
#  ('500',),
#  (),
#  (),
#  ('kystvagt',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  (),
#  ('syrisk',),
#  ('huse',),
#  (),
#  ('ritzau AFP',),
#  (),
#  (),
#  (),
#  (),
#  ('syrisk',),
#  ('slem',),
#  (),
#  (),
#  ('5000',),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('malisk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('100',),
#  ('4484',),
#  ('250',),
#  (),
#  (),
#  (),
#  (),
#  ('sne',),
#  ('syrisk',),
#  ('300 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('give',),
#  (),
#  ('antal',),
#  (),
#  ('nordafrikansk',),
#  ('25 50',),
#  (),
#  (),
#  (),
#  (),
#  ('herboende',),
#  (),
#  (),
#  (),
#  ('strømme',),
#  ('20 000',),
#  (),
#  (),
#  (),
#  (),
#  ('afrikansk',),
#  (),
#  ('somalisk',),
#  (),
#  ('80 000',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  (),
#  (),
#  (),
#  ('flå',),
#  ('drukne',),
#  ('libysk',),
#  (),
#  (),
#  ('million',),
#  ('komit en',),
#  ('komit en',),
#  ('230 000',),
#  ('515 000',),
#  ('17 600',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('tilsvarende',),
#  (),
#  ('palæstinensisk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('verden',),
#  (),
#  ('30 000',),
#  (),
#  ('syrisk',),
#  ('syrisk',),
#  ('syrisk',),
#  (),
#  ('afrikansk',),
#  (),
#  ('organisation',),
#  ('irakisk',),
#  ('udsætte',),
#  ('politisk',),
#  (),
#  ('gælde',),
#  (),
#  (),
#  ('tunesisk',),
#  (),
#  ('gælde',),
#  ('udsætte',),
#  (),
#  (),
#  ('mortensen',),
#  (),
#  (),
#  ('gruppe',),
#  (),
#  ('tydelig',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sluse',),
#  ('hundredetusind',),
#  (),
#  ('gruppe',),
#  ('papirløs',),
#  ('papirløs',),
#  (),
#  ('beskytte',),
#  ('opfatte',),
#  (),
#  ('politisk',),
#  ('hjælpe',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ...]

# %% [markdown]
# **Modifier Frequency**

# %%
flygtningmodifier_count = collections.Counter(flygtningmodifier).most_common(100)
flygtningmodifier_count
# Out:
# [((), 7701),
#  (('syrisk',), 644),
#  (('antal',), 159),
#  (('hjælpe',), 144),
#  (('million',), 139),
#  (('al',), 88),
#  (('sende',), 86),
#  (('nyankomme',), 60),
#  (('nå',), 57),
#  (('modtage',), 56),
#  (('hus',), 52),
#  (('',), 47),
#  (('give',), 45),
#  (('enkelt',), 45),
#  (('nytilkommen',), 45),
#  (('afrikansk',), 43),
#  (('tusind',), 40),
#  (('160 000',), 40),
#  (('somalisk',), 39),
#  (('verden',), 39),
#  (('gruppe',), 39),
#  (('palæstinensisk',), 39),
#  (('12 000',), 38),
#  (('integrere',), 36),
#  (('fordel',), 32),
#  (('ansætte',), 32),
#  (('ung',), 30),
#  (('300',), 29),
#  (('500',), 29),
#  (('20 000',), 28),
#  (('båd',), 26),
#  (('1 000',), 26),
#  (('holde',), 25),
#  (('afghansk',), 24),
#  (('uledsaget',), 24),
#  (('illegal',), 22),
#  (('irakisk',), 22),
#  (('placere',), 22),
#  (('udsat',), 21),
#  (('200',), 20),
#  (('10 000',), 20),
#  (('tysk',), 20),
#  (('behandle',), 19),
#  (('hav',), 19),
#  (('byde',), 19),
#  (('enlig',), 19),
#  (('hundred',), 18),
#  (('ekstra',), 18),
#  (('100',), 18),
#  (('mindreårig',), 18),
#  (('registrere',), 17),
#  (('vis',), 16),
#  (('and',), 16),
#  (('afvise',), 15),
#  (('samle',), 15),
#  (('fordrive',), 15),
#  (('første',), 15),
#  (('overfor',), 15),
#  (('120 000',), 15),
#  (('bosnisk',), 14),
#  (('80 000',), 14),
#  (('100 000',), 14),
#  (('håndtere',), 14),
#  (('kristen',), 14),
#  (('type',), 14),
#  (('fordele',), 13),
#  (('huse',), 13),
#  (('herboende',), 13),
#  (('indkvartere',), 13),
#  (('50 000',), 12),
#  (('600',), 12),
#  (('traumatisere',), 12),
#  (('muslimsk',), 12),
#  (('desperat',), 11),
#  (('smugle',), 11),
#  (('omfordele',), 11),
#  (('ritzau',), 11),
#  (('25 000',), 11),
#  (('tamilsk',), 11),
#  (('bo',), 11),
#  (('17 000',), 11),
#  (('20',), 10),
#  (('år',), 10),
#  (('per',), 10),
#  (('400',), 10),
#  (('flytte',), 10),
#  (('sårbar',), 10),
#  (('3 000',), 10),
#  (('enkel',), 10),
#  (('200 000',), 10),
#  (('800 000',), 10),
#  (('beslaglægge',), 10),
#  (('nordkoreansk',), 10),
#  (('tilbyde',), 9),
#  (('250',), 9),
#  (('1500',), 9),
#  (('ankomme',), 9),
#  (('6000',), 9),
#  (('redde',), 9),
#  (('støt',), 9)]

# %%
df_flytningmodifier = pd.DataFrame(flygtningmodifier_count)
df_flytningmodifier.head(13)
# Out:
#                0     1
# 0             ()  7701
# 1      (syrisk,)   644
# 2       (antal,)   159
# 3      (hjælpe,)   144
# 4     (million,)   139
# 5          (al,)    88
# 6       (sende,)    86
# 7   (nyankomme,)    60
# 8          (nå,)    57
# 9     (modtage,)    56
# 10        (hus,)    52
# 11           (,)    47
# 12       (give,)    45

# %%
df_flytningmodifier['Term'] = 'flygtning'

# %% [markdown]
# **Asylum Seeker Modifier**

# %%
string = lemmatize_strings(' '.join(article_data['Text']).split(' '))

# %%
dictionary = ['asylansøger']
asylansøgermodifier = []
for word in dictionary:
    stop = False
    while not stop:
        try:
            idx = string.index(word)
            asylansøgermodifier.append(tuple(string[idx-1:idx]))
            string = string[idx+1:]
        except:
            stop = True
                  
asylansøgermodifier
# Out:
# [('ikke',),
#  ('200',),
#  ('og',),
#  ('land',),
#  ('1 767',),
#  ('om',),
#  ('af',),
#  ('100',),
#  ('nå',),
#  ('100',),
#  ('af',),
#  ('at',),
#  ('af',),
#  ('al',),
#  ('afvise',),
#  ('380',),
#  ('3000',),
#  ('afghansk',),
#  ('blandt',),
#  ('frihedsberøve',),
#  ('forhindre',),
#  ('disse',),
#  ('813',),
#  ('femte',),
#  ('af',),
#  ('har',),
#  ('tiltrække',),
#  ('tunesisk',),
#  ('flest',),
#  ('år',),
#  ('nå',),
#  ('100',),
#  ('af',),
#  ('af',),
#  ('på',),
#  ('af',),
#  ('afvise',),
#  ('afvise',),
#  ('560',),
#  ('afghansk',),
#  ('160',),
#  ('at',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('til',),
#  ('af',),
#  ('5750',),
#  ('hus',),
#  ('200',),
#  ('udlændingestyrelse',),
#  ('henvise',),
#  ('disse',),
#  ('første',),
#  ('af',),
#  ('en',),
#  ('for',),
#  ('for',),
#  ('afvise',),
#  ('at',),
#  ('for',),
#  ('afvise',),
#  ('serbisk',),
#  ('392',),
#  ('af',),
#  ('indkvartere',),
#  ('for',),
#  ('flere',),
#  ('give',),
#  ('se',),
#  ('afvise',),
#  ('afvise',),
#  ('at',),
#  ('nå',),
#  ('de',),
#  ('for',),
#  ('afvise',),
#  ('af',),
#  ('af',),
#  ('hvorfor',),
#  ('være',),
#  ('antal',),
#  ('flere',),
#  ('mange',),
#  ('to',),
#  ('tale',),
#  ('afvise',),
#  ('en',),
#  ('afvise',),
#  ('den',),
#  ('gruppe',),
#  ('derimod',),
#  ('afvise',),
#  ('irakisk',),
#  ('at',),
#  ('sende',),
#  ('tvangsudsende',),
#  ('som',),
#  ('sende',),
#  ('sende',),
#  ('af',),
#  ('tusind',),
#  ('sende',),
#  ('sende',),
#  ('5521',),
#  ('2279',),
#  ('350',),
#  ('5500',),
#  ('for',),
#  ('afvise',),
#  ('ekstra',),
#  ('afvise',),
#  ('afvise',),
#  ('flere',),
#  ('afvise',),
#  ('42',),
#  ('1500',),
#  ('af',),
#  ('en',),
#  ('afvise',),
#  ('afvise',),
#  ('henriksen',),
#  ('og',),
#  ('og',),
#  ('i',),
#  ('til',),
#  ('',),
#  ('for',),
#  ('aktivere',),
#  ('flest',),
#  ('12 500',),
#  ('12 000',),
#  ('flest',),
#  ('3819',),
#  ('af',),
#  ('modtage',),
#  ('afghansk',),
#  ('ny',),
#  ('ny',),
#  ('hvor',),
#  ('blandt',),
#  ('give',),
#  ('afvise',),
#  ('hjælpe',),
#  ('tre',),
#  ('anden',),
#  ('nogen',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('af',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('340',),
#  ('afghansk',),
#  ('for',),
#  ('340',),
#  ('anden',),
#  ('at',),
#  ('at',),
#  ('behandle',),
#  ('at',),
#  ('for',),
#  ('afvise',),
#  ('for',),
#  ('hvordan',),
#  ('flere',),
#  ('vedrøre',),
#  ('for',),
#  ('få',),
#  ('blive',),
#  ('få',),
#  ('af',),
#  ('få',),
#  ('gruppe',),
#  ('iransk',),
#  ('fjerde',),
#  ('400',),
#  ('her',),
#  ('kamm',),
#  ('af',),
#  ('med',),
#  ('af',),
#  ('flere',),
#  ('af',),
#  ('af',),
#  ('mange',),
#  ('afvise',),
#  ('',),
#  ('sende',),
#  ('hvor',),
#  ('for',),
#  ('og',),
#  ('og',),
#  ('formode',),
#  ('afvise',),
#  ('almindelig',),
#  ('almindelig',),
#  ('ritzau',),
#  ('af',),
#  ('af',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('sektionere',),
#  ('6000',),
#  ('til',),
#  ('afvise',),
#  ('afvise',),
#  ('1160',),
#  ('flere',),
#  ('6000',),
#  ('40 000',),
#  ('af',),
#  ('mange',),
#  ('3 936',),
#  ('3 108',),
#  ('over',),
#  ('afvise',),
#  ('afvise',),
#  ('hjemsende',),
#  ('3 340',),
#  ('af',),
#  ('200',),
#  ('200',),
#  ('første',),
#  ('flere',),
#  ('340',),
#  ('afghansk',),
#  ('340',),
#  ('en',),
#  ('af',),
#  ('TV2 lorry',),
#  ('afhøre',),
#  ('af',),
#  ('at',),
#  ('hjælpe',),
#  ('hjælpe',),
#  ('ung',),
#  ('ung',),
#  ('ung',),
#  ('uledsaget',),
#  ('ung',),
#  ('uledsaget',),
#  ('afvise',),
#  ('afvise',),
#  ('irakisk',),
#  ('irakisk',),
#  ('standse',),
#  ('at',),
#  ('at',),
#  ('syrisk',),
#  ('flere',),
#  ('antal',),
#  ('flere',),
#  ('for',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('kriminel',),
#  ('afvise',),
#  ('afvise',),
#  ('guinea',),
#  ('500',),
#  ('150',),
#  ('mod',),
#  ('modtage',),
#  ('afvise',),
#  ('afvise',),
#  ('af',),
#  ('afvise',),
#  ('at',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('serbisk',),
#  ('tusind',),
#  ('afvise',),
#  ('presse',),
#  ('',),
#  ('afvise',),
#  ('indkvartere',),
#  ('mindreårig',),
#  ('afvise',),
#  ('afvise',),
#  ('mindreårig',),
#  ('hjemvendt',),
#  ('skal',),
#  ('skal',),
#  ('at',),
#  ('af',),
#  ('til',),
#  ('at',),
#  ('at',),
#  ('byde',),
#  ('hvor',),
#  ('få',),
#  ('gavne',),
#  ('hvor',),
#  ('til',),
#  ('af',),
#  ('irakisk',),
#  ('af',),
#  ('200',),
#  ('hun',),
#  ('irakisk',),
#  ('irakisk',),
#  ('af',),
#  ('afvise',),
#  ('iransk',),
#  ('lad',),
#  ('fordi',),
#  ('protest',),
#  ('samtlige',),
#  ('blive',),
#  ('at',),
#  ('al',),
#  ('iransk',),
#  ('om',),
#  ('oplyse',),
#  ('at',),
#  ('men',),
#  ('mindreårig',),
#  ('iransk',),
#  ('for',),
#  ('at',),
#  ('at',),
#  ('af',),
#  ('af',),
#  ('antal',),
#  ('antal',),
#  ('af',),
#  ('afvise',),
#  ('fra',),
#  ('at',),
#  ('af',),
#  ('afvise',),
#  ('iransk',),
#  ('sultestrejke',),
#  ('iransk',),
#  ('på',),
#  ('af',),
#  ('elleve',),
#  ('4500',),
#  ('af',),
#  ('sende',),
#  ('skal',),
#  ('150 000',),
#  ('og',),
#  ('behandle',),
#  ('for',),
#  ('400',),
#  ('se',),
#  ('at',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('irakisk',),
#  ('afvise',),
#  ('155',),
#  ('af',),
#  ('for',),
#  ('skal',),
#  ('at',),
#  ('hvis',),
#  ('til',),
#  ('behandle',),
#  ('møde',),
#  ('forhold',),
#  ('nu',),
#  ('hjælpe',),
#  ('lad',),
#  ('kun',),
#  ('afvise',),
#  ('somalisk',),
#  ('somalisk',),
#  ('ingen',),
#  ('sende',),
#  ('dansk',),
#  ('EU land',),
#  ('for',),
#  ('afghansk',),
#  ('350',),
#  ('al',),
#  ('forhold',),
#  ('tusindvis',),
#  ('behandle',),
#  ('at',),
#  ('',),
#  ('afghansk',),
#  ('350',),
#  ('forhold',),
#  ('tusindvis',),
#  ('behandle',),
#  ('afghansk',),
#  ('350',),
#  ('al',),
#  ('forhold',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('nå',),
#  ('fragte',),
#  ('ved',),
#  ('frihedsberøve',),
#  ('af',),
#  ('lukke',),
#  ('en',),
#  ('at',),
#  ('tvangsudsende',),
#  ('sende',),
#  ('400',),
#  ('samtlige',),
#  ('flygtningehjælp',),
#  ('for',),
#  ('20 000',),
#  ('afvise',),
#  ('at',),
#  ('sende',),
#  ('50',),
#  ('kunne',),
#  ('forhindre',),
#  ('tvangsudsende',),
#  ('af',),
#  ('sende',),
#  ('sende',),
#  ('har',),
#  ('udsende',),
#  ('at',),
#  ('af',),
#  ('million',),
#  ('fremtid',),
#  ('sikre',),
#  ('995',),
#  ('afghansk',),
#  ('af',),
#  ('af',),
#  ('for',),
#  ('for',),
#  ('enkel',),
#  ('340',),
#  ('af',),
#  ('for',),
#  ('kunne',),
#  ('men',),
#  ('flere',),
#  ('500',),
#  ('afvise',),
#  ('flere',),
#  ('syg',),
#  ('afvise',),
#  ('afvise',),
#  ('at',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('for',),
#  ('våge',),
#  ('leve',),
#  ('irakisk',),
#  ('afvise',),
#  ('afvise',),
#  ('syv',),
#  ('sende',),
#  ('tre',),
#  ('for',),
#  ('sende',),
#  ('tag',),
#  ('mange',),
#  ('20 000',),
#  ('afvise',),
#  ('afvise',),
#  ('irakisk',),
#  ('at',),
#  ('småting',),
#  ('at',),
#  ('sende',),
#  ('som',),
#  ('sende',),
#  ('indkvartere',),
#  ('indkvartere',),
#  ('indkvartere',),
#  ('antal',),
#  ('afvise',),
#  ('for',),
#  ('de',),
#  ('flest',),
#  ('flest',),
#  ('sjette',),
#  ('syrisk',),
#  ('flest',),
#  ('flest',),
#  ('afvise',),
#  ('afvise',),
#  ('kunne',),
#  ('afvise',),
#  ('afvise',),
#  ('mange',),
#  ('reel',),
#  ('kriminel',),
#  ('af',),
#  ('at',),
#  ('afvise',),
#  ('af',),
#  ('lad',),
#  ('blive',),
#  ('være',),
#  ('og',),
#  ('for',),
#  ('finde',),
#  ('al',),
#  ('af',),
#  ('land',),
#  ('se',),
#  ('samarbejde',),
#  ('5500',),
#  ('at',),
#  ('på',),
#  ('rigtig',),
#  ('rigtig',),
#  ('møde',),
#  ('på',),
#  ('sende',),
#  ('fra',),
#  ('at',),
#  ('sende',),
#  ('at',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afrikansk',),
#  ('mange',),
#  ('irakisk',),
#  ('irakisk',),
#  ('afvise',),
#  ('med',),
#  ('af',),
#  ('for',),
#  ('ikke',),
#  ('til',),
#  ('11',),
#  ('behandle',),
#  ('ej',),
#  ('som',),
#  ('af',),
#  ('mange',),
#  ('til',),
#  ('af',),
#  ('340',),
#  ('fremtidig',),
#  ('hvis',),
#  ('med',),
#  ('med',),
#  ('kurdisk',),
#  ('og',),
#  ('for',),
#  ('dyr',),
#  ('som',),
#  ('behandle',),
#  ('bør',),
#  ('afvise',),
#  ('irakisk',),
#  ('afvise',),
#  ('enkelt',),
#  ('syrisk',),
#  ('mange',),
#  ('dansk',),
#  ('af',),
#  ('de',),
#  ('af',),
#  ('til',),
#  ('af',),
#  ('afvise',),
#  ('serbisk',),
#  ('sommer',),
#  ('anden',),
#  ('holde',),
#  ('mange',),
#  ('EU land',),
#  ('sende',),
#  ('mange',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('fremtidig',),
#  ('herhjemme',),
#  ('tilbage',),
#  ('båd',),
#  ('mange',),
#  ('og',),
#  ('og',),
#  ('irakisk',),
#  ('irakisk',),
#  ('irakisk',),
#  ('ung',),
#  ('for',),
#  ('uledsaget',),
#  ('voksen',),
#  ('af',),
#  ('afghansk',),
#  ('af',),
#  ('og',),
#  ('13',),
#  ('om',),
#  ('for',),
#  ('for',),
#  ('mange',),
#  ('20',),
#  ('de',),
#  ('20',),
#  ('350',),
#  ('mindreårig',),
#  ('afghansk',),
#  ('lad',),
#  ('afvise',),
#  ('afvise',),
#  ('500',),
#  ('for',),
#  ('og',),
#  ('måde',),
#  ('af',),
#  ('europæisk',),
#  ('afvise',),
#  ('de',),
#  ('afvise',),
#  ('udvise',),
#  ('udvise',),
#  ('til',),
#  ('blandt',),
#  ('at',),
#  ('at',),
#  ('20',),
#  ('',),
#  ('behandle',),
#  ('for',),
#  ('irakisk',),
#  ('afvise',),
#  ('937 000',),
#  ('som',),
#  ('få',),
#  ('hvor',),
#  ('afvise',),
#  ('mindreårig',),
#  ('fordel',),
#  ('som',),
#  ('udvise',),
#  ('savne',),
#  ('at',),
#  ('',),
#  ('efter',),
#  ('af',),
#  ('syrisk',),
#  ('af',),
#  ('i',),
#  ('få',),
#  ('for',),
#  ('ny',),
#  ('af',),
#  ('million',),
#  ('mange',),
#  ('og',),
#  ('syg',),
#  ('af',),
#  ('få',),
#  ('migrant',),
#  ('migrant',),
#  ('af',),
#  ('legitim',),
#  ('af',),
#  ('afvise',),
#  ('og',),
#  ('538 000',),
#  ('af',),
#  ('antal',),
#  ('stoppe',),
#  ('godkende',),
#  ('afvise',),
#  ('ung',),
#  ('at',),
#  ('for',),
#  ('sende',),
#  ('at',),
#  ('21 253',),
#  ('som',),
#  ('for',),
#  ('forhindre',),
#  ('at',),
#  ('for',),
#  ('en',),
#  ('for',),
#  ('pågribe',),
#  ('40 000',),
#  ('175 000',),
#  ('enkelt',),
#  ('og',),
#  ('mod',),
#  ('holde',),
#  ('en',),
#  ('en',),
#  ('af',),
#  ('af',),
#  ('al',),
#  ('en',),
#  ('million',),
#  ('få',),
#  ('af',),
#  ('med',),
#  ('sende',),
#  ('million',),
#  ('af',),
#  ('tyskland',),
#  ('flere',),
#  ('ny',),
#  ('flere',),
#  ('på',),
#  ('80',),
#  ('million',),
#  ('af',),
#  ('mod',),
#  ('af',),
#  ('imod',),
#  ('i',),
#  ('5 413',),
#  ('afvise',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('384',),
#  ('75',),
#  ('håndtere',),
#  ('syrisk',),
#  ('og',),
#  ('hvor',),
#  ('16 000',),
#  ('for',),
#  ('indvandring',),
#  ('25 000',),
#  ('med',),
#  ('5 413',),
#  ('hvorvidt',),
#  ('af',),
#  ('af',),
#  ('følge',),
#  ('og',),
#  ('af',),
#  ('50',),
#  ('og',),
#  ('også',),
#  ('konfiskere',),
#  ('transporter',),
#  ('tilbageholde',),
#  ('stå',),
#  ('af',),
#  ('være',),
#  ('men',),
#  ('en',),
#  ('af',),
#  ('af',),
#  ('de',),
#  ('afvise',),
#  ('syrisk',),
#  ('37 000',),
#  ('afvise',),
#  ('og',),
#  ('hvor',),
#  ('afvise',),
#  ('og',),
#  ('million',),
#  ('af',),
#  ('få',),
#  ('imod',),
#  ('af',),
#  ('sende',),
#  ('som',),
#  ('få',),
#  ('tælle',),
#  ('indlogere',),
#  ('legitim',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('sende',),
#  ('for',),
#  ('en',),
#  ('for',),
#  ('2 000',),
#  ('',),
#  ('tilbageholde',),
#  ('332',),
#  ('10 000',),
#  ('mange',),
#  ('million',),
#  ('at',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('få',),
#  ('af',),
#  ('kunne',),
#  ('stramme',),
#  ('flygtning',),
#  ('for',),
#  ('en',),
#  ('pågældende',),
#  ('af',),
#  ('190 000',),
#  ('reducere',),
#  ('afvise',),
#  ('antal',),
#  ('for',),
#  ('af',),
#  ('745 545',),
#  ('ny',),
#  ('af',),
#  ('afvise',),
#  ('holde',),
#  ('at',),
#  ('at',),
#  ('flest',),
#  ('for',),
#  ('af',),
#  ('de',),
#  ('imod',),
#  ('af',),
#  ('al',),
#  ('omfordele',),
#  ('afvise',),
#  ('af',),
#  ('al',),
#  ('registrere',),
#  ('tag',),
#  ('få',),
#  ('imod',),
#  ('behandle',),
#  ('sende',),
#  ('sende',),
#  ('som',),
#  ('af',),
#  ('tre',),
#  ('af',),
#  ('tilbagesende',),
#  ('sende',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('afvise',),
#  ('at',),
#  ('registrere',),
#  ('modtage',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('fra',),
#  ('skal',),
#  ('vis',),
#  ('om',),
#  ('flere',),
#  ('være',),
#  ('8000',),
#  ('have',),
#  ('afghansk',),
#  ('mange',),
#  ('af',),
#  ('modtage',),
#  ('få',),
#  ('1 307',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('hvor',),
#  ('også',),
#  ('af',),
#  ('og',),
#  ('al',),
#  ('200',),
#  ('være',),
#  ('de',),
#  ('få',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('sende',),
#  ('med',),
#  ('507 332',),
#  ('73 309',),
#  ('af',),
#  ('nå',),
#  ('90 000',),
#  ('160 000',),
#  ('forhindre',),
#  ('afvise',),
#  ('af',),
#  ('flere',),
#  ('af',),
#  ('at',),
#  ('afvise',),
#  ('at',),
#  ('have',),
#  ('afghansk',),
#  ('afvise',),
#  ('rekordfå',),
#  ('2 150',),
#  ('afvise',),
#  ('afvise',),
#  ('hver',),
#  ('en',),
#  ('syrisk',),
#  ('som',),
#  ('fordel',),
#  ('måned',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('irakisk',),
#  ('hvorfra',),
#  ('antal',),
#  ('samtlige',),
#  ('kun',),
#  ('afvise',),
#  ('samtlige',),
#  ('blive',),
#  ('mange',),
#  ('til',),
#  ('få',),
#  ('af',),
#  ('få',),
#  ('af',),
#  ('af',),
#  ('se',),
#  ('afvise',),
#  ('som',),
#  ('og',),
#  ('flest',),
#  ('million',),
#  ('og',),
#  ('udenlandsk',),
#  ('afvise',),
#  ('fem',),
#  ('som',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('de',),
#  ('samtlige',),
#  ('se',),
#  ('fem',),
#  ('55',),
#  ('for',),
#  ('afvise',),
#  ('en',),
#  ('forhindre',),
#  ('af',),
#  ('flytte',),
#  ('spontan',),
#  ('en',),
#  ('afvise',),
#  ('blandt',),
#  ('40 000',),
#  ('afvise',),
#  ('20 000',),
#  ('på',),
#  ('en',),
#  ('vinke',),
#  ('kunne',),
#  ('1 200',),
#  ('af',),
#  ('få',),
#  ('få',),
#  ('36 000',),
#  ('3 200',),
#  ('af',),
#  ('350',),
#  ('mandlig',),
#  ('hvor',),
#  ('også',),
#  ('forvente',),
#  ('6 900',),
#  ('4 400',),
#  ('160 000',),
#  ('og',),
#  ('af',),
#  ('21 000',),
#  ('af',),
#  ('5100',),
#  ('mange',),
#  ('afvise',),
#  ('komme',),
#  ('de',),
#  ...]

# %%
asylansøgermodifier
def remove_stopwords(lst):
    with open('./stopord.txt', 'r') as sw:
        stopwords = sw.read().split('\n')
        #read the stopwords file 
        return [word for word in lst if not word in stopwords]

asylansøgermodifier = [tuple(remove_stopwords(lst)) for lst in asylansøgermodifier]
asylansøgermodifier
# Out:
# [(),
#  ('200',),
#  (),
#  ('land',),
#  ('1 767',),
#  (),
#  (),
#  ('100',),
#  ('nå',),
#  ('100',),
#  (),
#  (),
#  (),
#  ('al',),
#  ('afvise',),
#  ('380',),
#  ('3000',),
#  ('afghansk',),
#  (),
#  ('frihedsberøve',),
#  ('forhindre',),
#  (),
#  ('813',),
#  ('femte',),
#  (),
#  (),
#  ('tiltrække',),
#  ('tunesisk',),
#  (),
#  ('år',),
#  ('nå',),
#  ('100',),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('560',),
#  ('afghansk',),
#  ('160',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  (),
#  ('5750',),
#  ('hus',),
#  ('200',),
#  ('udlændingestyrelse',),
#  ('henvise',),
#  (),
#  ('første',),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  (),
#  (),
#  ('afvise',),
#  ('serbisk',),
#  ('392',),
#  (),
#  ('indkvartere',),
#  (),
#  (),
#  ('give',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('nå',),
#  (),
#  (),
#  ('afvise',),
#  (),
#  (),
#  (),
#  (),
#  ('antal',),
#  (),
#  (),
#  (),
#  ('tale',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  (),
#  ('gruppe',),
#  ('derimod',),
#  ('afvise',),
#  ('irakisk',),
#  (),
#  ('sende',),
#  ('tvangsudsende',),
#  (),
#  ('sende',),
#  ('sende',),
#  (),
#  ('tusind',),
#  ('sende',),
#  ('sende',),
#  ('5521',),
#  ('2279',),
#  ('350',),
#  ('5500',),
#  (),
#  ('afvise',),
#  ('ekstra',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  ('42',),
#  ('1500',),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('henriksen',),
#  (),
#  (),
#  (),
#  (),
#  ('',),
#  (),
#  ('aktivere',),
#  (),
#  ('12 500',),
#  ('12 000',),
#  (),
#  ('3819',),
#  (),
#  ('modtage',),
#  ('afghansk',),
#  (),
#  (),
#  (),
#  (),
#  ('give',),
#  ('afvise',),
#  ('hjælpe',),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('340',),
#  ('afghansk',),
#  (),
#  ('340',),
#  (),
#  (),
#  (),
#  ('behandle',),
#  (),
#  (),
#  ('afvise',),
#  (),
#  (),
#  (),
#  ('vedrøre',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('gruppe',),
#  ('iransk',),
#  ('fjerde',),
#  ('400',),
#  (),
#  ('kamm',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('',),
#  ('sende',),
#  (),
#  (),
#  (),
#  (),
#  ('formode',),
#  ('afvise',),
#  ('almindelig',),
#  ('almindelig',),
#  ('ritzau',),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('sektionere',),
#  ('6000',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('1160',),
#  (),
#  ('6000',),
#  ('40 000',),
#  (),
#  (),
#  ('3 936',),
#  ('3 108',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('hjemsende',),
#  ('3 340',),
#  (),
#  ('200',),
#  ('200',),
#  ('første',),
#  (),
#  ('340',),
#  ('afghansk',),
#  ('340',),
#  (),
#  (),
#  ('TV2 lorry',),
#  ('afhøre',),
#  (),
#  (),
#  ('hjælpe',),
#  ('hjælpe',),
#  ('ung',),
#  ('ung',),
#  ('ung',),
#  ('uledsaget',),
#  ('ung',),
#  ('uledsaget',),
#  ('afvise',),
#  ('afvise',),
#  ('irakisk',),
#  ('irakisk',),
#  ('standse',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('antal',),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('kriminel',),
#  ('afvise',),
#  ('afvise',),
#  ('guinea',),
#  ('500',),
#  ('150',),
#  (),
#  ('modtage',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('serbisk',),
#  ('tusind',),
#  ('afvise',),
#  ('presse',),
#  ('',),
#  ('afvise',),
#  ('indkvartere',),
#  ('mindreårig',),
#  ('afvise',),
#  ('afvise',),
#  ('mindreårig',),
#  ('hjemvendt',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('byde',),
#  (),
#  (),
#  ('gavne',),
#  (),
#  (),
#  (),
#  ('irakisk',),
#  (),
#  ('200',),
#  (),
#  ('irakisk',),
#  ('irakisk',),
#  (),
#  ('afvise',),
#  ('iransk',),
#  (),
#  (),
#  ('protest',),
#  ('samtlige',),
#  (),
#  (),
#  ('al',),
#  ('iransk',),
#  (),
#  ('oplyse',),
#  (),
#  (),
#  ('mindreårig',),
#  ('iransk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('antal',),
#  ('antal',),
#  (),
#  ('afvise',),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('iransk',),
#  ('sultestrejke',),
#  ('iransk',),
#  (),
#  (),
#  ('elleve',),
#  ('4500',),
#  (),
#  ('sende',),
#  (),
#  ('150 000',),
#  (),
#  ('behandle',),
#  (),
#  ('400',),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('irakisk',),
#  ('afvise',),
#  ('155',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('behandle',),
#  ('møde',),
#  ('forhold',),
#  (),
#  ('hjælpe',),
#  (),
#  (),
#  ('afvise',),
#  ('somalisk',),
#  ('somalisk',),
#  (),
#  ('sende',),
#  ('dansk',),
#  ('EU land',),
#  (),
#  ('afghansk',),
#  ('350',),
#  ('al',),
#  ('forhold',),
#  ('tusindvis',),
#  ('behandle',),
#  (),
#  ('',),
#  ('afghansk',),
#  ('350',),
#  ('forhold',),
#  ('tusindvis',),
#  ('behandle',),
#  ('afghansk',),
#  ('350',),
#  ('al',),
#  ('forhold',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('nå',),
#  ('fragte',),
#  (),
#  ('frihedsberøve',),
#  (),
#  ('lukke',),
#  (),
#  (),
#  ('tvangsudsende',),
#  ('sende',),
#  ('400',),
#  ('samtlige',),
#  ('flygtningehjælp',),
#  (),
#  ('20 000',),
#  ('afvise',),
#  (),
#  ('sende',),
#  ('50',),
#  (),
#  ('forhindre',),
#  ('tvangsudsende',),
#  (),
#  ('sende',),
#  ('sende',),
#  (),
#  ('udsende',),
#  (),
#  (),
#  ('million',),
#  ('fremtid',),
#  ('sikre',),
#  ('995',),
#  ('afghansk',),
#  (),
#  (),
#  (),
#  (),
#  ('enkel',),
#  ('340',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('500',),
#  ('afvise',),
#  (),
#  ('syg',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('våge',),
#  ('leve',),
#  ('irakisk',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('sende',),
#  (),
#  (),
#  ('sende',),
#  (),
#  (),
#  ('20 000',),
#  ('afvise',),
#  ('afvise',),
#  ('irakisk',),
#  (),
#  ('småting',),
#  (),
#  ('sende',),
#  (),
#  ('sende',),
#  ('indkvartere',),
#  ('indkvartere',),
#  ('indkvartere',),
#  ('antal',),
#  ('afvise',),
#  (),
#  (),
#  (),
#  (),
#  ('sjette',),
#  ('syrisk',),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('reel',),
#  ('kriminel',),
#  (),
#  (),
#  ('afvise',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('finde',),
#  ('al',),
#  (),
#  ('land',),
#  (),
#  ('samarbejde',),
#  ('5500',),
#  (),
#  (),
#  ('rigtig',),
#  ('rigtig',),
#  ('møde',),
#  (),
#  ('sende',),
#  (),
#  (),
#  ('sende',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('afrikansk',),
#  (),
#  ('irakisk',),
#  ('irakisk',),
#  ('afvise',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('11',),
#  ('behandle',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('340',),
#  ('fremtidig',),
#  (),
#  (),
#  (),
#  ('kurdisk',),
#  (),
#  (),
#  ('dyr',),
#  (),
#  ('behandle',),
#  (),
#  ('afvise',),
#  ('irakisk',),
#  ('afvise',),
#  ('enkelt',),
#  ('syrisk',),
#  (),
#  ('dansk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('serbisk',),
#  ('sommer',),
#  (),
#  ('holde',),
#  (),
#  ('EU land',),
#  ('sende',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('fremtidig',),
#  ('herhjemme',),
#  (),
#  ('båd',),
#  (),
#  (),
#  (),
#  ('irakisk',),
#  ('irakisk',),
#  ('irakisk',),
#  ('ung',),
#  (),
#  ('uledsaget',),
#  ('voksen',),
#  (),
#  ('afghansk',),
#  (),
#  (),
#  ('13',),
#  (),
#  (),
#  (),
#  (),
#  ('20',),
#  (),
#  ('20',),
#  ('350',),
#  ('mindreårig',),
#  ('afghansk',),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('500',),
#  (),
#  (),
#  ('måde',),
#  (),
#  ('europæisk',),
#  ('afvise',),
#  (),
#  ('afvise',),
#  ('udvise',),
#  ('udvise',),
#  (),
#  (),
#  (),
#  (),
#  ('20',),
#  ('',),
#  ('behandle',),
#  (),
#  ('irakisk',),
#  ('afvise',),
#  ('937 000',),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('mindreårig',),
#  ('fordel',),
#  (),
#  ('udvise',),
#  ('savne',),
#  (),
#  ('',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('million',),
#  (),
#  (),
#  ('syg',),
#  (),
#  (),
#  ('migrant',),
#  ('migrant',),
#  (),
#  ('legitim',),
#  (),
#  ('afvise',),
#  (),
#  ('538 000',),
#  (),
#  ('antal',),
#  ('stoppe',),
#  ('godkende',),
#  ('afvise',),
#  ('ung',),
#  (),
#  (),
#  ('sende',),
#  (),
#  ('21 253',),
#  (),
#  (),
#  ('forhindre',),
#  (),
#  (),
#  (),
#  (),
#  ('pågribe',),
#  ('40 000',),
#  ('175 000',),
#  ('enkelt',),
#  (),
#  (),
#  ('holde',),
#  (),
#  (),
#  (),
#  (),
#  ('al',),
#  (),
#  ('million',),
#  (),
#  (),
#  (),
#  ('sende',),
#  ('million',),
#  (),
#  ('tyskland',),
#  (),
#  (),
#  (),
#  (),
#  ('80',),
#  ('million',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('5 413',),
#  ('afvise',),
#  (),
#  (),
#  (),
#  ('384',),
#  ('75',),
#  ('håndtere',),
#  ('syrisk',),
#  (),
#  (),
#  ('16 000',),
#  (),
#  ('indvandring',),
#  ('25 000',),
#  (),
#  ('5 413',),
#  ('hvorvidt',),
#  (),
#  (),
#  ('følge',),
#  (),
#  (),
#  ('50',),
#  (),
#  (),
#  ('konfiskere',),
#  ('transporter',),
#  ('tilbageholde',),
#  ('stå',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('syrisk',),
#  ('37 000',),
#  ('afvise',),
#  (),
#  (),
#  ('afvise',),
#  (),
#  ('million',),
#  (),
#  (),
#  (),
#  (),
#  ('sende',),
#  (),
#  (),
#  ('tælle',),
#  ('indlogere',),
#  ('legitim',),
#  (),
#  (),
#  (),
#  (),
#  ('sende',),
#  (),
#  (),
#  (),
#  ('2 000',),
#  ('',),
#  ('tilbageholde',),
#  ('332',),
#  ('10 000',),
#  (),
#  ('million',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('stramme',),
#  ('flygtning',),
#  (),
#  (),
#  ('pågældende',),
#  (),
#  ('190 000',),
#  ('reducere',),
#  ('afvise',),
#  ('antal',),
#  (),
#  (),
#  ('745 545',),
#  (),
#  (),
#  ('afvise',),
#  ('holde',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('al',),
#  ('omfordele',),
#  ('afvise',),
#  (),
#  ('al',),
#  ('registrere',),
#  (),
#  (),
#  (),
#  ('behandle',),
#  ('sende',),
#  ('sende',),
#  (),
#  (),
#  (),
#  (),
#  ('tilbagesende',),
#  ('sende',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  (),
#  (),
#  ('afvise',),
#  (),
#  ('registrere',),
#  ('modtage',),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  (),
#  ('vis',),
#  (),
#  (),
#  (),
#  ('8000',),
#  (),
#  ('afghansk',),
#  (),
#  (),
#  ('modtage',),
#  (),
#  ('1 307',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('al',),
#  ('200',),
#  (),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  ('sende',),
#  (),
#  ('507 332',),
#  ('73 309',),
#  (),
#  ('nå',),
#  ('90 000',),
#  ('160 000',),
#  ('forhindre',),
#  ('afvise',),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  (),
#  (),
#  ('afghansk',),
#  ('afvise',),
#  ('rekordfå',),
#  ('2 150',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  (),
#  ('syrisk',),
#  (),
#  ('fordel',),
#  ('måned',),
#  (),
#  (),
#  (),
#  ('irakisk',),
#  (),
#  ('antal',),
#  ('samtlige',),
#  (),
#  ('afvise',),
#  ('samtlige',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('afvise',),
#  (),
#  (),
#  (),
#  ('million',),
#  (),
#  ('udenlandsk',),
#  ('afvise',),
#  (),
#  (),
#  ('afvise',),
#  ('afvise',),
#  ('afvise',),
#  (),
#  ('samtlige',),
#  (),
#  (),
#  ('55',),
#  (),
#  ('afvise',),
#  (),
#  ('forhindre',),
#  (),
#  ('flytte',),
#  ('spontan',),
#  (),
#  ('afvise',),
#  (),
#  ('40 000',),
#  ('afvise',),
#  ('20 000',),
#  (),
#  (),
#  ('vinke',),
#  (),
#  ('1 200',),
#  (),
#  (),
#  (),
#  ('36 000',),
#  ('3 200',),
#  (),
#  ('350',),
#  ('mandlig',),
#  (),
#  (),
#  ('forvente',),
#  ('6 900',),
#  ('4 400',),
#  ('160 000',),
#  (),
#  (),
#  ('21 000',),
#  (),
#  ('5100',),
#  (),
#  ('afvise',),
#  (),
#  (),
#  ...]

# %%
asylansøgermodifier_count = collections.Counter(asylansøgermodifier).most_common(100)

df_asylansøgermodifier = pd.DataFrame(asylansøgermodifier_count)
df_asylansøgermodifier.head(11)
# Out:
#                 0     1
# 0              ()  2491
# 1       (afvise,)   502
# 2        (antal,)   109
# 3        (sende,)    78
# 4   (mindreårig,)    51
# 5           (al,)    44
# 6       (syrisk,)    40
# 7       (20 000,)    36
# 8      (spontan,)    28
# 9           (nå,)    24
# 10         (ung,)    24

# %%
df_asylansøgermodifier['Searchword'] = 'asylansøger'
df_asylansøgermodifier.drop('Keyword', axis=1, inplace = True)

# %%
df_asylansøgermodifier['Term'] = 'asylansøger'
df_asylansøgermodifier.drop('Searchword', axis=1, inplace = True)

# %%
df_asylansøgermodifier
# Out:
#                   0     1         Term
# 0                ()  2491  asylansøger
# 1         (afvise,)   502  asylansøger
# 2          (antal,)   109  asylansøger
# 3          (sende,)    78  asylansøger
# 4     (mindreårig,)    51  asylansøger
# 5             (al,)    44  asylansøger
# 6         (syrisk,)    40  asylansøger
# 7         (20 000,)    36  asylansøger
# 8        (spontan,)    28  asylansøger
# 9             (nå,)    24  asylansøger
# 10           (ung,)    24  asylansøger
# 11      (afghansk,)    21  asylansøger
# 12           (hus,)    21  asylansøger
# 13       (irakisk,)    21  asylansøger
# 14       (million,)    21  asylansøger
# 15              (,)    20  asylansøger
# 16           (200,)    18  asylansøger
# 17      (kriminel,)    16  asylansøger
# 18       (modtage,)    15  asylansøger
# 19        (25 000,)    14  asylansøger
# 20        (hjælpe,)    13  asylansøger
# 21        (iransk,)    13  asylansøger
# 22           (500,)    13  asylansøger
# 23     (forhindre,)    12  asylansøger
# 24        (første,)    12  asylansøger
# 25   (indkvartere,)    12  asylansøger
# 26      (behandle,)    12  asylansøger
# 27        (enkelt,)    11  asylansøger
# 28  (tilbageholde,)    11  asylansøger
# 29        (21 000,)    11  asylansøger
# ..              ...   ...          ...
# 70          (5000,)     6  asylansøger
# 71       (tyrkisk,)     6  asylansøger
# 72          (land,)     5  asylansøger
# 73        (ritzau,)     5  asylansøger
# 74           (syg,)     5  asylansøger
# 75           (båd,)     5  asylansøger
# 76            (20,)     5  asylansøger
# 77        (stoppe,)     5  asylansøger
# 78     (flygtning,)     5  asylansøger
# 79      (forvente,)     5  asylansøger
# 80       (danmark,)     5  asylansøger
# 81     (forsvinde,)     5  asylansøger
# 82            (31,)     5  asylansøger
# 83            (60,)     5  asylansøger
# 84   (nytilkommen,)     5  asylansøger
# 85          (7500,)     5  asylansøger
# 86          (3000,)     4  asylansøger
# 87            (år,)     4  asylansøger
# 88            (42,)     4  asylansøger
# 89       (forhold,)     4  asylansøger
# 90      (somalisk,)     4  asylansøger
# 91       (EU land,)     4  asylansøger
# 92         (enkel,)     4  asylansøger
# 93       (160 000,)     4  asylansøger
# 94        (flytte,)     4  asylansøger
# 95         (række,)     4  asylansøger
# 96       (800 000,)     4  asylansøger
# 97           (120,)     4  asylansøger
# 98            (70,)     4  asylansøger
# 99        (mængde,)     4  asylansøger
#
# [100 rows x 3 columns]

# %% [markdown]
# **Migrant Modifier**

# %%
string = lemmatize_strings(' '.join(article_data['Text']).split(' '))

# %%
dictionary = ['migrant']
migrantmodifier = []
for word in dictionary:
    stop = False
    while not stop:
        try:
            idx = string.index(word)
            migrantmodifier.append(tuple(string[idx-1:idx]))
            string = string[idx+1:]
        except:
            stop = True
                  
migrantmodifier
# Out:
# [('165',),
#  ('gruppe',),
#  ('72',),
#  ('afrikansk',),
#  (),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('afrikansk',),
#  ('for',),
#  ('irregulær',),
#  ('som',),
#  ('var',),
#  ('af',),
#  ('250',),
#  ('20 000',),
#  ('af',),
#  ('med',),
#  ('8400',),
#  ('udokumentere',),
#  ('papirløs',),
#  ('300',),
#  ('de',),
#  ('426',),
#  ('af',),
#  ('redde',),
#  ('samle',),
#  ('141',),
#  ('søredningstjeneste',),
#  ('86',),
#  ('141',),
#  ('11 000',),
#  ('31 600',),
#  ('65',),
#  ('ø',),
#  ('af',),
#  ('italien',),
#  ('med',),
#  ('62',),
#  ('af',),
#  ('flest',),
#  ('blandt',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('håne',),
#  ('dø',),
#  ('42',),
#  ('',),
#  ('samle',),
#  ('lad',),
#  ('at',),
#  ('af',),
#  ('for',),
#  ('hvor',),
#  ('lade',),
#  ('kvindelig',),
#  ('dø',),
#  ('behandle',),
#  ('af',),
#  ('antal',),
#  ('tilbageholde',),
#  ('nødstedt',),
#  ('tusind',),
#  ('40',),
#  ('',),
#  ('al',),
#  ('ombordværende',),
#  ('40',),
#  ('at',),
#  ('lad',),
#  ('144 000',),
#  ('med',),
#  ('med',),
#  ('23 000',),
#  ('71',),
#  ('2015',),
#  ('71',),
#  ('indespærre',),
#  ('dø',),
#  ('og',),
#  ('smugle',),
#  ('redde',),
#  ('og',),
#  ('mange',),
#  ('skibbruden',),
#  ('82',),
#  ('skibbruden',),
#  ('samle',),
#  ('for',),
#  ('og',),
#  ('to',),
#  ('for',),
#  ('6 000',),
#  ('af',),
#  ('for',),
#  ('for',),
#  ('at',),
#  ('for',),
#  ('holde',),
#  ('afrikansk',),
#  ('med',),
#  ('hos',),
#  ('til',),
#  ('mod',),
#  ('og',),
#  ('og',),
#  ('arabisk',),
#  ('mange',),
#  ('tilbagesende',),
#  ('overleve',),
#  ('ifølge',),
#  ('6 000',),
#  ('de',),
#  ('de',),
#  ('af',),
#  ('af',),
#  ('at',),
#  ('til',),
#  ('med',),
#  ('500',),
#  ('ritzau',),
#  ('fordi',),
#  ('108',),
#  ('at',),
#  ('at',),
#  ('108',),
#  ('da',),
#  ('af',),
#  ('mod',),
#  ('med',),
#  ('af',),
#  ('missing',),
#  ('drukne',),
#  ('afrikansk',),
#  ('40',),
#  ('100',),
#  ('da',),
#  ('120',),
#  ('af',),
#  ('imod',),
#  ('afrikansk',),
#  ('afrikansk',),
#  ('med',),
#  ('de',),
#  ('forhindre',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('300',),
#  ('for',),
#  ('af',),
#  ('for',),
#  ('hundred',),
#  ('af',),
#  ('de',),
#  ('ned',),
#  ('tilbageholde',),
#  ('hundred',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('illegal',),
#  ('for',),
#  ('af',),
#  ('3139',),
#  ('af',),
#  ('180',),
#  ('300',),
#  ('afrikansk',),
#  ('land',),
#  ('og',),
#  ('af',),
#  ('nødstedt',),
#  ('hav',),
#  ('samle',),
#  ('144 000',),
#  ('samle',),
#  ('med',),
#  ('mod',),
#  ('på',),
#  ('desperat',),
#  ('sejle',),
#  ('nødstedt',),
#  ('62',),
#  ('imod',),
#  ('ville',),
#  ('af',),
#  ('afhente',),
#  ('en',),
#  ('af',),
#  ('af',),
#  ('for',),
#  ('være',),
#  ('af',),
#  ('og',),
#  ('den',),
#  ('bremse',),
#  ('og',),
#  ('jeg',),
#  ('af',),
#  ('bremse',),
#  ('som',),
#  ('49',),
#  ('modtage',),
#  ('øvrig',),
#  ('af',),
#  ('imod',),
#  ('49',),
#  ('af',),
#  ('imod',),
#  ('de',),
#  ('af',),
#  ('antal',),
#  ('desperat',),
#  ('500',),
#  ('udvise',),
#  ('tusind',),
#  ('af',),
#  ('tusind',),
#  ('desperat',),
#  ('3 000',),
#  ('med',),
#  ('mexico',),
#  ('bør',),
#  ('samtidig',),
#  ('10 000',),
#  ('af',),
#  ('håndtere',),
#  ('nyankomme',),
#  ('til',),
#  ('og',),
#  ('flere',),
#  ('af',),
#  ('mange',),
#  ('redde',),
#  ('for',),
#  ('redde',),
#  ('af',),
#  ('og',),
#  ('af',),
#  ('2 000',),
#  ('1 000',),
#  ('by',),
#  ('kunne',),
#  ('anden',),
#  ('mange',),
#  ('behandle',),
#  ('haitiansk',),
#  ('400',),
#  ('gruppe',),
#  ('city',),
#  ('af',),
#  ('illegal',),
#  ('stenkaste',),
#  ('forhindre',),
#  ('af',),
#  ('177',),
#  ('imod',),
#  ('og',),
#  ('lad',),
#  ('at',),
#  ('190',),
#  ('nødstedt',),
#  ('men',),
#  ('177',),
#  ('afvise',),
#  ('med',),
#  ('at',),
#  ('til',),
#  ('sende',),
#  ('for',),
#  ('restere',),
#  ('stenkaste',),
#  ('mellemamerikansk',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('at',),
#  ('fordi',),
#  ('afrikansk',),
#  ('her',),
#  ('dræbe',),
#  ('',),
#  ('ned',),
#  ('for',),
#  ('lade',),
#  ('for',),
#  ('mange',),
#  ('af',),
#  ('af',),
#  ('2 100',),
#  ('140 000',),
#  ('af',),
#  ('500',),
#  ('til',),
#  ('USA',),
#  ('illegal',),
#  ('have',),
#  ('sidde',),
#  ('for',),
#  ('650 000',),
#  ('bremse',),
#  ('og',),
#  ('eller',),
#  ('imod',),
#  ('centralamerikansk',),
#  ('af',),
#  ('stoppe',),
#  ('for',),
#  ('karavane',),
#  ('af',),
#  ('med',),
#  ('flere',),
#  ('at',),
#  ('for',),
#  ('mange',),
#  ('108',),
#  ('1 500',),
#  ('en',),
#  ('at',),
#  ('hvor',),
#  ('af',),
#  ('selvom',),
#  ('af',),
#  ('betale',),
#  ('1 000',),
#  ('USA',),
#  ('stor',),
#  ('med',),
#  ('der',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('for',),
#  ('og',),
#  ('centralamerikansk',),
#  ('af',),
#  ('beskytte',),
#  ('forbedre',),
#  ('for',),
#  ('6 000',),
#  ('igen',),
#  ('af',),
#  ('få',),
#  ('flere',),
#  ('og',),
#  ('som',),
#  ('sende',),
#  ('tilbagesende',),
#  ('og',),
#  ('samle',),
#  ('150',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('hvor',),
#  ('hundred',),
#  ('al',),
#  ('med',),
#  ('antal',),
#  ('137',),
#  ('redde',),
#  ('at',),
#  ('at',),
#  ('100',),
#  ('række',),
#  ('hver',),
#  ('forinden',),
#  ('juble',),
#  ('karavane',),
#  ('by',),
#  ('de',),
#  ('tusind',),
#  ('op',),
#  ('velorganiseret',),
#  ('sige',),
#  ('flest',),
#  ('140',),
#  ('af',),
#  ('lad',),
#  ('af',),
#  ('de',),
#  ('1 500',),
#  ('500',),
#  ('18 653',),
#  ('294',),
#  ('630',),
#  ('redde',),
#  ('imod',),
#  ('lod',),
#  ('for',),
#  ('af',),
#  ('at',),
#  ('økonomisk',),
#  ('7 000',),
#  ('hente',),
#  ('køre',),
#  ('efterlade',),
#  ('samle',),
#  ('og',),
#  ('629',),
#  ('200',),
#  ('fordel',),
#  ('hvordan',),
#  ('fordel',),
#  ('af',),
#  ('629',),
#  ('caribisk',),
#  ('som',),
#  ('hvorfor',),
#  ('af',),
#  ('af',),
#  ('mellem',),
#  ('sende',),
#  ('beskytte',),
#  ('113',),
#  ('landsætte',),
#  ('redde',),
#  ('113',),
#  ('629',),
#  ('ritzau',),
#  ('629',),
#  ('for',),
#  ('629',),
#  ('af',),
#  ('samle',),
#  ('men',),
#  ('og',),
#  ('af',),
#  ('få',),
#  ('flere',),
#  ('for',),
#  ('båd',),
#  ('de',),
#  ('antal',),
#  ('og',),
#  ('de',),
#  ('629',),
#  ('629',),
#  ('imod',),
#  ('strande',),
#  ('med',),
#  ('at',),
#  ('af',),
#  ('2 850',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('af',),
#  ('40 944',),
#  ('har',),
#  ('16 228',),
#  ('med',),
#  ('med',),
#  ('108',),
#  ('af',),
#  ('illegal',),
#  ('samle',),
#  ('illegal',),
#  ('mange',),
#  ('samle',),
#  ('2 400',),
#  ('og',),
#  ('nødstedt',),
#  ('nødstedt',),
#  ('imod',),
#  ('220',),
#  ('med',),
#  ('og',),
#  ('af',),
#  ('25 000',),
#  ('47 000',),
#  ('antal',),
#  ('for',),
#  ('blive',),
#  ('samtlige',),
#  ('adskille',),
#  ('illegal',),
#  ('dehumanisere',),
#  ('629',),
#  ('af',),
#  ('mange',),
#  ('600 000',),
#  ('2 853',),
#  ('for',),
#  ('med',),
#  ('af',),
#  ('afrikansk',),
#  ('116',),
#  ('200',),
#  ('for',),
#  ('af',),
#  ('forhindre',),
#  ('af',),
#  ('for',),
#  ('flest',),
#  ('23 000',),
#  ('af',),
#  ('million',),
#  ('af',),
#  ('af',),
#  ('65 000',),
#  ('selvom',),
#  ('108',),
#  ('af',),
#  ('for',),
#  ('for',),
#  ('6 000',),
#  ('7 000',),
#  ('for',),
#  ('har',),
#  ('og',),
#  ('flest',),
#  ('få',),
#  ('flere',),
#  ('term',),
#  ('751',),
#  ('709',),
#  ('11',),
#  ('som',),
#  ('af',),
#  ('af',),
#  ('125 000',),
#  ('600 000',),
#  ('italien',),
#  ('også',),
#  ('libysk',),
#  ('libysk',),
#  ('190',),
#  ('imod',),
#  ('at',),
#  ('18 000',),
#  ('samle',),
#  ('de',),
#  ('at',),
#  ('900',),
#  ('afrikansk',),
#  ('tilbageholde',),
#  ('og',),
#  ('for',),
#  ('mange',),
#  ('som',),
#  ('caribisk',),
#  ('første',),
#  ('caribisk',),
#  ('caribisk',),
#  ('af',),
#  ('5000',),
#  ('af',),
#  ('lad',),
#  ('centralamerikansk',),
#  ('de',),
#  ('200',),
#  ('tusind',),
#  ('at',),
#  ('som',),
#  ('tusind',),
#  ('flere',),
#  ('af',),
#  ('at',),
#  ('af',),
#  ('af',),
#  ('som',),
#  ('10 000',),
#  ('at',),
#  ('med',),
#  ('de',),
#  ('af',),
#  ('million',),
#  ('44 370',),
#  ('de',),
#  ('omkring',),
#  ('flest',),
#  ('mange',),
#  ('af',),
#  ('11 000',),
#  ('4 000',),
#  ('antal',),
#  ('af',),
#  ('komme',),
#  ('5 583',),
#  ('2 827',),
#  ('og',),
#  ('har',),
#  ('og',),
#  ('EU land',),
#  ('af',),
#  ('for',),
#  ('samle',),
#  ('nødstedt',),
#  ('med',),
#  ('få',),
#  ('samle',),
#  ('nødstedt',),
#  ('af',),
#  ('million',),
#  ('43 096',),
#  ('af',),
#  ('af',),
#  ('16 326',),
#  ('71 918',),
#  ('af',),
#  ('med',),
#  ('100',),
#  ('omkring',),
#  ('hvor',),
#  ('at',),
#  ('term',),
#  ('nødstedt',),
#  ('imod',),
#  ('at',),
#  ('200',),
#  ('629',),
#  ('hvor',),
#  ('de',),
#  ('økonomisk',),
#  ('netop',),
#  ('af',),
#  ('million',),
#  ('43 096',),
#  ('af',),
#  ('i',),
#  ('flest',),
#  ('med',),
#  ('59',),
#  ('59',),
#  ('med',),
#  ('59',),
#  ('at',),
#  ('med',),
#  ('629',),
#  ('nødstedt',),
#  ('af',),
#  ('mærske',),
#  ('mange',),
#  ('for',),
#  ('imod',),
#  ('108',),
#  ('41 000',),
#  ('600 000',),
#  ('113',),
#  ('med',),
#  ('ovenikøbet',),
#  ('sætte',),
#  ('629',),
#  ('nødstedt',),
#  ('nogen',),
#  ('og',),
#  ('nødstedt',),
#  ('komme',),
#  ('her',),
#  ('af',),
#  ('40 944',),
#  ('har',),
#  ('16 228',),
#  ('med',),
#  ('samle',),
#  ('at',),
#  ('samle',),
#  ('samle',),
#  ('113',),
#  ('629',),
#  ('samle',),
#  ('illegal',),
#  ('forhindre',),
#  ('illegal',),
#  ('nødstedt',),
#  ('hvorvidt',),
#  ('113',),
#  ('113',),
#  ('for',),
#  ('disse',),
#  ('redde',),
#  ('her',),
#  ('41 000',),
#  ('og',),
#  ('og',),
#  ('630',),
#  ('og',),
#  ('og',),
#  ('400',),
#  ('blive',),
#  ('før',),
#  ('og',),
#  ('44 370',),
#  ('flest',),
#  ('af',),
#  ('af',),
#  ('50',),
#  ('for',),
#  ('og',),
#  ('mange',),
#  ('imod',),
#  ('for',),
#  ('redde',),
#  ('af',),
#  ('af',),
#  ('stoppe',),
#  ('tilbyde',),
#  ('opfordre',),
#  ('hjælpe',),
#  ('7000',),
#  ('bed',),
#  ('af',),
#  ('af',),
#  ('stoppe',),
#  ('om',),
#  ('af',),
#  ('de',),
#  ('tilbyde',),
#  ('BBC',),
#  ('af',),
#  ('de',),
#  ('til',),
#  ('til',),
#  ('nogen',),
#  ('3 000',),
#  ('af',),
#  ('50',),
#  ('6 000',),
#  ('AP',),
#  ('rum',),
#  ('af',),
#  ('af',),
#  ('mange',),
#  ('7 000',),
#  ('by',),
#  ('være',),
#  ('2 500',),
#  ('af',),
#  ('12',),
#  ('imod',),
#  ('da',),
#  ('og',),
#  ('at',),
#  ('af',),
#  ('her',),
#  ('af',),
#  ('sejle',),
#  ('900',),
#  ('ombord',),
#  ('med',),
#  ('modtage',),
#  ('med',),
#  ('71',),
#  ('at',),
#  ('til',),
#  ('71',),
#  ('for',),
#  ('høre',),
#  ('desperat',),
#  ('være',),
#  ('at',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('redde',),
#  ('afrikansk',),
#  ('byde',),
#  ('180',),
#  ('stoppe',),
#  ('man',),
#  ('da',),
#  ('mange',),
#  ('at',),
#  ('187',),
#  ('200',),
#  ('med',),
#  ('afrika',),
#  ('få',),
#  ('15 000',),
#  ('med',),
#  ('af',),
#  ('af',),
#  ('1 200',),
#  ('ej',),
#  ('vinke',),
#  ('og',),
#  ('af',),
#  ('11 000',),
#  ('flere',),
#  ('opfange',),
#  ('1 180',),
#  ('af',),
#  ('i',),
#  ('opsamle',),
#  ('samle',),
#  ('og',),
#  ('at',),
#  ('af',),
#  ('sårbar',),
#  ('for',),
#  ('at',),
#  ('af',),
#  ('af',),
#  ('flere',),
#  ('de',),
#  ('og',),
#  ('6 400',),
#  ('IOM',),
#  ('antal',),
#  ('1 900',),
#  ('mange',),
#  ('at',),
#  ('af',),
#  ('5 000',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('mange',),
#  ('og',),
#  ('på',),
#  ('økonomisk',),
#  ('af',),
#  ('af',),
#  ('stoppe',),
#  ('af',),
#  ('6000',),
#  ('7000',),
#  ('af',),
#  ('at',),
#  ('af',),
#  ('de',),
#  ('af',),
#  ('700',),
#  ('300',),
#  ('lade',),
#  ('med',),
#  ('og',),
#  ('af',),
#  ('mod',),
#  ('at',),
#  ('af',),
#  ('for',),
#  ('50',),
#  ('og',),
#  ('være',),
#  ('af',),
#  ('af',),
#  ('forhindre',),
#  ('1100',),
#  ('sne',),
#  ('af',),
#  ('hvor',),
#  ('melilla',),
#  ('sende',),
#  ('fratage',),
#  ('400',),
#  ('ceuta',),
#  ('at',),
#  ('for',),
#  ('459 511',),
#  ('komme',),
#  ('nigeriansk',),
#  ('med',),
#  ('af',),
#  ('første',),
#  ('enkelt',),
#  ('og',),
#  ('og',),
#  ('af',),
#  ('og',),
#  ('illegal',),
#  ('at',),
#  ('før',),
#  ('fordi',),
#  ('illegal',),
#  ('afrikansk',),
#  ('afrikansk',),
#  ('hav',),
#  ('afrikansk',),
#  ('være',),
#  ('venezuelansk',),
#  ('mange',),
#  ('afrikansk',),
#  ('fragte',),
#  ('15 000',),
#  ('af',),
#  ('anden',),
#  ('af',),
#  ('ung',),
#  ('100',),
#  ('en',),
#  ('100',),
#  ('afghansk',),
#  ('200',),
#  ('mellem',),
#  ('for',),
#  ('800',),
#  ('anden',),
#  ('al',),
#  ('240',),
#  ('forlise',),
#  ('og',),
#  ('de',),
#  ('holde',),
#  ('for',),
#  ('latinamerikansk',),
#  ('600',),
#  ('antal',),
#  ('af',),
#  ('af',),
#  ('9000',),
#  ('flest',),
#  ('de',),
#  ('om',),
#  ('100 000',),
#  ('ung',),
#  ('120',),
#  ('som',),
#  ('reut',),
#  ('illegal',),
#  ('dø',),
#  ('illegal',),
#  ('mod',),
#  ('600 000',),
#  ('afrikansk',),
#  ('12',),
#  ('være',),
#  ('imod',),
#  ('om',),
#  ('sætte',),
#  ('1 046 599',),
#  ('imod',),
#  ('imod',),
#  ('med',),
#  ('12',),
#  ('for',),
#  ('lås',),
#  ('og',),
#  ('mellem',),
#  ('forsøge',),
#  ('på',),
#  ('at',),
#  ('som',),
#  ('de',),
#  ('sende',),
#  ('eller',),
#  ('for',),
#  ('44 370',),
#  ('flest',),
#  ('af',),
#  ('at',),
#  ('imod',),
#  ('for',),
#  ('sende',),
#  ('med',),
#  ('og',),
#  ('fra',),
#  ('for',),
#  ('120 000',),
#  ('afrikansk',),
#  ('og',),
#  ('15 000',),
#  ('de',),
#  ('hvordan',),
#  ('og',),
#  ('430',),
#  ('af',),
#  ('og',),
#  ('i',),
#  ('hvor',),
#  ('og',),
#  ('mellem',),
#  ('økonomisk',),
#  ('al',),
#  ('modtage',),
#  ('for',),
#  ('for',),
#  ('af',),
#  ('skal',),
#  ('stoppe',),
#  ('170',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('fragte',),
#  ('sende',),
#  ('at',),
#  ...]

# %%
migrantmodifier
def remove_stopwords(lst):
    with open('./stopord.txt', 'r') as sw:
        stopwords = sw.read().split('\n')
        #read the stopwords file 
        return [word for word in lst if not word in stopwords]

migrantmodifier = [tuple(remove_stopwords(lst)) for lst in migrantmodifier]
migrantmodifier
# Out:
# [('165',),
#  ('gruppe',),
#  ('72',),
#  ('afrikansk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('afrikansk',),
#  (),
#  ('irregulær',),
#  (),
#  (),
#  (),
#  ('250',),
#  ('20 000',),
#  (),
#  (),
#  ('8400',),
#  ('udokumentere',),
#  ('papirløs',),
#  ('300',),
#  (),
#  ('426',),
#  (),
#  ('redde',),
#  ('samle',),
#  ('141',),
#  ('søredningstjeneste',),
#  ('86',),
#  ('141',),
#  ('11 000',),
#  ('31 600',),
#  ('65',),
#  ('ø',),
#  (),
#  ('italien',),
#  (),
#  ('62',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('håne',),
#  ('dø',),
#  ('42',),
#  ('',),
#  ('samle',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('lade',),
#  ('kvindelig',),
#  ('dø',),
#  ('behandle',),
#  (),
#  ('antal',),
#  ('tilbageholde',),
#  ('nødstedt',),
#  ('tusind',),
#  ('40',),
#  ('',),
#  ('al',),
#  ('ombordværende',),
#  ('40',),
#  (),
#  (),
#  ('144 000',),
#  (),
#  (),
#  ('23 000',),
#  ('71',),
#  ('2015',),
#  ('71',),
#  ('indespærre',),
#  ('dø',),
#  (),
#  ('smugle',),
#  ('redde',),
#  (),
#  (),
#  ('skibbruden',),
#  ('82',),
#  ('skibbruden',),
#  ('samle',),
#  (),
#  (),
#  (),
#  (),
#  ('6 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('holde',),
#  ('afrikansk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('arabisk',),
#  (),
#  ('tilbagesende',),
#  ('overleve',),
#  ('ifølge',),
#  ('6 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('500',),
#  ('ritzau',),
#  (),
#  ('108',),
#  (),
#  (),
#  ('108',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('missing',),
#  ('drukne',),
#  ('afrikansk',),
#  ('40',),
#  ('100',),
#  (),
#  ('120',),
#  (),
#  (),
#  ('afrikansk',),
#  ('afrikansk',),
#  (),
#  (),
#  ('forhindre',),
#  (),
#  (),
#  (),
#  ('300',),
#  (),
#  (),
#  (),
#  ('hundred',),
#  (),
#  (),
#  (),
#  ('tilbageholde',),
#  ('hundred',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  (),
#  ('3139',),
#  (),
#  ('180',),
#  ('300',),
#  ('afrikansk',),
#  ('land',),
#  (),
#  (),
#  ('nødstedt',),
#  ('hav',),
#  ('samle',),
#  ('144 000',),
#  ('samle',),
#  (),
#  (),
#  (),
#  ('desperat',),
#  ('sejle',),
#  ('nødstedt',),
#  ('62',),
#  (),
#  (),
#  (),
#  ('afhente',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bremse',),
#  (),
#  (),
#  (),
#  ('bremse',),
#  (),
#  ('49',),
#  ('modtage',),
#  ('øvrig',),
#  (),
#  (),
#  ('49',),
#  (),
#  (),
#  (),
#  (),
#  ('antal',),
#  ('desperat',),
#  ('500',),
#  ('udvise',),
#  ('tusind',),
#  (),
#  ('tusind',),
#  ('desperat',),
#  ('3 000',),
#  (),
#  ('mexico',),
#  (),
#  ('samtidig',),
#  ('10 000',),
#  (),
#  ('håndtere',),
#  ('nyankomme',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('redde',),
#  (),
#  ('redde',),
#  (),
#  (),
#  (),
#  ('2 000',),
#  ('1 000',),
#  ('by',),
#  (),
#  (),
#  (),
#  ('behandle',),
#  ('haitiansk',),
#  ('400',),
#  ('gruppe',),
#  ('city',),
#  (),
#  ('illegal',),
#  ('stenkaste',),
#  ('forhindre',),
#  (),
#  ('177',),
#  (),
#  (),
#  (),
#  (),
#  ('190',),
#  ('nødstedt',),
#  (),
#  ('177',),
#  ('afvise',),
#  (),
#  (),
#  (),
#  ('sende',),
#  (),
#  ('restere',),
#  ('stenkaste',),
#  ('mellemamerikansk',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('afrikansk',),
#  (),
#  ('dræbe',),
#  ('',),
#  (),
#  (),
#  ('lade',),
#  (),
#  (),
#  (),
#  (),
#  ('2 100',),
#  ('140 000',),
#  (),
#  ('500',),
#  (),
#  ('USA',),
#  ('illegal',),
#  (),
#  ('sidde',),
#  (),
#  ('650 000',),
#  ('bremse',),
#  (),
#  (),
#  (),
#  ('centralamerikansk',),
#  (),
#  ('stoppe',),
#  (),
#  ('karavane',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('108',),
#  ('1 500',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('betale',),
#  ('1 000',),
#  ('USA',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('centralamerikansk',),
#  (),
#  ('beskytte',),
#  ('forbedre',),
#  (),
#  ('6 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sende',),
#  ('tilbagesende',),
#  (),
#  ('samle',),
#  ('150',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('hundred',),
#  ('al',),
#  (),
#  ('antal',),
#  ('137',),
#  ('redde',),
#  (),
#  (),
#  ('100',),
#  ('række',),
#  (),
#  ('forinden',),
#  ('juble',),
#  ('karavane',),
#  ('by',),
#  (),
#  ('tusind',),
#  (),
#  ('velorganiseret',),
#  (),
#  (),
#  ('140',),
#  (),
#  (),
#  (),
#  (),
#  ('1 500',),
#  ('500',),
#  ('18 653',),
#  ('294',),
#  ('630',),
#  ('redde',),
#  (),
#  ('lod',),
#  (),
#  (),
#  (),
#  ('økonomisk',),
#  ('7 000',),
#  ('hente',),
#  ('køre',),
#  ('efterlade',),
#  ('samle',),
#  (),
#  ('629',),
#  ('200',),
#  ('fordel',),
#  (),
#  ('fordel',),
#  (),
#  ('629',),
#  ('caribisk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sende',),
#  ('beskytte',),
#  ('113',),
#  ('landsætte',),
#  ('redde',),
#  ('113',),
#  ('629',),
#  ('ritzau',),
#  ('629',),
#  (),
#  ('629',),
#  (),
#  ('samle',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('båd',),
#  (),
#  ('antal',),
#  (),
#  (),
#  ('629',),
#  ('629',),
#  (),
#  ('strande',),
#  (),
#  (),
#  (),
#  ('2 850',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('40 944',),
#  (),
#  ('16 228',),
#  (),
#  (),
#  ('108',),
#  (),
#  ('illegal',),
#  ('samle',),
#  ('illegal',),
#  (),
#  ('samle',),
#  ('2 400',),
#  (),
#  ('nødstedt',),
#  ('nødstedt',),
#  (),
#  ('220',),
#  (),
#  (),
#  (),
#  ('25 000',),
#  ('47 000',),
#  ('antal',),
#  (),
#  (),
#  ('samtlige',),
#  ('adskille',),
#  ('illegal',),
#  ('dehumanisere',),
#  ('629',),
#  (),
#  (),
#  ('600 000',),
#  ('2 853',),
#  (),
#  (),
#  (),
#  ('afrikansk',),
#  ('116',),
#  ('200',),
#  (),
#  (),
#  ('forhindre',),
#  (),
#  (),
#  (),
#  ('23 000',),
#  (),
#  ('million',),
#  (),
#  (),
#  ('65 000',),
#  (),
#  ('108',),
#  (),
#  (),
#  (),
#  ('6 000',),
#  ('7 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('term',),
#  ('751',),
#  ('709',),
#  ('11',),
#  (),
#  (),
#  (),
#  ('125 000',),
#  ('600 000',),
#  ('italien',),
#  (),
#  ('libysk',),
#  ('libysk',),
#  ('190',),
#  (),
#  (),
#  ('18 000',),
#  ('samle',),
#  (),
#  (),
#  ('900',),
#  ('afrikansk',),
#  ('tilbageholde',),
#  (),
#  (),
#  (),
#  (),
#  ('caribisk',),
#  ('første',),
#  ('caribisk',),
#  ('caribisk',),
#  (),
#  ('5000',),
#  (),
#  (),
#  ('centralamerikansk',),
#  (),
#  ('200',),
#  ('tusind',),
#  (),
#  (),
#  ('tusind',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('10 000',),
#  (),
#  (),
#  (),
#  (),
#  ('million',),
#  ('44 370',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('11 000',),
#  ('4 000',),
#  ('antal',),
#  (),
#  (),
#  ('5 583',),
#  ('2 827',),
#  (),
#  (),
#  (),
#  ('EU land',),
#  (),
#  (),
#  ('samle',),
#  ('nødstedt',),
#  (),
#  (),
#  ('samle',),
#  ('nødstedt',),
#  (),
#  ('million',),
#  ('43 096',),
#  (),
#  (),
#  ('16 326',),
#  ('71 918',),
#  (),
#  (),
#  ('100',),
#  (),
#  (),
#  (),
#  ('term',),
#  ('nødstedt',),
#  (),
#  (),
#  ('200',),
#  ('629',),
#  (),
#  (),
#  ('økonomisk',),
#  ('netop',),
#  (),
#  ('million',),
#  ('43 096',),
#  (),
#  (),
#  (),
#  (),
#  ('59',),
#  ('59',),
#  (),
#  ('59',),
#  (),
#  (),
#  ('629',),
#  ('nødstedt',),
#  (),
#  ('mærske',),
#  (),
#  (),
#  (),
#  ('108',),
#  ('41 000',),
#  ('600 000',),
#  ('113',),
#  (),
#  ('ovenikøbet',),
#  ('sætte',),
#  ('629',),
#  ('nødstedt',),
#  (),
#  (),
#  ('nødstedt',),
#  (),
#  (),
#  (),
#  ('40 944',),
#  (),
#  ('16 228',),
#  (),
#  ('samle',),
#  (),
#  ('samle',),
#  ('samle',),
#  ('113',),
#  ('629',),
#  ('samle',),
#  ('illegal',),
#  ('forhindre',),
#  ('illegal',),
#  ('nødstedt',),
#  ('hvorvidt',),
#  ('113',),
#  ('113',),
#  (),
#  (),
#  ('redde',),
#  (),
#  ('41 000',),
#  (),
#  (),
#  ('630',),
#  (),
#  (),
#  ('400',),
#  (),
#  (),
#  (),
#  ('44 370',),
#  (),
#  (),
#  (),
#  ('50',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('redde',),
#  (),
#  (),
#  ('stoppe',),
#  ('tilbyde',),
#  ('opfordre',),
#  ('hjælpe',),
#  ('7000',),
#  ('bed',),
#  (),
#  (),
#  ('stoppe',),
#  (),
#  (),
#  (),
#  ('tilbyde',),
#  ('BBC',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('3 000',),
#  (),
#  ('50',),
#  ('6 000',),
#  ('AP',),
#  ('rum',),
#  (),
#  (),
#  (),
#  ('7 000',),
#  ('by',),
#  (),
#  ('2 500',),
#  (),
#  ('12',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sejle',),
#  ('900',),
#  ('ombord',),
#  (),
#  ('modtage',),
#  (),
#  ('71',),
#  (),
#  (),
#  ('71',),
#  (),
#  ('høre',),
#  ('desperat',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('redde',),
#  ('afrikansk',),
#  ('byde',),
#  ('180',),
#  ('stoppe',),
#  (),
#  (),
#  (),
#  (),
#  ('187',),
#  ('200',),
#  (),
#  ('afrika',),
#  (),
#  ('15 000',),
#  (),
#  (),
#  (),
#  ('1 200',),
#  (),
#  ('vinke',),
#  (),
#  (),
#  ('11 000',),
#  (),
#  ('opfange',),
#  ('1 180',),
#  (),
#  (),
#  ('opsamle',),
#  ('samle',),
#  (),
#  (),
#  (),
#  ('sårbar',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('6 400',),
#  ('IOM',),
#  ('antal',),
#  ('1 900',),
#  (),
#  (),
#  (),
#  ('5 000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('økonomisk',),
#  (),
#  (),
#  ('stoppe',),
#  (),
#  ('6000',),
#  ('7000',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('700',),
#  ('300',),
#  ('lade',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('50',),
#  (),
#  (),
#  (),
#  (),
#  ('forhindre',),
#  ('1100',),
#  ('sne',),
#  (),
#  (),
#  ('melilla',),
#  ('sende',),
#  ('fratage',),
#  ('400',),
#  ('ceuta',),
#  (),
#  (),
#  ('459 511',),
#  (),
#  ('nigeriansk',),
#  (),
#  (),
#  ('første',),
#  ('enkelt',),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('illegal',),
#  ('afrikansk',),
#  ('afrikansk',),
#  ('hav',),
#  ('afrikansk',),
#  (),
#  ('venezuelansk',),
#  (),
#  ('afrikansk',),
#  ('fragte',),
#  ('15 000',),
#  (),
#  (),
#  (),
#  ('ung',),
#  ('100',),
#  (),
#  ('100',),
#  ('afghansk',),
#  ('200',),
#  (),
#  (),
#  ('800',),
#  (),
#  ('al',),
#  ('240',),
#  ('forlise',),
#  (),
#  (),
#  ('holde',),
#  (),
#  ('latinamerikansk',),
#  ('600',),
#  ('antal',),
#  (),
#  (),
#  ('9000',),
#  (),
#  (),
#  (),
#  ('100 000',),
#  ('ung',),
#  ('120',),
#  (),
#  ('reut',),
#  ('illegal',),
#  ('dø',),
#  ('illegal',),
#  (),
#  ('600 000',),
#  ('afrikansk',),
#  ('12',),
#  (),
#  (),
#  (),
#  ('sætte',),
#  ('1 046 599',),
#  (),
#  (),
#  (),
#  ('12',),
#  (),
#  ('lås',),
#  (),
#  (),
#  ('forsøge',),
#  (),
#  (),
#  (),
#  (),
#  ('sende',),
#  (),
#  (),
#  ('44 370',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sende',),
#  (),
#  (),
#  (),
#  (),
#  ('120 000',),
#  ('afrikansk',),
#  (),
#  ('15 000',),
#  (),
#  (),
#  (),
#  ('430',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('økonomisk',),
#  ('al',),
#  ('modtage',),
#  (),
#  (),
#  (),
#  (),
#  ('stoppe',),
#  ('170',),
#  (),
#  (),
#  (),
#  ('fragte',),
#  ('sende',),
#  (),
#  ...]

# %%
migrantmodifier_count = collections.Counter(migrantmodifier).most_common(100)

df_migrantmodifier = pd.DataFrame(migrantmodifier_count)
df_migrantmodifier.head(11)
# Out:
#                0     1
# 0             ()  2302
# 1     (illegal,)    64
# 2   (afrikansk,)    39
# 3       (samle,)    26
# 4       (antal,)    24
# 5     (million,)    21
# 6   (økonomisk,)    20
# 7       (redde,)    19
# 8       (sende,)    19
# 9         (629,)    18
# 10   (nødstedt,)    17

# %%
df_migrantmodifier['Term'] = 'migrant'

# %% [markdown]
# **Immigrant Modifier**

# %%
string = lemmatize_strings(' '.join(article_data['Text']).split(' '))

# %%
dictionary = ['immigrant']
immigrantmodifier = []
for word in dictionary:
    stop = False
    while not stop:
        try:
            idx = string.index(word)
            immigrantmodifier.append(tuple(string[idx-1:idx]))
            string = string[idx+1:]
        except:
            stop = True
                  
immigrantmodifier
# Out:
# [('illegal',),
#  ('illegal',),
#  ('ilegal',),
#  ('463',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('illegal',),
#  ('illegal',),
#  ('og',),
#  ('de',),
#  ('25 000',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('for',),
#  ('blandt',),
#  ('at',),
#  ('klare',),
#  ('lide',),
#  ('at',),
#  ('at',),
#  ('afrikansk',),
#  ('af',),
#  ('imod',),
#  ('kunne',),
#  ('afrikansk',),
#  ('anden',),
#  ('sydamerikansk',),
#  ('afrikansk',),
#  ('om',),
#  ('the',),
#  ('polsk',),
#  ('algiersk',),
#  ('61',),
#  ('48 årig',),
#  ('4 000',),
#  ('mange',),
#  ('tusind',),
#  ('million',),
#  ('latinamerikansk',),
#  ('flere',),
#  ('mod',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('blandt',),
#  ('en',),
#  ('og',),
#  ('af',),
#  ('uddanne',),
#  ('land',),
#  ('3000',),
#  ('illegal',),
#  ('illegal',),
#  ('antal',),
#  ('illegal',),
#  ('72',),
#  ('300',),
#  ('og',),
#  ('USA',),
#  ('mange',),
#  ('en',),
#  ('jage',),
#  ('illegal',),
#  ('antal',),
#  ('for',),
#  ('300',),
#  ('redde',),
#  ('have',),
#  ('mange',),
#  ('af',),
#  ('system',),
#  ('afpresse',),
#  ('at',),
#  ('være',),
#  ('papirløs',),
#  ('af',),
#  ('78',),
#  ('12',),
#  ('afrikansk',),
#  ('illegal',),
#  ('på',),
#  ('illegal',),
#  ('få',),
#  ('illegal',),
#  ('25 000',),
#  ('for',),
#  ('den',),
#  ('dansk',),
#  ('al',),
#  ('at',),
#  ('tæske',),
#  ('på',),
#  ('1800',),
#  ('udenlandsk',),
#  ('illegal',),
#  ('uddanne',),
#  ('lad',),
#  ('illegal',),
#  ('for',),
#  ('overfor',),
#  ('to',),
#  ('af',),
#  ('returnere',),
#  ('efterlade',),
#  ('om',),
#  ('mange',),
#  ('sende',),
#  ('og',),
#  ('illegal',),
#  ('ACLUS',),
#  ('illegal',),
#  ('illegal',),
#  ('caribisk',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('nigeriansk',),
#  ('og',),
#  ('nigeriansk',),
#  ('illegal',),
#  ('caribisk',),
#  ('ung',),
#  ('mellem',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('absorbere',),
#  ('at',),
#  ('som illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('og',),
#  ('illegal',),
#  ('og',),
#  ('overfor',),
#  ('illegal',),
#  ('mod',),
#  ('illegal',),
#  ('enten',),
#  ('illegal',),
#  ('for',),
#  ('mod',),
#  ('på',),
#  ('før',),
#  ('at',),
#  ('dæmonisere',),
#  ('af',),
#  ('ulovlig',),
#  ('illegal',),
#  ('og',),
#  ('400',),
#  ('illegal',),
#  ('mange',),
#  ('selv',),
#  ('1 000',),
#  ('illegal',),
#  ('af',),
#  ('400',),
#  ('hundred',),
#  ('af',),
#  ('35',),
#  ('220',),
#  ('femten',),
#  ('håne',),
#  ('million',),
#  ('af',),
#  ('afrikansk',),
#  ('tusind',),
#  ('illegal',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('mange',),
#  ('mange',),
#  ('med',),
#  ('og',),
#  ('hjælpe',),
#  ('illegal',),
#  ('grænse',),
#  ('tjekke',),
#  ('illegal',),
#  ('illegal',),
#  ('smugle',),
#  ('fattig',),
#  ('fattig',),
#  ('8500',),
#  ('om',),
#  ('til',),
#  ('til',),
#  ('250',),
#  ('af',),
#  ('1000',),
#  ('1000',),
#  ('AFP',),
#  ('',),
#  ('flest',),
#  ('af',),
#  ('til',),
#  ('EU',),
#  ('de',),
#  ('af',),
#  ('at',),
#  ('på',),
#  ('5 000',),
#  ('fra',),
#  ('ni',),
#  ('sætte',),
#  ('holde',),
#  ('og',),
#  ('af',),
#  ('af',),
#  ('de',),
#  ('forsøge',),
#  ('fra',),
#  ('ni',),
#  ('som',),
#  ('lund',),
#  ('flere',),
#  ('få',),
#  ('5 000',),
#  ('illegal',),
#  ('illegal',),
#  ('og',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('ulovlig',),
#  ('af',),
#  ('og',),
#  ('ulovlig',),
#  ('og',),
#  ('al',),
#  ('for',),
#  ('uregelmæssig',),
#  ('og',),
#  ('papirløs',),
#  ('papirløs',),
#  ('og',),
#  ('modtage',),
#  ('acceptere',),
#  ('og',),
#  ('mange',),
#  ('og',),
#  ('og',),
#  ('time',),
#  ('antal',),
#  ('443',),
#  ('flest',),
#  ('af',),
#  ('og',),
#  ('og',),
#  ('illegal',),
#  ('at',),
#  ('900 000',),
#  ('ram',),
#  ('for',),
#  ('illegal',),
#  ('godtroende',),
#  ('indskrive',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('sted',),
#  ('dansk',),
#  ('illegal',),
#  ('se',),
#  ('om',),
#  ('mange',),
#  ('betale',),
#  ('af',),
#  ('kurdisk',),
#  ('tyrkisk',),
#  ('at',),
#  ('type',),
#  ('ulovlig',),
#  ('illegal',),
#  ('illegal',),
#  ('og',),
#  ('for',),
#  ('400 000',),
#  ('ung',),
#  ('ung',),
#  ('ung',),
#  ('ung',),
#  ('holde',),
#  ('mexicansk',),
#  ('hjælpe',),
#  ('illegal',),
#  ('illegal',),
#  ('illegalle',),
#  ('illegal',),
#  ('af',),
#  ('af',),
#  ('af',),
#  ('ulovlig',),
#  ('ulovlig',),
#  ('illegal',),
#  ('sejle',),
#  ('her',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('mange',),
#  ('tilbyde',),
#  ('mange',),
#  ('illegal',),
#  ('europæisk',),
#  ('har',),
#  ('mod',),
#  ('illegal',),
#  ('for',),
#  ('illegal',),
#  ('illegal',),
#  ('til',),
#  ('en',),
#  ('og',),
#  ('af',),
#  ('illegal',),
#  ('til',),
#  ('300',),
#  ('',),
#  ('tusind',),
#  ('366',),
#  ('til',),
#  ('af',),
#  ('af',),
#  ('sende',),
#  ('af',),
#  ('million',),
#  ('mod',),
#  ('f eks',),
#  ('om',),
#  ('og',),
#  ('ung',),
#  ('illegal',),
#  ('udokumentere',),
#  ('mexicansk',),
#  ('at',),
#  ('og',),
#  ('million',),
#  ('million',),
#  ('at',),
#  ('dømme',),
#  ('illegal',),
#  ('ulovlig',),
#  ('af',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('inkludere',),
#  ('nutid',),
#  ('om',),
#  ('på',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('af',),
#  ('illegal',),
#  ('mod',),
#  ('af',),
#  ('til',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('ung',),
#  ('illegal',),
#  ('være',),
#  ('al',),
#  ('illegal',),
#  ('fængsle',),
#  ('af',),
#  ('syrisk',),
#  ('af',),
#  ('udokumentere',),
#  ('udokumentere',),
#  ('union',),
#  ('illegal',),
#  ('illegal',),
#  ('gøre',),
#  ('flere',),
#  ('illegal',),
#  ('af',),
#  ('100 000',),
#  ('93 000',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('af',),
#  ('300 000',),
#  ('båd',),
#  ('flere',),
#  ('af',),
#  ('af',),
#  ('diversity',),
#  ('flere',),
#  ('en',),
#  ('en',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('og',),
#  ('og',),
#  ('på',),
#  ('og',),
#  ('for',),
#  ('illegal',),
#  ('for',),
#  ('an',),
#  ('og',),
#  ('100',),
#  ('950',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('sydeuropæisk',),
#  ('enhver',),
#  ('at',),
#  ('med',),
#  ('million',),
#  ('frede',),
#  ('om',),
#  ('faglært',),
#  ('illegal',),
#  ('flygtning',),
#  ('overfor',),
#  ('illegal',),
#  ('verden',),
#  ('300',),
#  ('af',),
#  ('sætte',),
#  ('dø',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('med',),
#  ('illegal',),
#  ('illegal',),
#  ('uorden',),
#  ('som',),
#  ('illegal',),
#  ('en',),
#  ('med',),
#  ('mexicansk',),
#  ('hilse',),
#  ('særlig',),
#  ('udokumentere',),
#  ('og',),
#  ('trods',),
#  ('trods',),
#  ('illegal',),
#  ('illegal',),
#  ('på',),
#  ('mange',),
#  ('som',),
#  ('voksen',),
#  ('mange',),
#  ('og',),
#  ('og',),
#  ('og',),
#  ('280 000',),
#  ('illegal',),
#  ('og',),
#  ('af',),
#  ('og',),
#  ('hjemløs',),
#  ('anden',),
#  ('fransk',),
#  ('flest',),
#  ('uddanne',),
#  ('anden',),
#  ('del',),
#  ('illegal',),
#  ('illegal',),
#  ('blive',),
#  ('algerisk',),
#  ('algerisk',),
#  ('algerisk',),
#  ('algerisk',),
#  ('illegal',),
#  ('af',),
#  ('bo',)]

# %%
immigrantmodifier
def remove_stopwords(lst):
    with open('./stopord.txt', 'r') as sw:
        stopwords = sw.read().split('\n')
        #read the stopwords file 
        return [word for word in lst if not word in stopwords]

immigrantmodifier = [tuple(remove_stopwords(lst)) for lst in immigrantmodifier]
immigrantmodifier
# Out:
# [('illegal',),
#  ('illegal',),
#  ('ilegal',),
#  ('463',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  ('25 000',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  ('klare',),
#  ('lide',),
#  (),
#  (),
#  ('afrikansk',),
#  (),
#  (),
#  (),
#  ('afrikansk',),
#  (),
#  ('sydamerikansk',),
#  ('afrikansk',),
#  (),
#  ('the',),
#  ('polsk',),
#  ('algiersk',),
#  ('61',),
#  ('48 årig',),
#  ('4 000',),
#  (),
#  ('tusind',),
#  ('million',),
#  ('latinamerikansk',),
#  (),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  ('uddanne',),
#  ('land',),
#  ('3000',),
#  ('illegal',),
#  ('illegal',),
#  ('antal',),
#  ('illegal',),
#  ('72',),
#  ('300',),
#  (),
#  ('USA',),
#  (),
#  (),
#  ('jage',),
#  ('illegal',),
#  ('antal',),
#  (),
#  ('300',),
#  ('redde',),
#  (),
#  (),
#  (),
#  ('system',),
#  ('afpresse',),
#  (),
#  (),
#  ('papirløs',),
#  (),
#  ('78',),
#  ('12',),
#  ('afrikansk',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  (),
#  ('illegal',),
#  ('25 000',),
#  (),
#  (),
#  ('dansk',),
#  ('al',),
#  (),
#  ('tæske',),
#  (),
#  ('1800',),
#  ('udenlandsk',),
#  ('illegal',),
#  ('uddanne',),
#  (),
#  ('illegal',),
#  (),
#  ('overfor',),
#  (),
#  (),
#  ('returnere',),
#  ('efterlade',),
#  (),
#  (),
#  ('sende',),
#  (),
#  ('illegal',),
#  ('ACLUS',),
#  ('illegal',),
#  ('illegal',),
#  ('caribisk',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('nigeriansk',),
#  (),
#  ('nigeriansk',),
#  ('illegal',),
#  ('caribisk',),
#  ('ung',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('absorbere',),
#  (),
#  ('som illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  (),
#  ('overfor',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  (),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('dæmonisere',),
#  (),
#  ('ulovlig',),
#  ('illegal',),
#  (),
#  ('400',),
#  ('illegal',),
#  (),
#  (),
#  ('1 000',),
#  ('illegal',),
#  (),
#  ('400',),
#  ('hundred',),
#  (),
#  ('35',),
#  ('220',),
#  ('femten',),
#  ('håne',),
#  ('million',),
#  (),
#  ('afrikansk',),
#  ('tusind',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('hjælpe',),
#  ('illegal',),
#  ('grænse',),
#  ('tjekke',),
#  ('illegal',),
#  ('illegal',),
#  ('smugle',),
#  ('fattig',),
#  ('fattig',),
#  ('8500',),
#  (),
#  (),
#  (),
#  ('250',),
#  (),
#  ('1000',),
#  ('1000',),
#  ('AFP',),
#  ('',),
#  (),
#  (),
#  (),
#  ('EU',),
#  (),
#  (),
#  (),
#  (),
#  ('5 000',),
#  (),
#  (),
#  ('sætte',),
#  ('holde',),
#  (),
#  (),
#  (),
#  (),
#  ('forsøge',),
#  (),
#  (),
#  (),
#  ('lund',),
#  (),
#  (),
#  ('5 000',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('ulovlig',),
#  (),
#  (),
#  ('ulovlig',),
#  (),
#  ('al',),
#  (),
#  ('uregelmæssig',),
#  (),
#  ('papirløs',),
#  ('papirløs',),
#  (),
#  ('modtage',),
#  ('acceptere',),
#  (),
#  (),
#  (),
#  (),
#  ('time',),
#  ('antal',),
#  ('443',),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('900 000',),
#  ('ram',),
#  (),
#  ('illegal',),
#  ('godtroende',),
#  ('indskrive',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('sted',),
#  ('dansk',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('betale',),
#  (),
#  ('kurdisk',),
#  ('tyrkisk',),
#  (),
#  ('type',),
#  ('ulovlig',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  ('400 000',),
#  ('ung',),
#  ('ung',),
#  ('ung',),
#  ('ung',),
#  ('holde',),
#  ('mexicansk',),
#  ('hjælpe',),
#  ('illegal',),
#  ('illegal',),
#  ('illegalle',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('ulovlig',),
#  ('ulovlig',),
#  ('illegal',),
#  ('sejle',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  ('tilbyde',),
#  (),
#  ('illegal',),
#  ('europæisk',),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('300',),
#  ('',),
#  ('tusind',),
#  ('366',),
#  (),
#  (),
#  (),
#  ('sende',),
#  (),
#  ('million',),
#  (),
#  ('f eks',),
#  (),
#  (),
#  ('ung',),
#  ('illegal',),
#  ('udokumentere',),
#  ('mexicansk',),
#  (),
#  (),
#  ('million',),
#  ('million',),
#  (),
#  ('dømme',),
#  ('illegal',),
#  ('ulovlig',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('inkludere',),
#  ('nutid',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('ung',),
#  ('illegal',),
#  (),
#  ('al',),
#  ('illegal',),
#  ('fængsle',),
#  (),
#  ('syrisk',),
#  (),
#  ('udokumentere',),
#  ('udokumentere',),
#  ('union',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('100 000',),
#  ('93 000',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('300 000',),
#  ('båd',),
#  (),
#  (),
#  (),
#  ('diversity',),
#  (),
#  (),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('an',),
#  (),
#  ('100',),
#  ('950',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('sydeuropæisk',),
#  (),
#  (),
#  (),
#  ('million',),
#  ('frede',),
#  (),
#  ('faglært',),
#  ('illegal',),
#  ('flygtning',),
#  ('overfor',),
#  ('illegal',),
#  ('verden',),
#  ('300',),
#  (),
#  ('sætte',),
#  ('dø',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('uorden',),
#  (),
#  ('illegal',),
#  (),
#  (),
#  ('mexicansk',),
#  ('hilse',),
#  ('særlig',),
#  ('udokumentere',),
#  (),
#  ('trods',),
#  ('trods',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('voksen',),
#  (),
#  (),
#  (),
#  (),
#  ('280 000',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  ('hjemløs',),
#  (),
#  ('fransk',),
#  (),
#  ('uddanne',),
#  (),
#  ('del',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('algerisk',),
#  ('algerisk',),
#  ('algerisk',),
#  ('algerisk',),
#  ('illegal',),
#  (),
#  ('bo',)]

# %%
immigrantmodifier_count = collections.Counter(immigrantmodifier).most_common(100)

df_immigrantmodifier = pd.DataFrame(immigrantmodifier_count)
df_immigrantmodifier.head(11)
# Out:
#                   0    1
# 0                ()  198
# 1        (illegal,)  116
# 2            (ung,)    7
# 3        (ulovlig,)    7
# 4        (million,)    6
# 5      (afrikansk,)    5
# 6            (300,)    4
# 7   (udokumentere,)    4
# 8       (algerisk,)    4
# 9         (tusind,)    3
# 10       (uddanne,)    3

# %%
df_immigrantmodifier['Term'] = 'immigrant'

# %% [markdown]
# **Indvandre Modifier**

# %%
string = lemmatize_strings(' '.join(article_data['Text']).split(' '))

# %%
dictionary = ['indvandre']
indvandremodifier = []
for word in dictionary:
    stop = False
    while not stop:
        try:
            idx = string.index(word)
            indvandremodifier.append(tuple(string[idx-1:idx]))
            string = string[idx+1:]
        except:
            stop = True
                  
indvandremodifier
# Out:
# [('illegal',),
#  ('illegal',),
#  ('al',),
#  ('en',),
#  ('illegal',),
#  ('være',),
#  ('illegal',),
#  ('eller',),
#  ('med',),
#  ('som',),
#  ('og',),
#  ('illegal',),
#  ('55 årig',),
#  ('illegal',),
#  ('illegal',),
#  ('og',),
#  ('illegal',),
#  ('illegal',),
#  ('stærk',),
#  ('ny',),
#  ('gruppe',),
#  ('gruppe',),
#  ('en',),
#  ('megen',),
#  ('som',),
#  ('de',),
#  ('illegal',),
#  ('at',),
#  ('illegal',),
#  ('og',),
#  ('en',),
#  ('ikke vestlig',),
#  ('illegal',),
#  ('som',),
#  ('som',),
#  ('være',),
#  ('være',),
#  ('som',),
#  ('som',),
#  ('være',),
#  ('være',),
#  ('der',),
#  ('der',),
#  ('2014',),
#  ('udlænding',),
#  ('syrer',),
#  ('2013',),
#  ('land',),
#  ('rumæner',),
#  ('statsløs',),
#  ('der',),
#  ('her',),
#  ('dermed',),
#  ('eller',),
#  ('eller',),
#  ('eller',),
#  ('som',),
#  ('flest',),
#  ('mexicansk',),
#  ('illegal',),
#  ('være',),
#  ('være',),
#  ('ikke vestlig',),
#  ('en',),
#  ('eller',),
#  ('eller',),
#  ('eller',),
#  ('for',),
#  ('være',),
#  ('være',),
#  ('være',),
#  ('velintegrere',),
#  ('femte',),
#  ('som',),
#  ('og',),
#  ('være',),
#  ('mange',),
#  ('være',),
#  ('eneste',),
#  ('kvinde',),
#  ('kvindelig',),
#  ('en',),
#  ('forebygge',),
#  ('og',),
#  ('polsk',),
#  ('eller',),
#  ('den',),
#  ('de',),
#  ('med',),
#  ('kvindelig',),
#  ('en',),
#  ('en',),
#  ('en',),
#  ('kristen',),
#  ('være',),
#  ('være',),
#  ('har',),
#  ('palæstinensisk',),
#  ('være',),
#  ('med',),
#  ('dag',),
#  ('2 620',),
#  ('som',),
#  ('ikke vestlig',),
#  ('en',),
#  ('en',),
#  ('var',),
#  ('være',),
#  ('være',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('hver',),
#  ('ikke vestlig',),
#  ('kinesisk',),
#  ('kinesisk',),
#  ('ikke vestlig',),
#  ('en',),
#  ('ikke vestlig',),
#  ('være',),
#  ('være',),
#  ('otte',),
#  ('være',),
#  ('være',),
#  ('de',),
#  ('være',),
#  ('øvrig',),
#  ('de',),
#  ('være',),
#  ('være',),
#  ('danmark',),
#  ('være',),
#  ('være',),
#  ('en',),
#  ('en',),
#  ('fjerde',),
#  ('fjerde',),
#  ('senegalesisk',),
#  ('fjerde',),
#  ('4',),
#  ('som',),
#  ('og',),
#  ('være',),
#  ('se',),
#  ('være',),
#  ('kvindelig',),
#  ('kvindelig',),
#  ('være',),
#  ('jeg',),
#  ('en',),
#  ('man',),
#  ('ikke',),
#  ('en',),
#  ('per',),
#  ('per',),
#  ('pr',),
#  ('højstuddannet',),
#  ('tie',),
#  ('ikke vestlig',),
#  ('jævnaldrende',),
#  ('vestlig',),
#  ('en',),
#  ('kategori',),
#  ('enkelt',),
#  ('der',),
#  ('højtuddannet',),
#  ('en',),
#  ('eneste',),
#  ('for',),
#  ('der',),
#  ('per',),
#  ('illegal',),
#  ('være',),
#  ('30 årig',),
#  ('illegal',),
#  ('illegal',),
#  ('ikke vestlig',),
#  ('en',),
#  ('en',),
#  ('til',),
#  ('illegal',),
#  ('en',),
#  ('sort',),
#  ('mandlig',),
#  ('være',),
#  ('ung',),
#  ('en',),
#  ('ufaglært',),
#  ('en',),
#  ('være',),
#  ('en',),
#  ('tosproget',),
#  ('23 årig',),
#  ('ene',)]

# %%
indvandremodifier
def remove_stopwords(lst):
    with open('./stopord.txt', 'r') as sw:
        stopwords = sw.read().split('\n')
        #read the stopwords file 
        return [word for word in lst if not word in stopwords]

indvandremodifier = [tuple(remove_stopwords(lst)) for lst in indvandremodifier]
indvandremodifier
# Out:
# [('illegal',),
#  ('illegal',),
#  ('al',),
#  (),
#  ('illegal',),
#  (),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  ('illegal',),
#  ('55 årig',),
#  ('illegal',),
#  ('illegal',),
#  (),
#  ('illegal',),
#  ('illegal',),
#  ('stærk',),
#  (),
#  ('gruppe',),
#  ('gruppe',),
#  (),
#  ('megen',),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('illegal',),
#  (),
#  (),
#  ('ikke vestlig',),
#  ('illegal',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('2014',),
#  ('udlænding',),
#  ('syrer',),
#  ('2013',),
#  ('land',),
#  ('rumæner',),
#  ('statsløs',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('mexicansk',),
#  ('illegal',),
#  (),
#  (),
#  ('ikke vestlig',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('velintegrere',),
#  ('femte',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('kvinde',),
#  ('kvindelig',),
#  (),
#  ('forebygge',),
#  (),
#  ('polsk',),
#  (),
#  (),
#  (),
#  (),
#  ('kvindelig',),
#  (),
#  (),
#  (),
#  ('kristen',),
#  (),
#  (),
#  (),
#  ('palæstinensisk',),
#  (),
#  (),
#  ('dag',),
#  ('2 620',),
#  (),
#  ('ikke vestlig',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  ('ikke vestlig',),
#  (),
#  ('ikke vestlig',),
#  ('kinesisk',),
#  ('kinesisk',),
#  ('ikke vestlig',),
#  (),
#  ('ikke vestlig',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('øvrig',),
#  (),
#  (),
#  (),
#  ('danmark',),
#  (),
#  (),
#  (),
#  (),
#  ('fjerde',),
#  ('fjerde',),
#  ('senegalesisk',),
#  ('fjerde',),
#  ('4',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('kvindelig',),
#  ('kvindelig',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('per',),
#  ('per',),
#  ('pr',),
#  ('højstuddannet',),
#  ('tie',),
#  ('ikke vestlig',),
#  ('jævnaldrende',),
#  ('vestlig',),
#  (),
#  ('kategori',),
#  ('enkelt',),
#  (),
#  ('højtuddannet',),
#  (),
#  (),
#  (),
#  (),
#  ('per',),
#  ('illegal',),
#  (),
#  ('30 årig',),
#  ('illegal',),
#  ('illegal',),
#  ('ikke vestlig',),
#  (),
#  (),
#  (),
#  ('illegal',),
#  (),
#  ('sort',),
#  ('mandlig',),
#  (),
#  ('ung',),
#  (),
#  ('ufaglært',),
#  (),
#  (),
#  (),
#  ('tosproget',),
#  ('23 årig',),
#  ()]

# %%
indvandremodifier_count = collections.Counter(indvandremodifier).most_common(100)

df_indvandremodifier = pd.DataFrame(indvandremodifier_count)
df_indvandremodifier.head(11)
# Out:
#                   0    1
# 0                ()  112
# 1        (illegal,)   17
# 2   (ikke vestlig,)   14
# 3      (kvindelig,)    4
# 4         (fjerde,)    3
# 5            (per,)    3
# 6         (gruppe,)    2
# 7       (kinesisk,)    2
# 8             (al,)    1
# 9        (55 årig,)    1
# 10         (stærk,)    1

# %%
df_indvandremodifier['Term'] = 'indvandre'

# %% [markdown]
# **Concatenating the dataframes**

# %%
import numpy as np
import pandas as pd

# %%
lst = [df_flytningmodifier, df_asylansøgermodifier, df_migrantmodifier, df_immigrantmodifier, df_indvandremodifier]
df_allmodifiers = []
for i in lst:
    df_allmodifiers.append(i.head(11).copy())
    
df_allmodifiers = pd.concat(df_allmodifiers)

# %%
df_allmodifiers[0] = df_allmodifiers[0].str[0]
df_allmodifiers['Term'].unique()
# Out:
# array(['flygtning', 'asylansøger', 'migrant', 'immigrant', 'indvandre'],
#       dtype=object)

# %%
df_allmodifiers[df_allmodifiers['Term'] == 'flygtning'].dropna()
# Out:
#             0    1       Term
# 1      syrisk  644  flygtning
# 2       antal  159  flygtning
# 3      hjælpe  144  flygtning
# 4     million  139  flygtning
# 5          al   88  flygtning
# 6       sende   86  flygtning
# 7   nyankomme   60  flygtning
# 8          nå   57  flygtning
# 9     modtage   56  flygtning
# 10        hus   52  flygtning

# %% [markdown]
# **Plot of frequencies**

# %%
df_flytningmodifier[1:11].plot(kind='bar',x=0,y=1)

# %%
df_asylansøgermodifier[1:11].plot(kind='bar',x=0,y=1)

# %%
df_migrantmodifier[1:11].plot(kind='bar',x=0,y=1)

# %%
df_immigrantmodifier[1:11].plot(kind='bar',x=0,y=1)

# %%
df_indvandremodifier[1:11].plot(kind='bar',x=0,y=1)

# %%
sns.palplot(sns.color_palette("hls", 15))

# %%
sns.set_color_codes("pastel")

# %%
lst = [df_flytningmodifier[1:11], df_asylansøgermodifier[1:11], df_immigrantmodifier[1:11], df_migrantmodifier[1:11], df_indvandremodifier[1:11]]
fig, axis = plt.subplots(3,2, figsize = (15,15))
plt.tight_layout(pad=8)

for ax, term in zip(axis.flatten(), df_allmodifiers['Term'].unique()):
    
    data = df_allmodifiers[df_allmodifiers['Term'] == term].dropna()
    
    ax.bar(data[0], data[1], color='g')
    ax.set_title(term, fontdict = {'fontsize':'20'})
    ax.set_xticklabels(data[0], fontdict = {'fontsize' : 12}, rotation = 40, horizontalalignment='right')
    #plt.text(0.5, 0.5, str((2, 3, i)),
             #fontsize=18, ha='center'

axis.flatten()[-1].axis('off')
plt.savefig('modifiers.png')
